# %%
import wittgenstein as lw
import pandas as pd
from inspect import currentframe, getframeinfo
from pandas.core.common import SettingWithCopyError
from wittgenstein import base
pd.options.mode.chained_assignment = 'raise'

# %%
df = pd.read_csv('/Users/ilanmoscovitz/Documents/Metis/Projects/local_lw/datasets/adult.csv')
#df = df.head(1000)

# %%
df.sort_values('age')
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 4159    17           Private  130125          10th              6
# 18810   17           Private  187308          10th              6
# 25709   17           Private  153021          12th              8
# 6046    17                 ?  103810          12th              8
# 8682    17                 ?  127003           9th              5
# 30359   17           Private  160029          11th              7
# 4458    17           Private  245918          11th              7
# 29417   17           Private  147069          10th              6
# 11757   17           Private  294485          10th              6
# 22875   17           Private  142964          11th              7
# 31107   17         Local-gov  192387           9th              5
# 5991    17  Self-emp-not-inc   60116          10th              6
# 8579    17           Private  121037          12th              8
# 22983   17                 ?  241021          12th              8
# 31098   17           Private  169155          12th              8
# 25669   17           Private  202521          10th              6
# 11922   17           Private  154908          10th              6
# 23013   17           Private  205726          11th              7
# 25639   17           Private  321880          10th              6
# 7028    17                 ?  110998  Some-college             10
# 8518    17         Local-gov  246308          11th              7
# 18518   17                 ?   34088          12th              8
# 27555   17           Private  160758          10th              6
# 18498   17           Private  173807          11th              7
# 18816   17                 ?  181337          10th              6
# 25725   17                 ?  212125          10th              6
# 18856   17           Private  277112          11th              7
# 18888   17           Private  244602          12th              8
# 1235    17           Private  209949          11th              7
# 11304   17           Private  111332          11th              7
# ...    ...               ...     ...           ...            ...
# 5896    90           Private  221832     Bachelors             13
# 21420   90           Private  226968       7th-8th              4
# 2299    90           Private  175491       HS-grad              9
# 2296    90           Private   46786     Bachelors             13
# 5134    90           Private  137018       HS-grad              9
# 2241    90  Self-emp-not-inc  155981     Bachelors             13
# 31799   90                 ?  313986       HS-grad              9
# 26259   90                 ?  175444       7th-8th              4
# 20149   90           Private  311184     Bachelors             13
# 1742    90           Private   87372   Prof-school             15
# 1739    90         Local-gov  227796       Masters             14
# 15057   90                 ?  225063  Some-college             10
# 199     90           Private   51744       HS-grad              9
# 28999   90       Federal-gov  195433       HS-grad              9
# 15505   90           Private  250832          10th              6
# 3776    90  Self-emp-not-inc   82628       HS-grad              9
# 3854    90         Local-gov  214594       7th-8th              4
# 31218   90           Private   47929       HS-grad              9
# 16552   90         Local-gov  187749    Assoc-acdm             12
# 23590   90           Private   52386     Bachelors             13
# 9984    90           Private  313986          11th              7
# 25339   90                 ?  166343       1st-4th              2
# 17603   90           Private   90523       HS-grad              9
# 22166   90           Private  206667       Masters             14
# 8914    90           Private   51744       Masters             14
# 8791    90           Private  141758           9th              5
# 8645    90           Private   52386  Some-college             10
# 7756    90           Private  313986          11th              7
# 14659   90           Private   40388     Bachelors             13
# 0       90                 ?   77053       HS-grad              9
#
#            marital.status         occupation    relationship  \
# 4159        Never-married      Other-service       Own-child
# 18810       Never-married      Other-service       Own-child
# 25709       Never-married              Sales       Own-child
# 6046        Never-married                  ?       Own-child
# 8682        Never-married                  ?       Own-child
# 30359       Never-married      Other-service  Other-relative
# 4458        Never-married      Other-service       Own-child
# 29417       Never-married              Sales       Own-child
# 11757       Never-married      Other-service       Own-child
# 22875       Never-married      Other-service       Own-child
# 31107       Never-married      Other-service       Own-child
# 5991        Never-married       Adm-clerical       Own-child
# 8579        Never-married              Sales       Own-child
# 22983       Never-married                  ?       Own-child
# 31098       Never-married      Other-service       Own-child
# 25669       Never-married      Other-service       Own-child
# 11922       Never-married      Other-service       Own-child
# 23013       Never-married              Sales       Own-child
# 25639       Never-married      Other-service       Own-child
# 7028        Never-married                  ?       Own-child
# 8518        Never-married     Prof-specialty       Own-child
# 18518       Never-married                  ?       Own-child
# 27555       Never-married              Sales  Other-relative
# 18498       Never-married       Craft-repair       Own-child
# 18816       Never-married                  ?       Own-child
# 25725       Never-married                  ?       Own-child
# 18856       Never-married              Sales       Own-child
# 18888       Never-married      Other-service       Own-child
# 1235        Never-married              Sales       Own-child
# 11304       Never-married              Sales       Own-child
# ...                   ...                ...             ...
# 5896   Married-civ-spouse    Exec-managerial         Husband
# 21420  Married-civ-spouse  Machine-op-inspct         Husband
# 2299   Married-civ-spouse       Craft-repair         Husband
# 2296   Married-civ-spouse              Sales         Husband
# 5134        Never-married      Other-service   Not-in-family
# 2241   Married-civ-spouse     Prof-specialty         Husband
# 31799  Married-civ-spouse                  ?         Husband
# 26259           Separated                  ?   Not-in-family
# 20149  Married-civ-spouse              Sales         Husband
# 1742   Married-civ-spouse     Prof-specialty         Husband
# 1739   Married-civ-spouse    Exec-managerial         Husband
# 15057       Never-married                  ?       Own-child
# 199         Never-married      Other-service   Not-in-family
# 28999  Married-civ-spouse       Craft-repair         Husband
# 15505  Married-civ-spouse    Exec-managerial         Husband
# 3776        Never-married    Exec-managerial   Not-in-family
# 3854   Married-civ-spouse    Protective-serv         Husband
# 31218  Married-civ-spouse  Machine-op-inspct         Husband
# 16552  Married-civ-spouse       Adm-clerical         Husband
# 23590       Never-married     Prof-specialty   Not-in-family
# 9984   Married-civ-spouse       Craft-repair         Husband
# 25339             Widowed                  ?   Not-in-family
# 17603             Widowed   Transport-moving       Unmarried
# 22166  Married-civ-spouse     Prof-specialty            Wife
# 8914        Never-married    Exec-managerial   Not-in-family
# 8791        Never-married       Adm-clerical   Not-in-family
# 8645        Never-married      Other-service   Not-in-family
# 7756        Never-married  Handlers-cleaners       Own-child
# 14659       Never-married    Exec-managerial   Not-in-family
# 0                 Widowed                  ?   Not-in-family
#
#                      race     sex  capital.gain  capital.loss  hours.per.week  \
# 18498  United-States  <=50K
# 18816  United-States  <=50K
# 25725  United-States  <=50K
# 18856  United-States  <=50K
# 18888  United-States  <=50K
# 1235   United-States  <=50K
# 11304  United-States  <=50K
# ...              ...    ...
# 5896   United-States  <=50K
# 21420  United-States  <=50K
# 2299         Ecuador   >50K
# 2296   United-States   >50K
# 5134   United-States  <=50K
# 2241   United-States  <=50K
# 31799  United-States   >50K
# 26259  United-States  <=50K
# 20149              ?  <=50K
# 1742   United-States   >50K
# 1739   United-States   >50K
# 15057          South  <=50K
# 199    United-States  <=50K
# 28999  United-States  <=50K
# 15505  United-States  <=50K
# 3776   United-States  <=50K
# 3854   United-States  <=50K
# 31218  United-States  <=50K
# 16552    Philippines  <=50K
# 23590  United-States  <=50K
# 9984   United-States  <=50K
# 25339  United-States  <=50K
# 17603  United-States  <=50K
# 22166  United-States   >50K
# 8914   United-States   >50K
# 8791   United-States  <=50K
# 8645   United-States  <=50K
# 7756   United-States  <=50K
# 14659  United-States  <=50K
# 0      United-States  <=50K
#
# [32561 rows x 15 columns]

# %%
train = df.head(1000)
test = df.tail(10000)
irep = lw.IREP(verbosity=4)
irep.fit(train, class_feat='income', pos_class='>50K')

# %%
end

# %%
test_X = test.drop('income',axis=1)
test_X.head(1)
test_y = test['income']
irep.score(test_X, test_y)
#irep.predict(test_X)

# %%
ripper = lw.RIPPER(verbosity=2)
ripper.fit(train, n_discretize_bins=3, class_feat='income', pos_class='>50K')
ripper.score(test_X, test_y)

# %%
ripper.bin_transformer_

# %%
def bar(df):
    def foo(df):
        bar_df = df.copy()
        bar_df['income']=bar_df['age']
        return bar_df
    df = foo(df)
bar(train)
train

# %%
end

# %%
#irep = lw.IREP()
#irep.fit(df, n_discretize_bins=10, class_feat='income', pos_class='>50K')

# %%
#irep.ruleset_

# %%
#from wittgenstein.base import bin_df
#bin_df(df, n_discretize_bins=10, ignore_feats=[], verbosity=0)[0]['age'].value_counts()

# %%
df.head(1)

# %%
irep.bin_transformer_

# %%
import numpy as np
pd.cut(df['age'], bins=10).value_counts()

# %%
bin_df

# %%
len(df)

# %%
train = df.head(1000)
test = df.tail(10000)
irep = lw.IREP(verbosity=2)
irep.fit(train, class_feat='income', pos_class='>50K')

# %%
test_X = test.drop('income',axis=1)
test_y = test['income']
binned_X = base.bin_transform(test_X, irep.bin_transformer_, names_precision=2)
irep.score(test_X, test_y)
#irep.predict(test_X)

# %%
test_X

# %%
df = pd.read_csv('/Users/ilanmoscovitz/Documents/Metis/Projects/local_lw/datasets/house-votes-84.csv')

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df)
irep = lw.IREP(verbosity=1)
irep.fit(train, class_feat='Party', pos_class='democrat')

# %%
test_X = test.drop('Party',axis=1)
test_y = test['Party']
irep.score(test_X, test_y)
