# %% [markdown]
# #### Usage example on congress dataset

# %% [markdown]
# These examples use the RIPPER algorithm. IREP usage is similar, with only slight hyperparameter differences.

# %%
import wittgenstein as lw
import pandas as pd

# %% [markdown]
# Load our dataset:

# %%
df = pd.read_csv('../datasets/adult.csv')
df.head(1)
# Out:
#    age workclass  fnlwgt education  education.num marital.status occupation  \
# 0   90         ?   77053   HS-grad              9        Widowed          ?
#
#     relationship   race     sex  capital.gain  capital.loss  hours.per.week  \
# 0  Not-in-family  White  Female             0          4356              40
#
#   native.country income
# 0  United-States  <=50K

# %% [markdown]
# Split our data into train-test sets:

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, random_state=42)

# %% [markdown]
# #### Training

# %% [markdown]
# Create a ruleset classifier:

# %%
ripper_clf = lw.RIPPER(random_state=42, verbosity=2)
ripper_clf
# Out:
# <RIPPER(n_discretize_bins=10, max_rule_conds=None, random_state=42, max_rules=None, verbosity=2, max_total_conds=None, dl_allowance=64, prune_size=0.33, k=2)>

# %% [markdown]
# Train the ruleset classifier on the trainset:

# %%
ripper_clf.fit(train, class_feat='income', pos_class='>50K')
ripper_clf.ruleset_ # Access underlying model
# Out:
# fitting bins for features ['age', 'fnlwgt', 'education.num', 'capital.gain', 'capital.loss', 'hours.per.week']
#
# growing ruleset...
#
# pos_growset 3950 pos_pruneset 1947
# neg_growset 12410 neg_pruneset 6113
# grew rule: [marital.status=Married-civ-spouse^education.num=(13^9)^capital.gain=(0^0)^hours.per.week=50-75]
# pruned rule unchanged
# updated ruleset: [marital.status=Married-civ-spouse^education.num=(13^9)^capital.gain=(0^0)^hours.per.week=50-75]
#
# pos_growset 3898 pos_pruneset 1920
# neg_growset 12410 neg_pruneset 6113
# grew rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^capital.gain=(0^0)^fnlwgt=(328610^162667)]
# pruned rule unchanged
# updated ruleset: [marital.status=Married-civ-spouse^education.num=(13^9)^capital.gain=(0^0)^hours.per.week=50-75] V [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^capital.gain=(0^0)^fnlwgt=(328610^162667)]
#
# pos_growset 3876 pos_pruneset 1910
# neg_growset 12410 neg_pruneset 6113
# grew rule: [marital.status=Married-civ-spouse^education=Bachelors^occupation=Exec-managerial^hours.per.week=40-50^capital.loss=(2559^0)^workclass=Self-emp-inc]
# pruned rule: [marital.status=Married-civ-spouse^education=Bachelors^occupation=Exec-managerial^hours.per.week=40-50^capital.loss=(2559^0)]
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^capital.gain=(0^0)^fnlwgt=(328610^162667)] V [marital.status=Married-civ-spouse^education=Bachelors^occupation=Exec-managerial^hours.per.week=40-50^capital.loss=(2559^0)]
#
# pos_growset 3859 pos_pruneset 1902
# neg_growset 12409 neg_pruneset 6113
# grew rule: [marital.status=Married-civ-spouse^education=Bachelors^capital.gain=(0^0)^occupation=Exec-managerial^hours.per.week=50-75]
# pruned rule: [marital.status=Married-civ-spouse^education=Bachelors^capital.gain=(0^0)]
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Bachelors^occupation=Exec-managerial^hours.per.week=40-50^capital.loss=(2559^0)] V [marital.status=Married-civ-spouse^education=Bachelors^capital.gain=(0^0)]
#
# pos_growset 3674 pos_pruneset 1810
# neg_growset 12383 neg_pruneset 6100
# grew rule: [marital.status=Married-civ-spouse^education.num=(13^9)^capital.gain=(0^0)^hours.per.week=40-50^occupation=Prof-specialty]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Bachelors^capital.gain=(0^0)] V [marital.status=Married-civ-spouse^education.num=(13^9)^capital.gain=(0^0)^hours.per.week=40-50^occupation=Prof-specialty]
#
# pos_growset 3638 pos_pruneset 1793
# neg_growset 12383 neg_pruneset 6100
# grew rule: [marital.status=Married-civ-spouse^education.num=(13^9)^capital.loss=(2559^0)^hours.per.week=40-50]
# pruned rule: [marital.status=Married-civ-spouse^education.num=(13^9)^capital.loss=(2559^0)]
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=(13^9)^capital.gain=(0^0)^hours.per.week=40-50^occupation=Prof-specialty] V [marital.status=Married-civ-spouse^education.num=(13^9)^capital.loss=(2559^0)]
#
# pos_growset 3544 pos_pruneset 1746
# neg_growset 12376 neg_pruneset 6097
# grew rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Exec-managerial^workclass=Private^age=43-48^hours.per.week=50-75]
# pruned rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Exec-managerial^workclass=Private^age=43-48]
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=(13^9)^capital.loss=(2559^0)] V [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Exec-managerial^workclass=Private^age=43-48]
#
# pos_growset 3513 pos_pruneset 1731
# neg_growset 12374 neg_pruneset 6096
# grew rule: [marital.status=Married-civ-spouse^education.num=(13^9)^capital.gain=(0^0)^occupation=Prof-specialty^hours.per.week=25-37]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Exec-managerial^workclass=Private^age=43-48] V [marital.status=Married-civ-spouse^education.num=(13^9)^capital.gain=(0^0)^occupation=Prof-specialty^hours.per.week=25-37]
#
# pos_growset 3500 pos_pruneset 1724
# neg_growset 12374 neg_pruneset 6096
# grew rule: [marital.status=Married-civ-spouse^education.num=(13^9)^occupation=Exec-managerial^workclass=Private^age=48-55]
# pruned rule: [marital.status=Married-civ-spouse^education.num=(13^9)^occupation=Exec-managerial]
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=(13^9)^capital.gain=(0^0)^occupation=Prof-specialty^hours.per.week=25-37] V [marital.status=Married-civ-spouse^education.num=(13^9)^occupation=Exec-managerial]
#
# pos_growset 3360 pos_pruneset 1655
# neg_growset 12350 neg_pruneset 6084
# grew rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Exec-managerial^workclass=Private^hours.per.week=40-50^fnlwgt=178686-197036]
# pruned rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Exec-managerial^workclass=Private^hours.per.week=40-50]
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=(13^9)^occupation=Exec-managerial] V [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Exec-managerial^workclass=Private^hours.per.week=40-50]
#
# pos_growset 3300 pos_pruneset 1626
# neg_growset 12338 neg_pruneset 6078
# grew rule: [marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^age=43-48^education=Prof-school]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Exec-managerial^workclass=Private^hours.per.week=40-50] V [marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^age=43-48^education=Prof-school]
#
# pos_growset 3286 pos_pruneset 1619
# neg_growset 12338 neg_pruneset 6078
# grew rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^hours.per.week=40-50^capital.loss=(2559^0)^workclass=Private^occupation=Prof-specialty]
# pruned rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^hours.per.week=40-50^capital.loss=(2559^0)]
# updated ruleset: ...[marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^age=43-48^education=Prof-school] V [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^hours.per.week=40-50^capital.loss=(2559^0)]
#
# pos_growset 3267 pos_pruneset 1610
# neg_growset 12336 neg_pruneset 6077
# grew rule: [marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^hours.per.week=37-40^workclass=Private^native.country=United-States^fnlwgt=131298-158948]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^hours.per.week=40-50^capital.loss=(2559^0)] V [marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^hours.per.week=37-40^workclass=Private^native.country=United-States^fnlwgt=131298-158948]
#
# pos_growset 3260 pos_pruneset 1607
# neg_growset 12336 neg_pruneset 6077
# grew rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^capital.loss=(2559^0)^workclass=Private^hours.per.week=37-40]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^hours.per.week=37-40^workclass=Private^native.country=United-States^fnlwgt=131298-158948] V [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^capital.loss=(2559^0)^workclass=Private^hours.per.week=37-40]
#
# pos_growset 3236 pos_pruneset 1595
# neg_growset 12336 neg_pruneset 6077
# grew rule: [marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^hours.per.week=37-40^race=White^workclass=State-gov^age=43-48]
# pruned rule: [marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^hours.per.week=37-40^race=White^workclass=State-gov]
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^capital.loss=(2559^0)^workclass=Private^hours.per.week=37-40] V [marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^hours.per.week=37-40^race=White^workclass=State-gov]
#
# pos_growset 3221 pos_pruneset 1587
# neg_growset 12336 neg_pruneset 6076
# grew rule: [marital.status=Married-civ-spouse^education.num=10-13^occupation=Exec-managerial^hours.per.week=50-75^fnlwgt=106812-131298]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^hours.per.week=37-40^race=White^workclass=State-gov] V [marital.status=Married-civ-spouse^education.num=10-13^occupation=Exec-managerial^hours.per.week=50-75^fnlwgt=106812-131298]
# pos_growset 3211 pos_pruneset 1583
# neg_growset 12336 neg_pruneset 6076
# grew rule: [marital.status=Married-civ-spouse^education.num=10-13^occupation=Exec-managerial^hours.per.week=40-50^workclass=Private^age=38-43]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=10-13^occupation=Exec-managerial^hours.per.week=50-75^fnlwgt=106812-131298] V [marital.status=Married-civ-spouse^education.num=10-13^occupation=Exec-managerial^hours.per.week=40-50^workclass=Private^age=38-43]
#
# pos_growset 3205 pos_pruneset 1580
# neg_growset 12336 neg_pruneset 6076
# grew rule: [marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^education=Prof-school^hours.per.week=40-50^age=38-43]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=10-13^occupation=Exec-managerial^hours.per.week=40-50^workclass=Private^age=38-43] V [marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^education=Prof-school^hours.per.week=40-50^age=38-43]
#
# pos_growset 3198 pos_pruneset 1576
# neg_growset 12336 neg_pruneset 6076
# grew rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^hours.per.week=40-50^occupation=Prof-specialty^relationship=Wife]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^education=Prof-school^hours.per.week=40-50^age=38-43] V [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^hours.per.week=40-50^occupation=Prof-specialty^relationship=Wife]
#
# pos_growset 3189 pos_pruneset 1572
# neg_growset 12335 neg_pruneset 6076
# grew rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Exec-managerial^age=48-55^workclass=Self-emp-not-inc^hours.per.week=37-40]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^hours.per.week=40-50^occupation=Prof-specialty^relationship=Wife] V [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Exec-managerial^age=48-55^workclass=Self-emp-not-inc^hours.per.week=37-40]
#
# pos_growset 3184 pos_pruneset 1569
# neg_growset 12335 neg_pruneset 6076
# grew rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^hours.per.week=40-50^age=43-48^occupation=Craft-repair]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Exec-managerial^age=48-55^workclass=Self-emp-not-inc^hours.per.week=37-40] V [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^hours.per.week=40-50^age=43-48^occupation=Craft-repair]
#
# pos_growset 3179 pos_pruneset 1567
# neg_growset 12335 neg_pruneset 6076
# grew rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Sales^relationship=Husband^age=34-38^native.country=United-States^race=White^fnlwgt=178686-197036]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^hours.per.week=40-50^age=43-48^occupation=Craft-repair] V [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Sales^relationship=Husband^age=34-38^native.country=United-States^race=White^fnlwgt=178686-197036]
#
# pos_growset 3175 pos_pruneset 1565
# neg_growset 12335 neg_pruneset 6076
# grew rule: [marital.status=Married-civ-spouse^education.num=10-13^occupation=Exec-managerial^age=55-68^workclass=Private]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Sales^relationship=Husband^age=34-38^native.country=United-States^race=White^fnlwgt=178686-197036] V [marital.status=Married-civ-spouse^education.num=10-13^occupation=Exec-managerial^age=55-68^workclass=Private]
#
# pos_growset 3165 pos_pruneset 1559
# neg_growset 12333 neg_pruneset 6075
# grew rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Sales^age=34-38^native.country=United-States^relationship=Husband^hours.per.week=37-40]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=10-13^occupation=Exec-managerial^age=55-68^workclass=Private] V [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Sales^age=34-38^native.country=United-States^relationship=Husband^hours.per.week=37-40]
#
# pos_growset 3159 pos_pruneset 1556
# neg_growset 12332 neg_pruneset 6074
# grew rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Exec-managerial^hours.per.week=37-40^fnlwgt=197036-220187^workclass=Private]
# pruned rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Exec-managerial^hours.per.week=37-40^fnlwgt=197036-220187]
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Sales^age=34-38^native.country=United-States^relationship=Husband^hours.per.week=37-40] V [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Exec-managerial^hours.per.week=37-40^fnlwgt=197036-220187]
#
# pos_growset 3151 pos_pruneset 1552
# neg_growset 12330 neg_pruneset 6074
# grew rule: [marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^hours.per.week=37-40^age=38-43^native.country=United-States^education=Masters]
# pruned rule: [marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^hours.per.week=37-40]
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^occupation=Exec-managerial^hours.per.week=37-40^fnlwgt=197036-220187] V [marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^hours.per.week=37-40]
#
# pos_growset 3055 pos_pruneset 1505
# neg_growset 12303 neg_pruneset 6061
# grew rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^hours.per.week=40-50^native.country=United-States^fnlwgt=197036-220187^occupation=Prof-specialty]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^hours.per.week=37-40] V [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^hours.per.week=40-50^native.country=United-States^fnlwgt=197036-220187^occupation=Prof-specialty]
#
# pos_growset 3048 pos_pruneset 1502
# neg_growset 12303 neg_pruneset 6060
# grew rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^hours.per.week=37-40^relationship=Husband^age=43-48^workclass=State-gov]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^hours.per.week=40-50^native.country=United-States^fnlwgt=197036-220187^occupation=Prof-specialty] V [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^hours.per.week=37-40^relationship=Husband^age=43-48^workclass=State-gov]
#
# pos_growset 3044 pos_pruneset 1500
# neg_growset 12303 neg_pruneset 6060
# grew rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^age=48-55^hours.per.week=50-75^occupation=Exec-managerial]
# pruned rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors]
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^hours.per.week=37-40^relationship=Husband^age=43-48^workclass=State-gov] V [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors]
#
# pos_growset 2517 pos_pruneset 1240
# neg_growset 11894 neg_pruneset 5859
# grew rule: [marital.status=Married-civ-spouse^capital.gain=(0^0)^hours.per.week=40-50^education.num=10-13^workclass=Private]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors] V [marital.status=Married-civ-spouse^capital.gain=(0^0)^hours.per.week=40-50^education.num=10-13^workclass=Private]
#
# pos_growset 2503 pos_pruneset 1233
# neg_growset 11894 neg_pruneset 5859
# grew rule: [marital.status=Married-civ-spouse^capital.gain=(0^0)^education=Some-college^occupation=Exec-managerial^hours.per.week=40-50]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^capital.gain=(0^0)^hours.per.week=40-50^education.num=10-13^workclass=Private] V [marital.status=Married-civ-spouse^capital.gain=(0^0)^education=Some-college^occupation=Exec-managerial^hours.per.week=40-50]
#
# pos_growset 2491 pos_pruneset 1228
# neg_growset 11893 neg_pruneset 5859
# grew rule: [marital.status=Married-civ-spouse^education.num=(13^9)^age=48-55^education=Masters^fnlwgt=106812-131298]
# pruned rule: [marital.status=Married-civ-spouse^education.num=(13^9)^age=48-55]
# updated ruleset: ...[marital.status=Married-civ-spouse^capital.gain=(0^0)^education=Some-college^occupation=Exec-managerial^hours.per.week=40-50] V [marital.status=Married-civ-spouse^education.num=(13^9)^age=48-55]
# pos_growset 2449 pos_pruneset 1207
# neg_growset 11881 neg_pruneset 5852
# grew rule: [marital.status=Married-civ-spouse^capital.gain=(0^0)^education=Some-college^hours.per.week=40-50^occupation=Craft-repair^native.country=United-States]
# pruned rule: [marital.status=Married-civ-spouse^capital.gain=(0^0)^education=Some-college]
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=(13^9)^age=48-55] V [marital.status=Married-civ-spouse^capital.gain=(0^0)^education=Some-college]
#
# pos_growset 2353 pos_pruneset 1159
# neg_growset 11838 neg_pruneset 5832
# grew rule: [marital.status=Married-civ-spouse^occupation=Exec-managerial^age=48-55^capital.gain=(0^0)]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^capital.gain=(0^0)^education=Some-college] V [marital.status=Married-civ-spouse^occupation=Exec-managerial^age=48-55^capital.gain=(0^0)]
#
# pos_growset 2343 pos_pruneset 1155
# neg_growset 11838 neg_pruneset 5831
# grew rule: [marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^education=Prof-school^workclass=Self-emp-inc]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^occupation=Exec-managerial^age=48-55^capital.gain=(0^0)] V [marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^education=Prof-school^workclass=Self-emp-inc]
#
# pos_growset 2336 pos_pruneset 1152
# neg_growset 11838 neg_pruneset 5831
# grew rule: [marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^fnlwgt=106812-131298^capital.gain=0-0^education=Masters]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^education=Prof-school^workclass=Self-emp-inc] V [marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^fnlwgt=106812-131298^capital.gain=0-0^education=Masters]
#
# pos_growset 2330 pos_pruneset 1148
# neg_growset 11838 neg_pruneset 5831
# grew rule: [marital.status=Married-civ-spouse^occupation=Exec-managerial^capital.loss=(2559^0)^education=HS-grad]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^occupation=Prof-specialty^education.num=(13^9)^fnlwgt=106812-131298^capital.gain=0-0^education=Masters] V [marital.status=Married-civ-spouse^occupation=Exec-managerial^capital.loss=(2559^0)^education=HS-grad]
#
# pos_growset 2316 pos_pruneset 1141
# neg_growset 11836 neg_pruneset 5831
# grew rule: [marital.status=Married-civ-spouse^education.num=(13^9)^education=Doctorate^hours.per.week=50-75^workclass=Private]
# pruned rule: [marital.status=Married-civ-spouse^education.num=(13^9)^education=Doctorate]
# updated ruleset: ...[marital.status=Married-civ-spouse^occupation=Exec-managerial^capital.loss=(2559^0)^education=HS-grad] V [marital.status=Married-civ-spouse^education.num=(13^9)^education=Doctorate]
#
# pos_growset 2274 pos_pruneset 1121
# neg_growset 11823 neg_pruneset 5824
# grew rule: [marital.status=Married-civ-spouse^occupation=Exec-managerial^education.num=10-13^age=48-55^workclass=Private]
# pruned rule: [marital.status=Married-civ-spouse^occupation=Exec-managerial^education.num=10-13]
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=(13^9)^education=Doctorate] V [marital.status=Married-civ-spouse^occupation=Exec-managerial^education.num=10-13]
#
# pos_growset 2230 pos_pruneset 1099
# neg_growset 11798 neg_pruneset 5811
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^age=48-55^hours.per.week=40-50]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^occupation=Exec-managerial^education.num=10-13] V [marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^age=48-55^hours.per.week=40-50]
#
# pos_growset 2223 pos_pruneset 1095
# neg_growset 11796 neg_pruneset 5811
# grew rule: [marital.status=Married-civ-spouse^hours.per.week=40-50^occupation=Prof-specialty^education.num=(13^9)^workclass=Private^age=38-43^native.country=United-States]
# pruned rule: [marital.status=Married-civ-spouse^hours.per.week=40-50^occupation=Prof-specialty^education.num=(13^9)]
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^age=48-55^hours.per.week=40-50] V [marital.status=Married-civ-spouse^hours.per.week=40-50^occupation=Prof-specialty^education.num=(13^9)]
#
# pos_growset 2190 pos_pruneset 1080
# neg_growset 11781 neg_pruneset 5803
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^age=43-48^hours.per.week=50-75^fnlwgt=220187-260617]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^hours.per.week=40-50^occupation=Prof-specialty^education.num=(13^9)] V [marital.status=Married-civ-spouse^education=Some-college^age=43-48^hours.per.week=50-75^fnlwgt=220187-260617]
#
# pos_growset 2187 pos_pruneset 1078
# neg_growset 11781 neg_pruneset 5803
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^workclass=Federal-gov^race=White]
# pruned rule: [marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^workclass=Federal-gov]
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^age=43-48^hours.per.week=50-75^fnlwgt=220187-260617] V [marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^workclass=Federal-gov]
#
# pos_growset 2179 pos_pruneset 1074
# neg_growset 11779 neg_pruneset 5802
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^workclass=Private^fnlwgt=220187-260617]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^workclass=Federal-gov] V [marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^workclass=Private^fnlwgt=220187-260617]
#
# pos_growset 2173 pos_pruneset 1071
# neg_growset 11777 neg_pruneset 5802
# grew rule: [marital.status=Married-civ-spouse^capital.gain=(0^0)^native.country=United-States^occupation=Prof-specialty^workclass=Private]
# pruned rule: [marital.status=Married-civ-spouse^capital.gain=(0^0)^native.country=United-States^occupation=Prof-specialty]
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^workclass=Private^fnlwgt=220187-260617] V [marital.status=Married-civ-spouse^capital.gain=(0^0)^native.country=United-States^occupation=Prof-specialty]
#
# pos_growset 2159 pos_pruneset 1064
# neg_growset 11773 neg_pruneset 5800
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^age=48-55^workclass=Private^fnlwgt=260617-328610]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^capital.gain=(0^0)^native.country=United-States^occupation=Prof-specialty] V [marital.status=Married-civ-spouse^education=Some-college^age=48-55^workclass=Private^fnlwgt=260617-328610]
#
# pos_growset 2150 pos_pruneset 1060
# neg_growset 11772 neg_pruneset 5799
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^workclass=Self-emp-inc^relationship=Husband^age=48-55]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^age=48-55^workclass=Private^fnlwgt=260617-328610] V [marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^workclass=Self-emp-inc^relationship=Husband^age=48-55]
#
# pos_growset 2148 pos_pruneset 1058
# neg_growset 11772 neg_pruneset 5799
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^age=43-48^race=White^relationship=Husband^workclass=Self-emp-not-inc]
# pruned rule: [marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^age=43-48]
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^workclass=Self-emp-inc^relationship=Husband^age=48-55] V [marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^age=43-48]
#
# pos_growset 2129 pos_pruneset 1050
# neg_growset 11759 neg_pruneset 5793
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^age=43-48^hours.per.week=40-50^workclass=Private^fnlwgt=260617-328610]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^age=43-48] V [marital.status=Married-civ-spouse^education=Some-college^age=43-48^hours.per.week=40-50^workclass=Private^fnlwgt=260617-328610]
#
# pos_growset 2128 pos_pruneset 1049
# neg_growset 11759 neg_pruneset 5792
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^age=43-48^hours.per.week=40-50^fnlwgt=158948-178686^occupation=Transport-moving]
# pruned rule: [marital.status=Married-civ-spouse^education=Some-college^age=43-48^hours.per.week=40-50^fnlwgt=158948-178686]
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^age=43-48^hours.per.week=40-50^workclass=Private^fnlwgt=260617-328610] V [marital.status=Married-civ-spouse^education=Some-college^age=43-48^hours.per.week=40-50^fnlwgt=158948-178686]
# pos_growset 2125 pos_pruneset 1047
# neg_growset 11758 neg_pruneset 5792
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^workclass=Private^age=38-43^hours.per.week=37-40]
# pruned rule: [marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^workclass=Private^age=38-43]
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^age=43-48^hours.per.week=40-50^fnlwgt=158948-178686] V [marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^workclass=Private^age=38-43]
#
# pos_growset 2115 pos_pruneset 1043
# neg_growset 11754 neg_pruneset 5790
# grew rule: [marital.status=Married-civ-spouse^capital.gain=(0^0)^hours.per.week=40-50^education=HS-grad^workclass=Private^age=48-55]
# pruned rule: [marital.status=Married-civ-spouse^capital.gain=(0^0)^hours.per.week=40-50^education=HS-grad]
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^workclass=Private^age=38-43] V [marital.status=Married-civ-spouse^capital.gain=(0^0)^hours.per.week=40-50^education=HS-grad]
#
# pos_growset 2087 pos_pruneset 1028
# neg_growset 11743 neg_pruneset 5785
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^fnlwgt=(328610^162667)^age=38-43^occupation=Adm-clerical]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^capital.gain=(0^0)^hours.per.week=40-50^education=HS-grad] V [marital.status=Married-civ-spouse^education=Some-college^fnlwgt=(328610^162667)^age=38-43^occupation=Adm-clerical]
#
# pos_growset 2083 pos_pruneset 1027
# neg_growset 11742 neg_pruneset 5784
# grew rule: [marital.status=Married-civ-spouse^capital.gain=(0^0)^age=48-55^native.country=United-States^education=HS-grad^workclass=Private^race=White^hours.per.week=37-40]
# pruned rule: [marital.status=Married-civ-spouse^capital.gain=(0^0)^age=48-55^native.country=United-States^education=HS-grad^workclass=Private^race=White]
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^fnlwgt=(328610^162667)^age=38-43^occupation=Adm-clerical] V [marital.status=Married-civ-spouse^capital.gain=(0^0)^age=48-55^native.country=United-States^education=HS-grad^workclass=Private^race=White]
#
# pos_growset 2072 pos_pruneset 1021
# neg_growset 11739 neg_pruneset 5783
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^capital.loss=(2559^0)^age=43-48^occupation=Craft-repair]
# pruned rule: [marital.status=Married-civ-spouse^education=Some-college^capital.loss=(2559^0)^age=43-48]
# updated ruleset: ...[marital.status=Married-civ-spouse^capital.gain=(0^0)^age=48-55^native.country=United-States^education=HS-grad^workclass=Private^race=White] V [marital.status=Married-civ-spouse^education=Some-college^capital.loss=(2559^0)^age=43-48]
#
# pos_growset 2062 pos_pruneset 1017
# neg_growset 11737 neg_pruneset 5782
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^age=30-34^fnlwgt=(328610^162667)]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^capital.loss=(2559^0)^age=43-48] V [marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^age=30-34^fnlwgt=(328610^162667)]
#
# pos_growset 2058 pos_pruneset 1015
# neg_growset 11736 neg_pruneset 5781
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^occupation=Sales^age=38-43^hours.per.week=40-50^fnlwgt=175360-65991]
# pruned rule: [marital.status=Married-civ-spouse^education=Some-college^occupation=Sales^age=38-43^hours.per.week=40-50]
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^age=30-34^fnlwgt=(328610^162667)] V [marital.status=Married-civ-spouse^education=Some-college^occupation=Sales^age=38-43^hours.per.week=40-50]
#
# pos_growset 2052 pos_pruneset 1011
# neg_growset 11735 neg_pruneset 5781
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^fnlwgt=(328610^162667)^age=43-48^occupation=Sales]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^occupation=Sales^age=38-43^hours.per.week=40-50] V [marital.status=Married-civ-spouse^education=Some-college^fnlwgt=(328610^162667)^age=43-48^occupation=Sales]
#
# pos_growset 2048 pos_pruneset 1010
# neg_growset 11735 neg_pruneset 5781
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^age=48-55^workclass=Self-emp-inc^fnlwgt=65991-106812]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^fnlwgt=(328610^162667)^age=43-48^occupation=Sales] V [marital.status=Married-civ-spouse^education=Some-college^age=48-55^workclass=Self-emp-inc^fnlwgt=65991-106812]
#
# pos_growset 2046 pos_pruneset 1009
# neg_growset 11735 neg_pruneset 5781
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^fnlwgt=220187-260617^occupation=Craft-repair^workclass=Private^age=38-43]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^age=48-55^workclass=Self-emp-inc^fnlwgt=65991-106812] V [marital.status=Married-civ-spouse^education=Some-college^fnlwgt=220187-260617^occupation=Craft-repair^workclass=Private^age=38-43]
#
# pos_growset 2042 pos_pruneset 1007
# neg_growset 11735 neg_pruneset 5781
# grew rule: [marital.status=Married-civ-spouse^occupation=Sales^education=Masters^native.country=United-States^age=34-38]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^fnlwgt=220187-260617^occupation=Craft-repair^workclass=Private^age=38-43] V [marital.status=Married-civ-spouse^occupation=Sales^education=Masters^native.country=United-States^age=34-38]
#
# pos_growset 2038 pos_pruneset 1004
# neg_growset 11735 neg_pruneset 5781
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^age=48-55^workclass=Private^fnlwgt=158948-178686^hours.per.week=37-40]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^occupation=Sales^education=Masters^native.country=United-States^age=34-38] V [marital.status=Married-civ-spouse^education=Some-college^age=48-55^workclass=Private^fnlwgt=158948-178686^hours.per.week=37-40]
#
# pos_growset 2033 pos_pruneset 1002
# neg_growset 11735 neg_pruneset 5780
# grew rule: [marital.status=Married-civ-spouse^age=43-48^occupation=Sales^native.country=United-States^fnlwgt=178686-197036^hours.per.week=40-50]
# pruned rule: [marital.status=Married-civ-spouse^age=43-48^occupation=Sales^native.country=United-States^fnlwgt=178686-197036]
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^age=48-55^workclass=Private^fnlwgt=158948-178686^hours.per.week=37-40] V [marital.status=Married-civ-spouse^age=43-48^occupation=Sales^native.country=United-States^fnlwgt=178686-197036]
#
# pos_growset 2026 pos_pruneset 999
# neg_growset 11734 neg_pruneset 5780
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^fnlwgt=178686-197036^hours.per.week=37-40^occupation=Protective-serv]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^age=43-48^occupation=Sales^native.country=United-States^fnlwgt=178686-197036] V [marital.status=Married-civ-spouse^education=Some-college^fnlwgt=178686-197036^hours.per.week=37-40^occupation=Protective-serv]
#
# pos_growset 2022 pos_pruneset 997
# neg_growset 11734 neg_pruneset 5780
# grew rule: [marital.status=Married-civ-spouse^occupation=Prof-specialty^age=34-38^education.num=(13^9)^education=Prof-school^fnlwgt=178686-197036]
# pruned rule: [marital.status=Married-civ-spouse^occupation=Prof-specialty^age=34-38^education.num=(13^9)^education=Prof-school]
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^fnlwgt=178686-197036^hours.per.week=37-40^occupation=Protective-serv] V [marital.status=Married-civ-spouse^occupation=Prof-specialty^age=34-38^education.num=(13^9)^education=Prof-school]
#
# pos_growset 2017 pos_pruneset 994
# neg_growset 11733 neg_pruneset 5780
# grew rule: [marital.status=Married-civ-spouse^age=43-48^native.country=United-States^workclass=Federal-gov^education=Assoc-acdm]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^occupation=Prof-specialty^age=34-38^education.num=(13^9)^education=Prof-school] V [marital.status=Married-civ-spouse^age=43-48^native.country=United-States^workclass=Federal-gov^education=Assoc-acdm]
#
# pos_growset 2015 pos_pruneset 993
# neg_growset 11733 neg_pruneset 5780
# grew rule: [marital.status=Married-civ-spouse^age=43-48^native.country=United-States^workclass=Federal-gov^hours.per.week=37-40^occupation=Adm-clerical^capital.loss=2559-0]
# pruned rule: [marital.status=Married-civ-spouse^age=43-48^native.country=United-States^workclass=Federal-gov^hours.per.week=37-40^occupation=Adm-clerical]
# updated ruleset: ...[marital.status=Married-civ-spouse^age=43-48^native.country=United-States^workclass=Federal-gov^education=Assoc-acdm] V [marital.status=Married-civ-spouse^age=43-48^native.country=United-States^workclass=Federal-gov^hours.per.week=37-40^occupation=Adm-clerical]
#
# pos_growset 2009 pos_pruneset 990
# neg_growset 11732 neg_pruneset 5779
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^age=55-68^fnlwgt=178686-197036^workclass=Self-emp-inc]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^age=43-48^native.country=United-States^workclass=Federal-gov^hours.per.week=37-40^occupation=Adm-clerical] V [marital.status=Married-civ-spouse^education=Some-college^age=55-68^fnlwgt=178686-197036^workclass=Self-emp-inc]
#
# pos_growset 2006 pos_pruneset 989
# neg_growset 11732 neg_pruneset 5779
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^occupation=Tech-support^hours.per.week=50-75]
# pruned rule: [marital.status=Married-civ-spouse^education=Some-college^occupation=Tech-support]
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^age=55-68^fnlwgt=178686-197036^workclass=Self-emp-inc] V [marital.status=Married-civ-spouse^education=Some-college^occupation=Tech-support]
#
# pos_growset 1980 pos_pruneset 976
# neg_growset 11712 neg_pruneset 5769
# grew rule: [marital.status=Married-civ-spouse^occupation=Prof-specialty^education=Prof-school^age=30-34]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^occupation=Tech-support] V [marital.status=Married-civ-spouse^occupation=Prof-specialty^education=Prof-school^age=30-34]
#
# pos_growset 1975 pos_pruneset 973
# neg_growset 11712 neg_pruneset 5769
# grew rule: [marital.status=Married-civ-spouse^hours.per.week=40-50^age=34-38^occupation=Exec-managerial^fnlwgt=178686-197036]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^occupation=Prof-specialty^education=Prof-school^age=30-34] V [marital.status=Married-civ-spouse^hours.per.week=40-50^age=34-38^occupation=Exec-managerial^fnlwgt=178686-197036]
#
# pos_growset 1973 pos_pruneset 972
# neg_growset 11712 neg_pruneset 5769
# grew rule: [marital.status=Married-civ-spouse^hours.per.week=40-50^education=Some-college^fnlwgt=(328610^162667)^occupation=Sales]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^hours.per.week=40-50^age=34-38^occupation=Exec-managerial^fnlwgt=178686-197036] V [marital.status=Married-civ-spouse^hours.per.week=40-50^education=Some-college^fnlwgt=(328610^162667)^occupation=Sales]
#
# pos_growset 1969 pos_pruneset 971
# neg_growset 11710 neg_pruneset 5768
# grew rule: [marital.status=Married-civ-spouse^occupation=Sales^workclass=Self-emp-inc^age=55-68^education=HS-grad]
# pruned rule: [marital.status=Married-civ-spouse^occupation=Sales^workclass=Self-emp-inc^age=55-68]
# updated ruleset: ...[marital.status=Married-civ-spouse^hours.per.week=40-50^education=Some-college^fnlwgt=(328610^162667)^occupation=Sales] V [marital.status=Married-civ-spouse^occupation=Sales^workclass=Self-emp-inc^age=55-68]
#
# pos_growset 1961 pos_pruneset 966
# neg_growset 11706 neg_pruneset 5766
# grew rule: [marital.status=Married-civ-spouse^capital.loss=(2559^0)^workclass=Self-emp-inc^hours.per.week=50-75]
# pruned rule: [marital.status=Married-civ-spouse^capital.loss=(2559^0)^workclass=Self-emp-inc]
# updated ruleset: ...[marital.status=Married-civ-spouse^occupation=Sales^workclass=Self-emp-inc^age=55-68] V [marital.status=Married-civ-spouse^capital.loss=(2559^0)^workclass=Self-emp-inc]
#
# pos_growset 1951 pos_pruneset 962
# neg_growset 11702 neg_pruneset 5764
# grew rule: [marital.status=Married-civ-spouse^occupation=Exec-managerial^workclass=Private^education=HS-grad^age=38-43^hours.per.week=40-50]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^capital.loss=(2559^0)^workclass=Self-emp-inc] V [marital.status=Married-civ-spouse^occupation=Exec-managerial^workclass=Private^education=HS-grad^age=38-43^hours.per.week=40-50]
#
# pos_growset 1948 pos_pruneset 960
# neg_growset 11702 neg_pruneset 5764
# grew rule: [marital.status=Married-civ-spouse^capital.gain=(0^0)^age=43-48^hours.per.week=37-40^fnlwgt=197036-220187]
# pruned rule: [marital.status=Married-civ-spouse^capital.gain=(0^0)^age=43-48^hours.per.week=37-40]
# updated ruleset: ...[marital.status=Married-civ-spouse^occupation=Exec-managerial^workclass=Private^education=HS-grad^age=38-43^hours.per.week=40-50] V [marital.status=Married-civ-spouse^capital.gain=(0^0)^age=43-48^hours.per.week=37-40]
#
# pos_growset 1932 pos_pruneset 953
# neg_growset 11696 neg_pruneset 5761
# grew rule: [marital.status=Married-civ-spouse^occupation=Prof-specialty^age=34-38^education=Assoc-acdm]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^capital.gain=(0^0)^age=43-48^hours.per.week=37-40] V [marital.status=Married-civ-spouse^occupation=Prof-specialty^age=34-38^education=Assoc-acdm]
#
# pos_growset 1927 pos_pruneset 950
# neg_growset 11694 neg_pruneset 5761
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^fnlwgt=220187-260617^workclass=Self-emp-inc]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^occupation=Prof-specialty^age=34-38^education=Assoc-acdm] V [marital.status=Married-civ-spouse^education=Some-college^fnlwgt=220187-260617^workclass=Self-emp-inc]
#
# pos_growset 1922 pos_pruneset 948
# neg_growset 11694 neg_pruneset 5760
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^occupation=Sales^hours.per.week=50-75^race=White^age=34-38^workclass=Self-emp-inc]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^fnlwgt=220187-260617^workclass=Self-emp-inc] V [marital.status=Married-civ-spouse^education=Some-college^occupation=Sales^hours.per.week=50-75^race=White^age=34-38^workclass=Self-emp-inc]
#
# pos_growset 1920 pos_pruneset 947
# neg_growset 11694 neg_pruneset 5760
# grew rule: [marital.status=Married-civ-spouse^occupation=Prof-specialty^age=34-38^hours.per.week=40-50]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^occupation=Sales^hours.per.week=50-75^race=White^age=34-38^workclass=Self-emp-inc] V [marital.status=Married-civ-spouse^occupation=Prof-specialty^age=34-38^hours.per.week=40-50]
#
# pos_growset 1917 pos_pruneset 945
# neg_growset 11693 neg_pruneset 5760
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^workclass=Private^age=34-38^race=White^hours.per.week=50-75]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^occupation=Prof-specialty^age=34-38^hours.per.week=40-50] V [marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^workclass=Private^age=34-38^race=White^hours.per.week=50-75]
#
# pos_growset 1914 pos_pruneset 944
# neg_growset 11692 neg_pruneset 5760
# grew rule: [marital.status=Married-civ-spouse^occupation=Prof-specialty^hours.per.week=25-37^relationship=Husband^age=38-43]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^occupation=Exec-managerial^workclass=Private^age=34-38^race=White^hours.per.week=50-75] V [marital.status=Married-civ-spouse^occupation=Prof-specialty^hours.per.week=25-37^relationship=Husband^age=38-43]
#
# pos_growset 1912 pos_pruneset 942
# neg_growset 11692 neg_pruneset 5760
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^occupation=Prof-specialty^fnlwgt=(328610^162667)]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^occupation=Prof-specialty^hours.per.week=25-37^relationship=Husband^age=38-43] V [marital.status=Married-civ-spouse^education=Some-college^occupation=Prof-specialty^fnlwgt=(328610^162667)]
#
# pos_growset 1905 pos_pruneset 939
# neg_growset 11690 neg_pruneset 5759
# grew rule: [marital.status=Married-civ-spouse^education=Some-college^age=43-48^fnlwgt=106812-131298^relationship=Husband]
# pruned rule: [marital.status=Married-civ-spouse^education=Some-college^age=43-48^fnlwgt=106812-131298]
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^occupation=Prof-specialty^fnlwgt=(328610^162667)] V [marital.status=Married-civ-spouse^education=Some-college^age=43-48^fnlwgt=106812-131298]
#
# pos_growset 1898 pos_pruneset 936
# neg_growset 11688 neg_pruneset 5757
# grew rule: [marital.status=Married-civ-spouse^education.num=10-13^age=48-55^hours.per.week=40-50^education=Assoc-voc^occupation=Craft-repair]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Some-college^age=43-48^fnlwgt=106812-131298] V [marital.status=Married-civ-spouse^education.num=10-13^age=48-55^hours.per.week=40-50^education=Assoc-voc^occupation=Craft-repair]
#
# pos_growset 1897 pos_pruneset 935
# neg_growset 11688 neg_pruneset 5757
# grew rule: [marital.status=Married-civ-spouse^age=48-55^education.num=7-9^race=White^workclass=Private^fnlwgt=131298-158948^hours.per.week=50-75]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=10-13^age=48-55^hours.per.week=40-50^education=Assoc-voc^occupation=Craft-repair] V [marital.status=Married-civ-spouse^age=48-55^education.num=7-9^race=White^workclass=Private^fnlwgt=131298-158948^hours.per.week=50-75]
#
# pos_growset 1894 pos_pruneset 934
# neg_growset 11686 neg_pruneset 5757
# grew rule: [marital.status=Married-civ-spouse^occupation=Exec-managerial^workclass=Private^age=48-55^capital.loss=2559-0^fnlwgt=65991-106812]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^age=48-55^education.num=7-9^race=White^workclass=Private^fnlwgt=131298-158948^hours.per.week=50-75] V [marital.status=Married-civ-spouse^occupation=Exec-managerial^workclass=Private^age=48-55^capital.loss=2559-0^fnlwgt=65991-106812]
#
#
# GREW INITIAL RULESET:
# [[marital.status=Married-civ-spouse ^ education.num=(13 ^ 9) ^ capital.gain=(0 ^ 0) ^ hours.per.week=50-75] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors ^ capital.gain=(0 ^ 0) ^ fnlwgt=(328610 ^ 162667)] V
# [marital.status=Married-civ-spouse ^ education=Bachelors ^ occupation=Exec-managerial ^ hours.per.week=40-50 ^ capital.loss=(2559 ^ 0)] V
# [marital.status=Married-civ-spouse ^ education=Bachelors ^ capital.gain=(0 ^ 0)] V
# [marital.status=Married-civ-spouse ^ education.num=(13 ^ 9) ^ capital.gain=(0 ^ 0) ^ hours.per.week=40-50 ^ occupation=Prof-specialty] V
# [marital.status=Married-civ-spouse ^ education.num=(13 ^ 9) ^ capital.loss=(2559 ^ 0)] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors ^ occupation=Exec-managerial ^ workclass=Private ^ age=43-48] V
# [marital.status=Married-civ-spouse ^ education.num=(13 ^ 9) ^ capital.gain=(0 ^ 0) ^ occupation=Prof-specialty ^ hours.per.week=25-37] V
# [marital.status=Married-civ-spouse ^ education.num=(13 ^ 9) ^ occupation=Exec-managerial] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors ^ occupation=Exec-managerial ^ workclass=Private ^ hours.per.week=40-50] V
# [marital.status=Married-civ-spouse ^ occupation=Prof-specialty ^ education.num=(13 ^ 9) ^ age=43-48 ^ education=Prof-school] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors ^ hours.per.week=40-50 ^ capital.loss=(2559 ^ 0)] V
# [marital.status=Married-civ-spouse ^ occupation=Prof-specialty ^ education.num=(13 ^ 9) ^ hours.per.week=37-40 ^ workclass=Private ^ native.country=United-States ^ fnlwgt=131298-158948] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors ^ capital.loss=(2559 ^ 0) ^ workclass=Private ^ hours.per.week=37-40] V
# [marital.status=Married-civ-spouse ^ occupation=Prof-specialty ^ education.num=(13 ^ 9) ^ hours.per.week=37-40 ^ race=White ^ workclass=State-gov] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ occupation=Exec-managerial ^ hours.per.week=50-75 ^ fnlwgt=106812-131298] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ occupation=Exec-managerial ^ hours.per.week=40-50 ^ workclass=Private ^ age=38-43] V
# ...
# [marital.status=Married-civ-spouse ^ occupation=Prof-specialty ^ age=34-38 ^ hours.per.week=40-50] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ occupation=Exec-managerial ^ workclass=Private ^ age=34-38 ^ race=White ^ hours.per.week=50-75] V
# [marital.status=Married-civ-spouse ^ occupation=Prof-specialty ^ hours.per.week=25-37 ^ relationship=Husband ^ age=38-43] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ occupation=Prof-specialty ^ fnlwgt=(328610 ^ 162667)] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ age=43-48 ^ fnlwgt=106812-131298] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ age=48-55 ^ hours.per.week=40-50 ^ education=Assoc-voc ^ occupation=Craft-repair] V
# [marital.status=Married-civ-spouse ^ age=48-55 ^ education.num=7-9 ^ race=White ^ workclass=Private ^ fnlwgt=131298-158948 ^ hours.per.week=50-75] V
# [marital.status=Married-civ-spouse ^ occupation=Exec-managerial ^ workclass=Private ^ age=48-55 ^ capital.loss=2559-0 ^ fnlwgt=65991-106812]]
#
# No changes were made. Halting optimization.
# 5897 pos left. Growing final rules...
# growing ruleset...
#
# pos_growset 3950 pos_pruneset 1947
# neg_growset 12410 neg_pruneset 6113
# grew rule: [marital.status=Married-civ-spouse^education.num=(13^9)^capital.gain=(0^0)^hours.per.week=50-75]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^occupation=Exec-managerial^workclass=Private^age=48-55^capital.loss=2559-0^fnlwgt=65991-106812] V [marital.status=Married-civ-spouse^education.num=(13^9)^capital.gain=(0^0)^hours.per.week=50-75]
# pos_growset 3898 pos_pruneset 1920
# neg_growset 12410 neg_pruneset 6113
# grew rule: [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^capital.gain=(0^0)^fnlwgt=(328610^162667)]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=(13^9)^capital.gain=(0^0)^hours.per.week=50-75] V [marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^capital.gain=(0^0)^fnlwgt=(328610^162667)]
#
# pos_growset 3876 pos_pruneset 1910
# neg_growset 12410 neg_pruneset 6113
# grew rule: [marital.status=Married-civ-spouse^education=Bachelors^occupation=Exec-managerial^hours.per.week=40-50^capital.loss=(2559^0)^workclass=Self-emp-inc]
# pruned rule: [marital.status=Married-civ-spouse^education=Bachelors^occupation=Exec-managerial^hours.per.week=40-50^capital.loss=(2559^0)]
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=10-13^education=Bachelors^capital.gain=(0^0)^fnlwgt=(328610^162667)] V [marital.status=Married-civ-spouse^education=Bachelors^occupation=Exec-managerial^hours.per.week=40-50^capital.loss=(2559^0)]
#
# pos_growset 3859 pos_pruneset 1902
# neg_growset 12409 neg_pruneset 6113
# grew rule: [marital.status=Married-civ-spouse^education=Bachelors^capital.gain=(0^0)^occupation=Exec-managerial^hours.per.week=50-75]
# pruned rule: [marital.status=Married-civ-spouse^education=Bachelors^capital.gain=(0^0)]
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Bachelors^occupation=Exec-managerial^hours.per.week=40-50^capital.loss=(2559^0)] V [marital.status=Married-civ-spouse^education=Bachelors^capital.gain=(0^0)]
#
# pos_growset 3674 pos_pruneset 1810
# neg_growset 12383 neg_pruneset 6100
# grew rule: [marital.status=Married-civ-spouse^education.num=(13^9)^capital.gain=(0^0)^hours.per.week=40-50^occupation=Prof-specialty]
# pruned rule unchanged
# updated ruleset: ...[marital.status=Married-civ-spouse^education=Bachelors^capital.gain=(0^0)] V [marital.status=Married-civ-spouse^education.num=(13^9)^capital.gain=(0^0)^hours.per.week=40-50^occupation=Prof-specialty]
#
# pos_growset 3638 pos_pruneset 1793
# neg_growset 12383 neg_pruneset 6100
# grew rule: [marital.status=Married-civ-spouse^education.num=(13^9)^capital.loss=(2559^0)^hours.per.week=40-50]
# pruned rule: [marital.status=Married-civ-spouse^education.num=(13^9)^capital.loss=(2559^0)]
# updated ruleset: ...[marital.status=Married-civ-spouse^education.num=(13^9)^capital.gain=(0^0)^hours.per.week=40-50^occupation=Prof-specialty] V [marital.status=Married-civ-spouse^education.num=(13^9)^capital.loss=(2559^0)]
#
# GREW FINAL RULES
# [[marital.status=Married-civ-spouse ^ education.num=(13 ^ 9) ^ capital.gain=(0 ^ 0) ^ hours.per.week=50-75] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors ^ capital.gain=(0 ^ 0) ^ fnlwgt=(328610 ^ 162667)] V
# [marital.status=Married-civ-spouse ^ education=Bachelors ^ occupation=Exec-managerial ^ hours.per.week=40-50 ^ capital.loss=(2559 ^ 0)] V
# [marital.status=Married-civ-spouse ^ education=Bachelors ^ capital.gain=(0 ^ 0)] V
# [marital.status=Married-civ-spouse ^ education.num=(13 ^ 9) ^ capital.gain=(0 ^ 0) ^ hours.per.week=40-50 ^ occupation=Prof-specialty] V
# [marital.status=Married-civ-spouse ^ education.num=(13 ^ 9) ^ capital.loss=(2559 ^ 0)] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors ^ occupation=Exec-managerial ^ workclass=Private ^ age=43-48] V
# [marital.status=Married-civ-spouse ^ education.num=(13 ^ 9) ^ capital.gain=(0 ^ 0) ^ occupation=Prof-specialty ^ hours.per.week=25-37] V
# [marital.status=Married-civ-spouse ^ education.num=(13 ^ 9) ^ occupation=Exec-managerial] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors ^ occupation=Exec-managerial ^ workclass=Private ^ hours.per.week=40-50] V
# [marital.status=Married-civ-spouse ^ occupation=Prof-specialty ^ education.num=(13 ^ 9) ^ age=43-48 ^ education=Prof-school] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors ^ hours.per.week=40-50 ^ capital.loss=(2559 ^ 0)] V
# [marital.status=Married-civ-spouse ^ occupation=Prof-specialty ^ education.num=(13 ^ 9) ^ hours.per.week=37-40 ^ workclass=Private ^ native.country=United-States ^ fnlwgt=131298-158948] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors ^ capital.loss=(2559 ^ 0) ^ workclass=Private ^ hours.per.week=37-40] V
# [marital.status=Married-civ-spouse ^ occupation=Prof-specialty ^ education.num=(13 ^ 9) ^ hours.per.week=37-40 ^ race=White ^ workclass=State-gov] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ occupation=Exec-managerial ^ hours.per.week=50-75 ^ fnlwgt=106812-131298] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ occupation=Exec-managerial ^ hours.per.week=40-50 ^ workclass=Private ^ age=38-43] V
# [marital.status=Married-civ-spouse ^ occupation=Prof-specialty ^ education.num=(13 ^ 9) ^ education=Prof-school ^ hours.per.week=40-50 ^ age=38-43] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors ^ hours.per.week=40-50 ^ occupation=Prof-specialty ^ relationship=Wife] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors ^ occupation=Exec-managerial ^ age=48-55 ^ workclass=Self-emp-not-inc ^ hours.per.week=37-40] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors ^ hours.per.week=40-50 ^ age=43-48 ^ occupation=Craft-repair] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors ^ occupation=Sales ^ relationship=Husband ^ age=34-38 ^ native.country=United-States ^ race=White ^ fnlwgt=178686-197036] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ occupation=Exec-managerial ^ age=55-68 ^ workclass=Private] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors ^ occupation=Sales ^ age=34-38 ^ native.country=United-States ^ relationship=Husband ^ hours.per.week=37-40] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors ^ occupation=Exec-managerial ^ hours.per.week=37-40 ^ fnlwgt=197036-220187] V
# [marital.status=Married-civ-spouse ^ occupation=Prof-specialty ^ education.num=(13 ^ 9) ^ hours.per.week=37-40] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors ^ hours.per.week=40-50 ^ native.country=United-States ^ fnlwgt=197036-220187 ^ occupation=Prof-specialty] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors ^ hours.per.week=37-40 ^ relationship=Husband ^ age=43-48 ^ workclass=State-gov] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors] V
# [marital.status=Married-civ-spouse ^ capital.gain=(0 ^ 0) ^ hours.per.week=40-50 ^ education.num=10-13 ^ workclass=Private] V
# [marital.status=Married-civ-spouse ^ capital.gain=(0 ^ 0) ^ education=Some-college ^ occupation=Exec-managerial ^ hours.per.week=40-50] V
# [marital.status=Married-civ-spouse ^ education.num=(13 ^ 9) ^ age=48-55] V
# [marital.status=Married-civ-spouse ^ capital.gain=(0 ^ 0) ^ education=Some-college] V
# [marital.status=Married-civ-spouse ^ occupation=Exec-managerial ^ age=48-55 ^ capital.gain=(0 ^ 0)] V
# [marital.status=Married-civ-spouse ^ occupation=Prof-specialty ^ education.num=(13 ^ 9) ^ education=Prof-school ^ workclass=Self-emp-inc] V
# [marital.status=Married-civ-spouse ^ occupation=Prof-specialty ^ education.num=(13 ^ 9) ^ fnlwgt=106812-131298 ^ capital.gain=0-0 ^ education=Masters] V
# [marital.status=Married-civ-spouse ^ occupation=Exec-managerial ^ capital.loss=(2559 ^ 0) ^ education=HS-grad] V
# [marital.status=Married-civ-spouse ^ education.num=(13 ^ 9) ^ education=Doctorate] V
# [marital.status=Married-civ-spouse ^ occupation=Exec-managerial ^ education.num=10-13] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ occupation=Exec-managerial ^ age=48-55 ^ hours.per.week=40-50] V
# [marital.status=Married-civ-spouse ^ hours.per.week=40-50 ^ occupation=Prof-specialty ^ education.num=(13 ^ 9)] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ age=43-48 ^ hours.per.week=50-75 ^ fnlwgt=220187-260617] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ occupation=Exec-managerial ^ workclass=Federal-gov] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ occupation=Exec-managerial ^ workclass=Private ^ fnlwgt=220187-260617] V
# [marital.status=Married-civ-spouse ^ capital.gain=(0 ^ 0) ^ native.country=United-States ^ occupation=Prof-specialty] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ age=48-55 ^ workclass=Private ^ fnlwgt=260617-328610] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ occupation=Exec-managerial ^ workclass=Self-emp-inc ^ relationship=Husband ^ age=48-55] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ occupation=Exec-managerial ^ age=43-48] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ age=43-48 ^ hours.per.week=40-50 ^ workclass=Private ^ fnlwgt=260617-328610] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ age=43-48 ^ hours.per.week=40-50 ^ fnlwgt=158948-178686] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ occupation=Exec-managerial ^ workclass=Private ^ age=38-43] V
# [marital.status=Married-civ-spouse ^ capital.gain=(0 ^ 0) ^ hours.per.week=40-50 ^ education=HS-grad] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ fnlwgt=(328610 ^ 162667) ^ age=38-43 ^ occupation=Adm-clerical] V
# [marital.status=Married-civ-spouse ^ capital.gain=(0 ^ 0) ^ age=48-55 ^ native.country=United-States ^ education=HS-grad ^ workclass=Private ^ race=White] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ capital.loss=(2559 ^ 0) ^ age=43-48] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ occupation=Exec-managerial ^ age=30-34 ^ fnlwgt=(328610 ^ 162667)] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ occupation=Sales ^ age=38-43 ^ hours.per.week=40-50] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ fnlwgt=(328610 ^ 162667) ^ age=43-48 ^ occupation=Sales] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ age=48-55 ^ workclass=Self-emp-inc ^ fnlwgt=65991-106812] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ fnlwgt=220187-260617 ^ occupation=Craft-repair ^ workclass=Private ^ age=38-43] V
# [marital.status=Married-civ-spouse ^ occupation=Sales ^ education=Masters ^ native.country=United-States ^ age=34-38] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ age=48-55 ^ workclass=Private ^ fnlwgt=158948-178686 ^ hours.per.week=37-40] V
# [marital.status=Married-civ-spouse ^ age=43-48 ^ occupation=Sales ^ native.country=United-States ^ fnlwgt=178686-197036] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ fnlwgt=178686-197036 ^ hours.per.week=37-40 ^ occupation=Protective-serv] V
# [marital.status=Married-civ-spouse ^ occupation=Prof-specialty ^ age=34-38 ^ education.num=(13 ^ 9) ^ education=Prof-school] V
# [marital.status=Married-civ-spouse ^ age=43-48 ^ native.country=United-States ^ workclass=Federal-gov ^ education=Assoc-acdm] V
# [marital.status=Married-civ-spouse ^ age=43-48 ^ native.country=United-States ^ workclass=Federal-gov ^ hours.per.week=37-40 ^ occupation=Adm-clerical] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ age=55-68 ^ fnlwgt=178686-197036 ^ workclass=Self-emp-inc] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ occupation=Tech-support] V
# [marital.status=Married-civ-spouse ^ occupation=Prof-specialty ^ education=Prof-school ^ age=30-34] V
# [marital.status=Married-civ-spouse ^ hours.per.week=40-50 ^ age=34-38 ^ occupation=Exec-managerial ^ fnlwgt=178686-197036] V
# [marital.status=Married-civ-spouse ^ hours.per.week=40-50 ^ education=Some-college ^ fnlwgt=(328610 ^ 162667) ^ occupation=Sales] V
# [marital.status=Married-civ-spouse ^ occupation=Sales ^ workclass=Self-emp-inc ^ age=55-68] V
# [marital.status=Married-civ-spouse ^ capital.loss=(2559 ^ 0) ^ workclass=Self-emp-inc] V
# [marital.status=Married-civ-spouse ^ occupation=Exec-managerial ^ workclass=Private ^ education=HS-grad ^ age=38-43 ^ hours.per.week=40-50] V
# [marital.status=Married-civ-spouse ^ capital.gain=(0 ^ 0) ^ age=43-48 ^ hours.per.week=37-40] V
# [marital.status=Married-civ-spouse ^ occupation=Prof-specialty ^ age=34-38 ^ education=Assoc-acdm] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ fnlwgt=220187-260617 ^ workclass=Self-emp-inc] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ occupation=Sales ^ hours.per.week=50-75 ^ race=White ^ age=34-38 ^ workclass=Self-emp-inc] V
# [marital.status=Married-civ-spouse ^ occupation=Prof-specialty ^ age=34-38 ^ hours.per.week=40-50] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ occupation=Exec-managerial ^ workclass=Private ^ age=34-38 ^ race=White ^ hours.per.week=50-75] V
# [marital.status=Married-civ-spouse ^ occupation=Prof-specialty ^ hours.per.week=25-37 ^ relationship=Husband ^ age=38-43] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ occupation=Prof-specialty ^ fnlwgt=(328610 ^ 162667)] V
# [marital.status=Married-civ-spouse ^ education=Some-college ^ age=43-48 ^ fnlwgt=106812-131298] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ age=48-55 ^ hours.per.week=40-50 ^ education=Assoc-voc ^ occupation=Craft-repair] V
# [marital.status=Married-civ-spouse ^ age=48-55 ^ education.num=7-9 ^ race=White ^ workclass=Private ^ fnlwgt=131298-158948 ^ hours.per.week=50-75] V
# [marital.status=Married-civ-spouse ^ occupation=Exec-managerial ^ workclass=Private ^ age=48-55 ^ capital.loss=2559-0 ^ fnlwgt=65991-106812] V
# [marital.status=Married-civ-spouse ^ education.num=(13 ^ 9) ^ capital.gain=(0 ^ 0) ^ hours.per.week=50-75] V
# [marital.status=Married-civ-spouse ^ education.num=10-13 ^ education=Bachelors ^ capital.gain=(0 ^ 0) ^ fnlwgt=(328610 ^ 162667)] V
# [marital.status=Married-civ-spouse ^ education=Bachelors ^ occupation=Exec-managerial ^ hours.per.week=40-50 ^ capital.loss=(2559 ^ 0)] V
# [marital.status=Married-civ-spouse ^ education=Bachelors ^ capital.gain=(0 ^ 0)] V
# [marital.status=Married-civ-spouse ^ education.num=(13 ^ 9) ^ capital.gain=(0 ^ 0) ^ hours.per.week=40-50 ^ occupation=Prof-specialty] V
# [marital.status=Married-civ-spouse ^ education.num=(13 ^ 9) ^ capital.loss=(2559 ^ 0)]]
#
# Optimizing dl...

# %% [markdown]
# The fit method is flexible and can be called in various ways, including with train_x and train_y, or with numpy arrays.
#
# Unlike dataframes, arrays don't have feature names...

# %%
X_train, y_train = train.drop('Party', axis=1), train['Party']
X_array, y_array = X_train.values, y_train.values
ripper_clf.fit(X_array, y_array, pos_class='democrat')
ripper_clf.ruleset_

# %% [markdown]
# But we can pass them in:

# %%
X_array, y_arry = train.drop('Party', axis=1).values, train['Party'].values
ripper_clf.fit(X_array, y_arry, 
               pos_class='democrat', class_feat='Party', 
               feature_names=df.columns[1:])
ripper_clf.ruleset_
# Out:
# <Ruleset [physician-fee-freeze=n] V [synfuels-corporation-cutback=y^adoption-of-the-budget-resolution=y^anti-satellite-test-ban=n] V [adoption-of-the-budget-resolution=?^Handicapped-infants=y]>

# %% [markdown]
# We can force a simpler ruleset using max_rules, max_total_conds, or max_rule_conds.

# %%
ripper_clf = lw.RIPPER(max_rules=2, random_state=1)
ripper_clf.fit(train, class_feat='Party', pos_class='democrat')
ripper_clf.ruleset_
# Out:
# <Ruleset [physician-fee-freeze=n] V [synfuels-corporation-cutback=y^physician-fee-freeze=?]>

# %% [markdown]
# Verbosity allows us to view training steps...

# %%
ripper_clf = lw.RIPPER(random_state=42, verbosity=1) # Scale of 0-5
ripper_clf.fit(train, class_feat='Party', pos_class='democrat')
ripper_clf.ruleset_
# Out:
# GREW INITIAL RULESET:
# [[physician-fee-freeze=n] V
# [synfuels-corporation-cutback=y] V
# [superfund-right-to-sue=? ^ export-administration-act-south-africa=y] V
# [adoption-of-the-budget-resolution=y ^ anti-satellite-test-ban=n ^ immigration=n]]
#
# optimization run 1 of 2
#
# OPTIMIZED RULESET:
# [[physician-fee-freeze=n] V
# [synfuels-corporation-cutback=y] V
# [superfund-right-to-sue=? ^ export-administration-act-south-africa=y] V
# [adoption-of-the-budget-resolution=y ^ anti-satellite-test-ban=n ^ immigration=n]]
#
# No changes were made. Halting optimization.
# GREW FINAL RULES
# [[physician-fee-freeze=n] V
# [synfuels-corporation-cutback=y] V
# [superfund-right-to-sue=? ^ export-administration-act-south-africa=y] V
# [adoption-of-the-budget-resolution=y ^ anti-satellite-test-ban=n ^ immigration=n] V
# [physician-fee-freeze=n] V
# [synfuels-corporation-cutback=y] V
# [superfund-right-to-sue=? ^ export-administration-act-south-africa=y] V
# [adoption-of-the-budget-resolution=y ^ anti-satellite-test-ban=n ^ immigration=n]]
#
# FINAL RULESET:
# [[physician-fee-freeze=n] V
# [adoption-of-the-budget-resolution=y ^ anti-satellite-test-ban=n ^ immigration=n]]
# <Ruleset [physician-fee-freeze=n] V [adoption-of-the-budget-resolution=y^anti-satellite-test-ban=n^immigration=n]>

# %% [markdown]
# #### Model selection

# %% [markdown]
# Some sklearn methods are supported. Cross-validation:

# %%
from sklearn.model_selection import cross_val_score

# Dummify our data to make sklearn happy
X_train = pd.get_dummies(X_train, columns=X_train.select_dtypes('object').columns)
y_train = y_train.map(lambda x: 1 if x=='democrat' else 0)

ripper_clf = lw.RIPPER(random_state=42)
cross_val_score(ripper_clf, X_train, y_train)
# Out:
# array([0.95454545, 0.90769231, 0.89230769, 0.92307692, 0.90769231])

# %% [markdown]
# Grid-search:

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {"prune_size": [0.1, 0.25, 0.33, 0.5], "k": [1, 2]}
grid = GridSearchCV(estimator=ripper_clf, param_grid=param_grid)
grid.fit(X_train, y_train)
grid.best_params_
# Out:
# {'k': 1, 'prune_size': 0.33}

# %% [markdown]
# Ensemble:

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

nb = GaussianNB()
tree = DecisionTreeClassifier(random_state=42)
estimators = [("rip", ripper_clf), ("tree", tree), ("nb", nb)]
ensemble_clf = StackingClassifier(
  estimators=estimators, final_estimator=LogisticRegression()
)

# %% [markdown]
# #### Testing

# %% [markdown]
# How good is our model?

# %%
X_test = test.drop('Party', axis=1)
y_test = test['Party']
ripper_clf = lw.RIPPER(random_state=42)
ripper_clf.fit(train, class_feat='Party', pos_class='democrat')
ripper_clf.score(X_test, y_test) # Default metric is accuracy
# Out:
# 0.908256880733945

# %% [markdown]
# We can also score it on custom metrics, including sklearn's:

# %%
from sklearn.metrics import precision_score, recall_score
precision = ripper_clf.score(X_test, y_test, precision_score)
recall = ripper_clf.score(X_test, y_test, recall_score)
print(f'precision: {precision}')
print(f'recall: {recall}')
# Out:
# precision: 1.0
# recall: 0.855072463768116

# %% [markdown]
# #### Prediction

# %% [markdown]
# To make predictions, use the predict method.

# %%
ripper_clf.predict(X_test.tail(10))
# Out:
# [False, True, True, True, False, False, False, True, False, True]

# %% [markdown]
# For predicted probabilities, use predict_proba.

# %%
ripper_clf.predict_proba(X_test.tail(10))
# Out:
# array([[0.75903614, 0.24096386],
#        [0.01086957, 0.98913043],
#        [0.01086957, 0.98913043],
#        [0.01086957, 0.98913043],
#        [0.75903614, 0.24096386],
#        [0.75903614, 0.24096386],
#        [0.75903614, 0.24096386],
#        [0.01086957, 0.98913043],
#        [0.75903614, 0.24096386],
#        [0.01086957, 0.98913043]])

# %% [markdown]
# We can also ask our model to give us the reasons for its predictions.

# %%
ripper_clf.predict(X_test.tail(), give_reasons=True)
# Out:
# ([False, False, True, False, True],
#  [[],
#   [],
#   [<Rule [physician-fee-freeze=n]>],
#   [],
#   [<Rule [physician-fee-freeze=n]>]])
