# %% [markdown]
# # Kiwi-Aussie Classification with IREP

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Define our features and their distributions

# %%
features = {'Nationality':('Kiwi','Aussie'),
 'Funny_Accent':
    ('Yes','No'),
 'Waltzing':
    ('Yes','No'),
 'AU_Anthem':
    ('Yes','No','Some'),
 'Six':
    ('Properly','Seeks'), 
 'Fish_and_Chips':
    ('Normal','Feessh_and_Cheeps','Fush_and_Chups'),
 'Favourite':
    ('Vegemite','Marmite','Butter','Marmalade'),
 'Owns_X_Sheep':
    ('One','Two','Three','Many'),
 'Can_Fly':
    ('Yes','No','Briefly')
}
                
kiwi_dist = {'Nationality':(1,0),
  'Funny_Accent':
      (.8,.2),
  'Waltzing':
      (.6,.4),
  'AU_Anthem':
      (.05,.90,.05),
  'Six':
      (.8,.20),
  'Fish_and_Chips':
      (.4,.15,.45),
  'Favourite':
      (.35,.40,.10,.15),
  'Owns_X_Sheep':
      (.1,.3,.4,.2),
  'Can_Fly':
      (0,.9,.1)
 }
    
aussie_dist = {'Nationality':(0,1),
  'Funny_Accent':
      (.9,.1),
  'Waltzing':
      (.7,.3),
  'AU_Anthem':
      (.05,.85,.1),
  'Six':
      (.4,.6),
  'Fish_and_Chips':
      (.3,.05,.65),
  'Favourite':
      (.5,.25,.15,.1),
  'Owns_X_Sheep':
      (.2,.5,.1,.2),
  'Can_Fly':
      (0,1,0)
 }

# %% [markdown]
# ### Generate Kiwis and Aussies

# %% [markdown]
# Generate arrays of random kiwis and aussies according to their feature distributions:

# %%
n_kiwis = 100
n_aussies = 100

kiwis = [ np.random.choice(options, n_kiwis, p=kiwi_dist[feature])
            for feature, options in features.items() ]

aussies = [ np.random.choice(options, n_aussies, p=aussie_dist[feature])
            for feature, options in features.items() ]

# %%
kiwis = np.array(kiwis).T
aussies = np.array(aussies).T
everyone = np.concatenate((kiwis, aussies), axis=0)

# %% [markdown]
# Load everyone into pandas.

# %%
df = pd.DataFrame(columns=['Nationality','Funny_Accent','Waltzing','AU_Anthem',
                          'Six','Fish_and_Chips','Favorite',
                          'Own_X_Sheep','Can_Fly'], data=everyone)

# %% [markdown]
# This shuffles the dataframe:

# %%
df = df.sample(frac=1, random_state=42)

# %%
df.head(10)
# Out:
#     Nationality Funny_Accent Waltzing AU_Anthem       Six     Fish_and_Chips  \
# 95         Kiwi          Yes       No       Yes     Seeks  Feessh_and_Cheeps
# 15         Kiwi          Yes       No      Some  Properly             Normal
# 30         Kiwi          Yes      Yes        No  Properly     Fush_and_Chups
# 158      Aussie          Yes      Yes        No  Properly             Normal
# 128      Aussie          Yes       No        No  Properly     Fush_and_Chups
# 115      Aussie          Yes      Yes        No  Properly             Normal
# 69         Kiwi          Yes      Yes        No  Properly     Fush_and_Chups
# 170      Aussie          Yes      Yes        No     Seeks     Fush_and_Chups
# 174      Aussie          Yes       No        No  Properly     Fush_and_Chups
# 45         Kiwi          Yes      Yes        No  Properly  Feessh_and_Cheeps
#
#       Favorite Own_X_Sheep Can_Fly
# 95     Marmite       Three      No
# 15   Marmalade       Three      No
# 30    Vegemite         Two      No
# 158  Marmalade        Many      No
# 128   Vegemite         One      No
# 115     Butter         One      No
# 69    Vegemite       Three      No
# 170    Marmite         Two      No
# 174   Vegemite        Many      No
# 45    Vegemite       Three      No

# %% [markdown]
# ### Bring in IREP

# %%
import sys
sys.path.insert(0, '/Users/ilanmoscovitz/Documents/Python')
import IREP

# %% [markdown]
# Split our data:

# %%
train, test = IREP.train_test_split(df, test_percent=.33, seed=42)

# %% [markdown]
# Grow a ruleset without pruning:

# %%
ire_ruleset = IREP.ire(df=train, display=True, show_gain=False, sleep=False)
ire_ruleset
# Out:
# Remaining pos: 61
# Update: []
# Update: [('Own_X_Sheep', 'Three')]
# Update: [('Own_X_Sheep', 'Three'), ('Six', 'Properly')]
# Grown: [('Own_X_Sheep', 'Three'), ('Six', 'Properly'), ('Fish_and_Chips', 'Normal')]
#
# Remaining pos: 48
# Update: []
# Update: [('Six', 'Properly')]
# Update: [('Six', 'Properly'), ('Own_X_Sheep', 'Three')]
# Grown: [('Six', 'Properly'), ('Own_X_Sheep', 'Three'), ('Favorite', 'Vegemite')]
#
# Remaining pos: 42
# Update: []
# Update: [('Six', 'Properly')]
# Update: [('Six', 'Properly'), ('Own_X_Sheep', 'Two')]
# Grown: [('Six', 'Properly'), ('Own_X_Sheep', 'Two'), ('Favorite', 'Marmite')]
#
# Remaining pos: 36
# Update: []
# Update: [('Favorite', 'Marmalade')]
# Grown: [('Favorite', 'Marmalade'), ('Waltzing', 'No')]
#
# Remaining pos: 29
# Update: []
# Update: [('Six', 'Properly')]
# Grown: [('Six', 'Properly'), ('Can_Fly', 'Briefly')]
#
# Remaining pos: 25
# Update: []
# Update: [('Own_X_Sheep', 'Three')]
# Grown: [('Own_X_Sheep', 'Three'), ('Waltzing', 'No')]
#
# Remaining pos: 21
# Update: []
# Update: [('Six', 'Properly')]
# Update: [('Six', 'Properly'), ('Fish_and_Chips', 'Fush_and_Chups')]
# Update: [('Six', 'Properly'), ('Fish_and_Chips', 'Fush_and_Chups'), ('Own_X_Sheep', 'One')]
# Grown: [('Six', 'Properly'), ('Fish_and_Chips', 'Fush_and_Chups'), ('Own_X_Sheep', 'One'), ('Favorite', 'Vegemite')]
#
# Remaining pos: 19
# Update: []
# Update: [('Six', 'Properly')]
# Update: [('Six', 'Properly'), ('Favorite', 'Marmalade')]
# Update: [('Six', 'Properly'), ('Favorite', 'Marmalade'), ('Funny_Accent', 'Yes')]
# Update: [('Six', 'Properly'), ('Favorite', 'Marmalade'), ('Funny_Accent', 'Yes'), ('Fish_and_Chips', 'Fush_and_Chups')]
# Grown: [('Six', 'Properly'), ('Favorite', 'Marmalade'), ('Funny_Accent', 'Yes'), ('Fish_and_Chips', 'Fush_and_Chups'), ('Own_X_Sheep', 'Many')]
#
# Remaining pos: 18
# Update: []
# Update: [('Six', 'Properly')]
# Update: [('Six', 'Properly'), ('Favorite', 'Marmalade')]
# Update: [('Six', 'Properly'), ('Favorite', 'Marmalade'), ('Funny_Accent', 'Yes')]
# Update: [('Six', 'Properly'), ('Favorite', 'Marmalade'), ('Funny_Accent', 'Yes'), ('Own_X_Sheep', 'Two')]
# Grown: [('Six', 'Properly'), ('Favorite', 'Marmalade'), ('Funny_Accent', 'Yes'), ('Own_X_Sheep', 'Two')]
#
# Remaining pos: 16
# Update: []
# Update: [('Own_X_Sheep', 'Three')]
# Update: [('Own_X_Sheep', 'Three'), ('Favorite', 'Marmite')]
# Update: [('Own_X_Sheep', 'Three'), ('Favorite', 'Marmite'), ('Six', 'Seeks')]
# Grown: [('Own_X_Sheep', 'Three'), ('Favorite', 'Marmite'), ('Six', 'Seeks'), ('Funny_Accent', 'Yes')]
#
# Remaining pos: 14
# Update: []
# Update: [('Six', 'Properly')]
# Grown: [('Six', 'Properly'), ('Fish_and_Chips', 'Feessh_and_Cheeps')]
#
# Remaining pos: 13
# Update: []
# Update: [('Six', 'Properly')]
# Update: [('Six', 'Properly'), ('Fish_and_Chips', 'Fush_and_Chups')]
# Update: [('Six', 'Properly'), ('Fish_and_Chips', 'Fush_and_Chups'), ('Own_X_Sheep', 'One')]
# Grown: [('Six', 'Properly'), ('Fish_and_Chips', 'Fush_and_Chups'), ('Own_X_Sheep', 'One'), ('Favorite', 'Marmite')]
#
# Remaining pos: 12
# Update: []
# Update: [('Own_X_Sheep', 'Many')]
# Update: [('Own_X_Sheep', 'Many'), ('Waltzing', 'No')]
# Grown: [('Own_X_Sheep', 'Many'), ('Waltzing', 'No'), ('Funny_Accent', 'No')]
#
# Remaining pos: 11
# Update: []
# Update: [('Six', 'Properly')]
# Update: [('Six', 'Properly'), ('Favorite', 'Butter')]
# Grown: [('Six', 'Properly'), ('Favorite', 'Butter'), ('Funny_Accent', 'No')]
#
# Remaining pos: 10
# Update: []
# Update: [('Own_X_Sheep', 'Many')]
# Update: [('Own_X_Sheep', 'Many'), ('Fish_and_Chips', 'Normal')]
# Grown: [('Own_X_Sheep', 'Many'), ('Fish_and_Chips', 'Normal'), ('Waltzing', 'No')]
#
# Remaining pos: 9
# Update: []
# Update: [('Six', 'Properly')]
# Update: [('Six', 'Properly'), ('Own_X_Sheep', 'Three')]
# Grown: [('Six', 'Properly'), ('Own_X_Sheep', 'Three'), ('Favorite', 'Butter')]
#
# Remaining pos: 8
# Update: []
# Update: [('Own_X_Sheep', 'Many')]
# Update: [('Own_X_Sheep', 'Many'), ('Fish_and_Chips', 'Normal')]
# Update: [('Own_X_Sheep', 'Many'), ('Fish_and_Chips', 'Normal'), ('Funny_Accent', 'Yes')]
# Update: [('Own_X_Sheep', 'Many'), ('Fish_and_Chips', 'Normal'), ('Funny_Accent', 'Yes'), ('Six', 'Seeks')]
# Grown: [('Own_X_Sheep', 'Many'), ('Fish_and_Chips', 'Normal'), ('Funny_Accent', 'Yes'), ('Six', 'Seeks'), ('Favorite', 'Marmalade')]
#
# Remaining pos: 7
# Update: []
# Update: [('Six', 'Properly')]
# Update: [('Six', 'Properly'), ('Favorite', 'Vegemite')]
# Update: [('Six', 'Properly'), ('Favorite', 'Vegemite'), ('Waltzing', 'Yes')]
# Update: [('Six', 'Properly'), ('Favorite', 'Vegemite'), ('Waltzing', 'Yes'), ('Own_X_Sheep', 'Many')]
# Grown: [('Six', 'Properly'), ('Favorite', 'Vegemite'), ('Waltzing', 'Yes'), ('Own_X_Sheep', 'Many'), ('Fish_and_Chips', 'Normal')]
#
# Remaining pos: 6
# Update: []
# Update: [('Fish_and_Chips', 'Fush_and_Chups')]
# Update: [('Fish_and_Chips', 'Fush_and_Chups'), ('Six', 'Properly')]
# Update: [('Fish_and_Chips', 'Fush_and_Chups'), ('Six', 'Properly'), ('Own_X_Sheep', 'One')]
# Grown: [('Fish_and_Chips', 'Fush_and_Chups'), ('Six', 'Properly'), ('Own_X_Sheep', 'One')]
#
# Remaining pos: 5
# Update: []
# Update: [('Funny_Accent', 'No')]
# Update: [('Funny_Accent', 'No'), ('Favorite', 'Marmite')]
# Grown: [('Funny_Accent', 'No'), ('Favorite', 'Marmite'), ('Waltzing', 'No')]
#
# Remaining pos: 4
# Update: []
# Update: [('Own_X_Sheep', 'Three')]
# Update: [('Own_X_Sheep', 'Three'), ('Funny_Accent', 'No')]
# Grown: [('Own_X_Sheep', 'Three'), ('Funny_Accent', 'No')]
#
# Remaining pos: 3
# Update: []
# Update: [('Favorite', 'Vegemite')]
# Update: [('Favorite', 'Vegemite'), ('Own_X_Sheep', 'Many')]
# Update: [('Favorite', 'Vegemite'), ('Own_X_Sheep', 'Many'), ('Waltzing', 'No')]
# Update: [('Favorite', 'Vegemite'), ('Own_X_Sheep', 'Many'), ('Waltzing', 'No'), ('Six', 'Seeks')]
# Grown: [('Favorite', 'Vegemite'), ('Own_X_Sheep', 'Many'), ('Waltzing', 'No'), ('Six', 'Seeks')]
#
# Remaining pos: 2
# Update: []
# Update: [('Six', 'Properly')]
# Update: [('Six', 'Properly'), ('Favorite', 'Vegemite')]
# Update: [('Six', 'Properly'), ('Favorite', 'Vegemite'), ('Waltzing', 'Yes')]
# Update: [('Six', 'Properly'), ('Favorite', 'Vegemite'), ('Waltzing', 'Yes'), ('Fish_and_Chips', 'Fush_and_Chups')]
# Update: [('Six', 'Properly'), ('Favorite', 'Vegemite'), ('Waltzing', 'Yes'), ('Fish_and_Chips', 'Fush_and_Chups'), ('Own_X_Sheep', 'Two')]
# Update: [('Six', 'Properly'), ('Favorite', 'Vegemite'), ('Waltzing', 'Yes'), ('Fish_and_Chips', 'Fush_and_Chups'), ('Own_X_Sheep', 'Two'), ('Funny_Accent', 'Yes')]
# Grown: [('Six', 'Properly'), ('Favorite', 'Vegemite'), ('Waltzing', 'Yes'), ('Fish_and_Chips', 'Fush_and_Chups'), ('Own_X_Sheep', 'Two'), ('Funny_Accent', 'Yes')]
#
# Remaining pos: 1
# Update: []
# Update: [('Own_X_Sheep', 'Many')]
# Update: [('Own_X_Sheep', 'Many'), ('Six', 'Properly')]
# Update: [('Own_X_Sheep', 'Many'), ('Six', 'Properly'), ('Favorite', 'Vegemite')]
# Update: [('Own_X_Sheep', 'Many'), ('Six', 'Properly'), ('Favorite', 'Vegemite'), ('Waltzing', 'Yes')]
# Grown: [('Own_X_Sheep', 'Many'), ('Six', 'Properly'), ('Favorite', 'Vegemite'), ('Waltzing', 'Yes')]
# [[('Own_X_Sheep', 'Many'),
#   ('Six', 'Properly'),
#   ('Favorite', 'Vegemite'),
#   ('Waltzing', 'Yes')],
#  [('Six', 'Properly'),
#   ('Favorite', 'Vegemite'),
#   ('Waltzing', 'Yes'),
#   ('Fish_and_Chips', 'Fush_and_Chups'),
#   ('Own_X_Sheep', 'Two'),
#   ('Funny_Accent', 'Yes')],
#  [('Favorite', 'Vegemite'),
#   ('Own_X_Sheep', 'Many'),
#   ('Waltzing', 'No'),
#   ('Six', 'Seeks')],
#  [('Own_X_Sheep', 'Three'), ('Funny_Accent', 'No')],
#  [('Funny_Accent', 'No'), ('Favorite', 'Marmite'), ('Waltzing', 'No')],
#  [('Fish_and_Chips', 'Fush_and_Chups'),
#   ('Six', 'Properly'),
#   ('Own_X_Sheep', 'One')],
#  [('Six', 'Properly'),
#   ('Favorite', 'Vegemite'),
#   ('Waltzing', 'Yes'),
#   ('Own_X_Sheep', 'Many'),
#   ('Fish_and_Chips', 'Normal')],
#  [('Own_X_Sheep', 'Many'),
#   ('Fish_and_Chips', 'Normal'),
#   ('Funny_Accent', 'Yes'),
#   ('Six', 'Seeks'),
#   ('Favorite', 'Marmalade')],
#  [('Six', 'Properly'), ('Own_X_Sheep', 'Three'), ('Favorite', 'Butter')],
#  [('Own_X_Sheep', 'Many'), ('Fish_and_Chips', 'Normal'), ('Waltzing', 'No')],
#  [('Six', 'Properly'), ('Favorite', 'Butter'), ('Funny_Accent', 'No')],
#  [('Own_X_Sheep', 'Many'), ('Waltzing', 'No'), ('Funny_Accent', 'No')],
#  [('Six', 'Properly'),
#   ('Fish_and_Chips', 'Fush_and_Chups'),
#   ('Own_X_Sheep', 'One'),
#   ('Favorite', 'Marmite')],
#  [('Six', 'Properly'), ('Fish_and_Chips', 'Feessh_and_Cheeps')],
#  [('Own_X_Sheep', 'Three'),
#   ('Favorite', 'Marmite'),
#   ('Six', 'Seeks'),
#   ('Funny_Accent', 'Yes')],
#  [('Six', 'Properly'),
#   ('Favorite', 'Marmalade'),
#   ('Funny_Accent', 'Yes'),
#   ('Own_X_Sheep', 'Two')],
#  [('Six', 'Properly'),
#   ('Favorite', 'Marmalade'),
#   ('Funny_Accent', 'Yes'),
#   ('Fish_and_Chips', 'Fush_and_Chups'),
#   ('Own_X_Sheep', 'Many')],
#  [('Six', 'Properly'),
#   ('Fish_and_Chips', 'Fush_and_Chups'),
#   ('Own_X_Sheep', 'One'),
#   ('Favorite', 'Vegemite')],
#  [('Own_X_Sheep', 'Three'), ('Waltzing', 'No')],
#  [('Six', 'Properly'), ('Can_Fly', 'Briefly')],
#  [('Favorite', 'Marmalade'), ('Waltzing', 'No')],
#  [('Six', 'Properly'), ('Own_X_Sheep', 'Two'), ('Favorite', 'Marmite')],
#  [('Six', 'Properly'), ('Own_X_Sheep', 'Three'), ('Favorite', 'Vegemite')],
#  [('Own_X_Sheep', 'Three'), ('Six', 'Properly'), ('Fish_and_Chips', 'Normal')]]

# %% [markdown]
# Now with pruning:

# %%
irep_ruleset = IREP.irep(df=train, display=True, show_gain=False, sleep=False, seed=42)
irep_ruleset
# Out:
# Update: []
# Update: [('Own_X_Sheep', 'Three')]
# Grown: [('Own_X_Sheep', 'Three'), ('Six', 'Properly')]
# Pruned to: [('Own_X_Sheep', 'Three')]
# Updated ruleset: [[('Own_X_Sheep', 'Three')]]
#
# Update: []
# Update: [('Six', 'Properly')]
# Update: [('Six', 'Properly'), ('Own_X_Sheep', 'Two')]
# Grown: [('Six', 'Properly'), ('Own_X_Sheep', 'Two'), ('Favorite', 'Marmite')]
# Pruned to: [('Six', 'Properly'), ('Own_X_Sheep', 'Two')]
# Updated ruleset: [[('Own_X_Sheep', 'Three')], [('Six', 'Properly'), ('Own_X_Sheep', 'Two')]]
#
# Update: []
# Update: [('Waltzing', 'No')]
# Grown: [('Waltzing', 'No'), ('Funny_Accent', 'No')]
# Pruned to: [('Waltzing', 'No'), ('Funny_Accent', 'No')]
# Updated ruleset: [[('Own_X_Sheep', 'Three')], [('Six', 'Properly'), ('Own_X_Sheep', 'Two')], [('Waltzing', 'No'), ('Funny_Accent', 'No')]]
#
# Update: []
# Update: [('Favorite', 'Marmalade')]
# Grown: [('Favorite', 'Marmalade'), ('Waltzing', 'No')]
# Pruned to: [('Favorite', 'Marmalade')]
# Updated ruleset: [[('Own_X_Sheep', 'Three')], [('Six', 'Properly'), ('Own_X_Sheep', 'Two')], [('Waltzing', 'No'), ('Funny_Accent', 'No')], [('Favorite', 'Marmalade')]]
#
# Update: []
# Update: [('Six', 'Properly')]
# Grown: [('Six', 'Properly'), ('AU_Anthem', 'Yes')]
# Pruned to: [('Six', 'Properly'), ('AU_Anthem', 'Yes')]
# [[('Own_X_Sheep', 'Three')],
#  [('Six', 'Properly'), ('Own_X_Sheep', 'Two')],
#  [('Waltzing', 'No'), ('Funny_Accent', 'No')],
#  [('Favorite', 'Marmalade')]]

# %% [markdown]
# Now a bunch of times:

# %%
experiment_results = IREP.experiment(df, n=10, first_seed=42)

# %%
experiment_results
# Out:
#                                                     Precision    Recall  \
# Ruleset
# [[(Own_X_Sheep, Three)]]                             0.860133  0.369925
# [[(Six, Properly), (Own_X_Sheep, Three)]]            1.000000  0.313492
# [[(Six, Properly), (Own_X_Sheep, Two), (Favorit...   0.812500  0.838710
# [[(Six, Properly), (Own_X_Sheep, Two), (Favorit...   0.823529  0.518519
# [[(Six, Properly), (Own_X_Sheep, Two), (Favorit...   0.833333  0.769231
# [[(Waltzing, No), (Six, Properly), (Funny_Accen...   0.760000  0.655172
#
#                                                     Freq_Selected
# Ruleset
# [[(Own_X_Sheep, Three)]]                                      0.4
# [[(Six, Properly), (Own_X_Sheep, Three)]]                     0.2
# [[(Six, Properly), (Own_X_Sheep, Two), (Favorit...            0.1
# [[(Six, Properly), (Own_X_Sheep, Two), (Favorit...            0.1
# [[(Six, Properly), (Own_X_Sheep, Two), (Favorit...            0.1
# [[(Waltzing, No), (Six, Properly), (Funny_Accen...            0.1

# %%
IREP.exp_performance(experiment_results)

# %%
IREP.ruleset_covers(irep_ruleset,test)
