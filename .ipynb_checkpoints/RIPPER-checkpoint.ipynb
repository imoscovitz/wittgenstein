# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.metrics import precision_score, recall_score

# %%
import ripper

def make_ripper_dataset(dataset_filename, random_state=42):
    # Load df
    df = pd.read_csv(dataset_filename)
    
    # Split
    train, test = train_test_split(df, test_size=.33, random_state=random_state)
    
    return train, test

# %%
def make_ripper(train, class_feat, pos_class, random_state=42):
    # Train
    irep_clf = ripper.RIPPER(class_feat=class_feat,pos_class=pos_class)
    irep_clf.fit(train, seed=random_state, prune=True, verbose=True)
    return irep_clf

# %%
def score_ripper(ripper_clf, test, class_feat):
    X_test = test.drop(class_feat,axis=1)
    y_test = test[class_feat]

    precision = ripper_clf.score(X_test, y_test, precision_score)
    recall = ripper_clf.score(X_test, y_test, recall_score)
    total_conds = ripper_clf.ruleset_.count_conds()
    return precision, recall, total_conds

# %%
datasets_path = '../datasets/'
random_state = 0

# %%
# Set up
dataset = 'house-votes-84.csv'
filename = datasets_path + dataset
class_feat = 'Party'
pos_class = 'democrat'
n_classes = 2

# %%
# Run ripper
train, test = make_ripper_dataset(filename, random_state=random_state)
ripper_clf = make_ripper(train, class_feat, pos_class, random_state=random_state)
ripper_precision, ripper_recall, ripper_conds = score_ripper(ripper_clf, test, class_feat)
ripper_precision, ripper_recall, ripper_conds
# Out:
# grew rule: [physician-fee-freeze=n^adoption-of-the-budget-resolution=y]
# on pruneset iter, p_covered 103 n_covered 0
# on pruneset iter, p_covered 113 n_covered 1
# pruned rule: [physician-fee-freeze=n^adoption-of-the-budget-resolution=y]
# rule_bits| rule [physician-fee-freeze=n^adoption-of-the-budget-resolution=y] k 2 n 48 pr 0.041666666666666664: rule_bits 6.5
# exceptions_bits| P 183 p 154 fp 0 fn 29: exceptions_bits 0.0
# Rule [physician-fee-freeze=n^adoption-of-the-budget-resolution=y] total_bits 6.5
# examples remaining: 29 pos, 108 neg
# mdl 6.5
#
# grew rule: [synfuels-corporation-cutback=y^export-administration-act-south-africa=n]
# on pruneset iter, p_covered 3 n_covered 2
# on pruneset iter, p_covered 12 n_covered 8
# pruned rule: [synfuels-corporation-cutback=y^export-administration-act-south-africa=n]
# rule_bits| rule [synfuels-corporation-cutback=y^export-administration-act-south-africa=n] k 2 n 48 pr 0.041666666666666664: rule_bits 6.5
# exceptions_bits| P 29 p 6 fp 2 fn 23: exceptions_bits 3.91
# Rule [synfuels-corporation-cutback=y^export-administration-act-south-africa=n] total_bits 10.4
# examples remaining: 23 pos, 106 neg
# mdl 6.5
#
# grew rule: [el-salvador-aid=n^Water-project-cost-sharing=y]
# on pruneset iter, p_covered 2 n_covered 0
# on pruneset iter, p_covered 7 n_covered 3
# pruned rule: [el-salvador-aid=n^Water-project-cost-sharing=y]
# rule_bits| rule [el-salvador-aid=n^Water-project-cost-sharing=y] k 2 n 48 pr 0.041666666666666664: rule_bits 6.5
# exceptions_bits| P 23 p 5 fp 0 fn 18: exceptions_bits 0.0
# Rule [el-salvador-aid=n^Water-project-cost-sharing=y] total_bits 6.5
# examples remaining: 18 pos, 106 neg
# mdl 6.5
#
# grew rule: [mx-missile=y^anti-satellite-test-ban=n]
# on pruneset iter, p_covered 0 n_covered 0
# on pruneset iter, p_covered 6 n_covered 6
# pruned rule: [mx-missile=y^anti-satellite-test-ban=n]
# rule_bits| rule [mx-missile=y^anti-satellite-test-ban=n] k 2 n 48 pr 0.041666666666666664: rule_bits 6.5
# exceptions_bits| P 18 p 2 fp 0 fn 16: exceptions_bits 0.0
# Rule [mx-missile=y^anti-satellite-test-ban=n] total_bits 6.5
# examples remaining: 16 pos, 106 neg
# mdl 6.5
#
# grew rule: [physician-fee-freeze=?^Handicapped-infants=n]
# on pruneset iter, p_covered 1 n_covered 0
# on pruneset iter, p_covered 2 n_covered 0
# pruned rule: [physician-fee-freeze=?^Handicapped-infants=n]
# rule_bits| rule [physician-fee-freeze=?^Handicapped-infants=n] k 2 n 48 pr 0.041666666666666664: rule_bits 6.5
# exceptions_bits| P 16 p 2 fp 0 fn 14: exceptions_bits 0.0
# Rule [physician-fee-freeze=?^Handicapped-infants=n] total_bits 6.5
# examples remaining: 14 pos, 106 neg
# mdl 6.5
#
# grew rule: [adoption-of-the-budget-resolution=?^mx-missile=y]
# on pruneset iter, p_covered 1 n_covered 0
# on pruneset iter, p_covered 1 n_covered 1
# pruned rule: [adoption-of-the-budget-resolution=?^mx-missile=y]
# rule_bits| rule [adoption-of-the-budget-resolution=?^mx-missile=y] k 2 n 48 pr 0.041666666666666664: rule_bits 6.5
# exceptions_bits| P 14 p 3 fp 0 fn 11: exceptions_bits 0.0
# Rule [adoption-of-the-budget-resolution=?^mx-missile=y] total_bits 6.5
# examples remaining: 11 pos, 106 neg
# mdl 6.5
#
# grew rule: [physician-fee-freeze=n^immigration=y]
# on pruneset iter, p_covered 2 n_covered 1
# on pruneset iter, p_covered 6 n_covered 1
# pruned rule: [physician-fee-freeze=n]
# rule_bits| rule [physician-fee-freeze=n] k 1 n 38 pr 0.02631578947368421: rule_bits 3.34
# exceptions_bits| P 11 p 8 fp 2 fn 3: exceptions_bits 4.81
# Rule [physician-fee-freeze=n] total_bits 8.14
# examples remaining: 3 pos, 104 neg
# mdl 6.5
#
# grow replacement for rule 0: [physician-fee-freeze=n^adoption-of-the-budget-resolution=y]
# successor [Handicapped-infants=?] gain 76.0
# successor [Handicapped-infants=y] gain -19.0
# successor [Handicapped-infants=n] gain -105.0
# successor [Water-project-cost-sharing=?] gain -15.0
# successor [Water-project-cost-sharing=y] gain -57.0
# successor [Water-project-cost-sharing=n] gain -58.0
# successor [adoption-of-the-budget-resolution=?] gain -0.0
# successor [adoption-of-the-budget-resolution=y] gain -13.0
# successor [adoption-of-the-budget-resolution=n] gain -108.0
# successor [physician-fee-freeze=?] gain 1.0
# successor [physician-fee-freeze=y] gain -122.0
# successor [physician-fee-freeze=n] gain 5.0
# successor [el-salvador-aid=?] gain 0.0
# successor [el-salvador-aid=y] gain -120.0
# successor [el-salvador-aid=n] gain 2.0
# successor [religious-groups-in-schools=?] gain 1.0
# successor [religious-groups-in-schools=y] gain -113.0
# successor [religious-groups-in-schools=n] gain -11.0
# successor [anti-satellite-test-ban=?] gain -4.0
# successor [anti-satellite-test-ban=y] gain -30.0
# successor [anti-satellite-test-ban=n] gain -92.0
# successor [aid-to-nicaraguan-contras=?] gain -6.0
# successor [aid-to-nicaraguan-contras=y] gain -13.0
# successor [aid-to-nicaraguan-contras=n] gain -104.0
# successor [mx-missile=?] gain 0.0
# successor [mx-missile=y] gain -6.0
# successor [mx-missile=n] gain -115.0
# successor [immigration=?] gain -0.0
# successor [immigration=y] gain -73.0
# successor [immigration=n] gain -56.0
# successor [synfuels-corporation-cutback=?] gain -6.0
# successor [synfuels-corporation-cutback=y] gain -13.0
# successor [synfuels-corporation-cutback=n] gain -107.0
# successor [education-spending=?] gain -7.0
# successor [education-spending=y] gain -107.0
# successor [education-spending=n] gain -8.0
# successor [superfund-right-to-sue=?] gain -6.0
# successor [superfund-right-to-sue=y] gain -104.0
# successor [superfund-right-to-sue=n] gain -14.0
# successor [crime=?] gain -4.0
# successor [crime=y] gain -120.0
# successor [crime=n] gain 5.0
# successor [duty-free-exports=?] gain -7.0
# successor [duty-free-exports=y] gain -5.0
# successor [duty-free-exports=n] gain -111.0
# successor [export-administration-act-south-africa=?] gain -10.0
# successor [export-administration-act-south-africa=y] gain -79.0
# successor [export-administration-act-south-africa=n] gain -41.0
# best successor: [Handicapped-infants=?]
# successor [Handicapped-infants=?^Water-project-cost-sharing=?] gain 1.0
# successor [Handicapped-infants=?^Water-project-cost-sharing=y] gain 1.0
# successor [Handicapped-infants=?^Water-project-cost-sharing=n] gain -1.0
# successor [Handicapped-infants=?^adoption-of-the-budget-resolution=?] gain -1.0
# successor [Handicapped-infants=?^adoption-of-the-budget-resolution=y] gain -1.0
# successor [Handicapped-infants=?^adoption-of-the-budget-resolution=n] gain 0.0
# successor [Handicapped-infants=?^physician-fee-freeze=?] gain -1.0
# successor [Handicapped-infants=?^physician-fee-freeze=y] gain -1.0
# successor [Handicapped-infants=?^physician-fee-freeze=n] gain 0.0
# successor [Handicapped-infants=?^el-salvador-aid=?] gain -1.0
# successor [Handicapped-infants=?^el-salvador-aid=y] gain -0.0
# successor [Handicapped-infants=?^el-salvador-aid=n] gain -1.0
# successor [Handicapped-infants=?^religious-groups-in-schools=?] gain -1.0
# successor [Handicapped-infants=?^religious-groups-in-schools=y] gain -1.0
# successor [Handicapped-infants=?^religious-groups-in-schools=n] gain 0.0
# successor [Handicapped-infants=?^anti-satellite-test-ban=?] gain -1.0
# successor [Handicapped-infants=?^anti-satellite-test-ban=y] gain -1.0
# successor [Handicapped-infants=?^anti-satellite-test-ban=n] gain -0.0
# successor [Handicapped-infants=?^aid-to-nicaraguan-contras=?] gain -1.0
# successor [Handicapped-infants=?^aid-to-nicaraguan-contras=y] gain -1.0
# successor [Handicapped-infants=?^aid-to-nicaraguan-contras=n] gain 0.0
# successor [Handicapped-infants=?^mx-missile=?] gain -1.0
# successor [Handicapped-infants=?^mx-missile=y] gain -1.0
# successor [Handicapped-infants=?^mx-missile=n] gain 0.0
# successor [Handicapped-infants=?^immigration=?] gain -1.0
# successor [Handicapped-infants=?^immigration=y] gain -1.0
# successor [Handicapped-infants=?^immigration=n] gain 0.0
# successor [Handicapped-infants=?^synfuels-corporation-cutback=?] gain -1.0
# successor [Handicapped-infants=?^synfuels-corporation-cutback=y] gain 0.0
# successor [Handicapped-infants=?^synfuels-corporation-cutback=n] gain -1.0
# successor [Handicapped-infants=?^education-spending=?] gain -1.0
# successor [Handicapped-infants=?^education-spending=y] gain -1.0
# successor [Handicapped-infants=?^education-spending=n] gain 0.0
# successor [Handicapped-infants=?^superfund-right-to-sue=?] gain -1.0
# successor [Handicapped-infants=?^superfund-right-to-sue=y] gain 0.0
# successor [Handicapped-infants=?^superfund-right-to-sue=n] gain -1.0
# successor [Handicapped-infants=?^crime=?] gain -1.0
# successor [Handicapped-infants=?^crime=y] gain -1.0
# successor [Handicapped-infants=?^crime=n] gain 0.0
# successor [Handicapped-infants=?^duty-free-exports=?] gain -1.0
# successor [Handicapped-infants=?^duty-free-exports=y] gain 0.0
# successor [Handicapped-infants=?^duty-free-exports=n] gain -1.0
# successor [Handicapped-infants=?^export-administration-act-south-africa=?] gain -1.0
# successor [Handicapped-infants=?^export-administration-act-south-africa=y] gain -1.0
# successor [Handicapped-infants=?^export-administration-act-south-africa=n] gain -0.0
# best successor: [Handicapped-infants=?^Water-project-cost-sharing=y]
# best replacement: [Handicapped-infants=?^Water-project-cost-sharing=y]
#
# rule [physician-fee-freeze=n^adoption-of-the-budget-resolution=y] replacement: [Handicapped-infants=?^Water-project-cost-sharing=y]
#
# grow replacement for rule 1: [synfuels-corporation-cutback=y^export-administration-act-south-africa=n]
# successor [Handicapped-infants=?] gain 95.0
# successor [Handicapped-infants=y] gain -21.0
# successor [Handicapped-infants=n] gain -112.0
# successor [Water-project-cost-sharing=?] gain -15.0
# successor [Water-project-cost-sharing=y] gain -60.0
# successor [Water-project-cost-sharing=n] gain -62.0
# successor [adoption-of-the-budget-resolution=?] gain -0.0
# successor [adoption-of-the-budget-resolution=y] gain -16.0
# successor [adoption-of-the-budget-resolution=n] gain -115.0
# successor [physician-fee-freeze=?] gain 1.0
# successor [physician-fee-freeze=y] gain -131.0
# successor [physician-fee-freeze=n] gain 2.0
# successor [el-salvador-aid=?] gain 0.0
# successor [el-salvador-aid=y] gain -128.0
# successor [el-salvador-aid=n] gain -1.0
# successor [religious-groups-in-schools=?] gain 1.0
# successor [religious-groups-in-schools=y] gain -120.0
# successor [religious-groups-in-schools=n] gain -13.0
# successor [anti-satellite-test-ban=?] gain -4.0
# successor [anti-satellite-test-ban=y] gain -33.0
# successor [anti-satellite-test-ban=n] gain -97.0
# successor [aid-to-nicaraguan-contras=?] gain -6.0
# successor [aid-to-nicaraguan-contras=y] gain -16.0
# successor [aid-to-nicaraguan-contras=n] gain -110.0
# successor [mx-missile=?] gain 0.0
# successor [mx-missile=y] gain -8.0
# successor [mx-missile=n] gain -122.0
# successor [immigration=?] gain -0.0
# successor [immigration=y] gain -77.0
# successor [immigration=n] gain -59.0
# successor [synfuels-corporation-cutback=?] gain -6.0
# successor [synfuels-corporation-cutback=y] gain -14.0
# successor [synfuels-corporation-cutback=n] gain -113.0
# successor [education-spending=?] gain -7.0
# successor [education-spending=y] gain -114.0
# successor [education-spending=n] gain -11.0
# successor [superfund-right-to-sue=?] gain -6.0
# successor [superfund-right-to-sue=y] gain -110.0
# successor [superfund-right-to-sue=n] gain -17.0
# successor [crime=?] gain -4.0
# successor [crime=y] gain -128.0
# successor [crime=n] gain 3.0
# successor [duty-free-exports=?] gain -7.0
# successor [duty-free-exports=y] gain -7.0
# successor [duty-free-exports=n] gain -118.0
# successor [export-administration-act-south-africa=?] gain -11.0
# successor [export-administration-act-south-africa=y] gain -83.0
# successor [export-administration-act-south-africa=n] gain -43.0
# best successor: [Handicapped-infants=?]
# successor [Handicapped-infants=?^Water-project-cost-sharing=?] gain 1.0
# successor [Handicapped-infants=?^Water-project-cost-sharing=y] gain 1.0
# successor [Handicapped-infants=?^Water-project-cost-sharing=n] gain -1.0
# successor [Handicapped-infants=?^adoption-of-the-budget-resolution=?] gain -1.0
# successor [Handicapped-infants=?^adoption-of-the-budget-resolution=y] gain -1.0
# successor [Handicapped-infants=?^adoption-of-the-budget-resolution=n] gain 0.0
# successor [Handicapped-infants=?^physician-fee-freeze=?] gain -1.0
# successor [Handicapped-infants=?^physician-fee-freeze=y] gain -1.0
# successor [Handicapped-infants=?^physician-fee-freeze=n] gain 0.0
# successor [Handicapped-infants=?^el-salvador-aid=?] gain -1.0
# successor [Handicapped-infants=?^el-salvador-aid=y] gain -0.0
# successor [Handicapped-infants=?^el-salvador-aid=n] gain -1.0
# successor [Handicapped-infants=?^religious-groups-in-schools=?] gain -1.0
# successor [Handicapped-infants=?^religious-groups-in-schools=y] gain -1.0
# successor [Handicapped-infants=?^religious-groups-in-schools=n] gain 0.0
# successor [Handicapped-infants=?^anti-satellite-test-ban=?] gain -1.0
# successor [Handicapped-infants=?^anti-satellite-test-ban=y] gain -1.0
# successor [Handicapped-infants=?^anti-satellite-test-ban=n] gain -0.0
# successor [Handicapped-infants=?^aid-to-nicaraguan-contras=?] gain -1.0
# successor [Handicapped-infants=?^aid-to-nicaraguan-contras=y] gain -1.0
# successor [Handicapped-infants=?^aid-to-nicaraguan-contras=n] gain 0.0
# successor [Handicapped-infants=?^mx-missile=?] gain -1.0
# successor [Handicapped-infants=?^mx-missile=y] gain -1.0
# successor [Handicapped-infants=?^mx-missile=n] gain 0.0
# successor [Handicapped-infants=?^immigration=?] gain -1.0
# successor [Handicapped-infants=?^immigration=y] gain -1.0
# successor [Handicapped-infants=?^immigration=n] gain 0.0
# successor [Handicapped-infants=?^synfuels-corporation-cutback=?] gain -1.0
# successor [Handicapped-infants=?^synfuels-corporation-cutback=y] gain 0.0
# successor [Handicapped-infants=?^synfuels-corporation-cutback=n] gain -1.0
# successor [Handicapped-infants=?^education-spending=?] gain -1.0
# successor [Handicapped-infants=?^education-spending=y] gain -1.0
# successor [Handicapped-infants=?^education-spending=n] gain 0.0
# successor [Handicapped-infants=?^superfund-right-to-sue=?] gain -1.0
# successor [Handicapped-infants=?^superfund-right-to-sue=y] gain 0.0
# successor [Handicapped-infants=?^superfund-right-to-sue=n] gain -1.0
# successor [Handicapped-infants=?^crime=?] gain -1.0
# successor [Handicapped-infants=?^crime=y] gain -1.0
# successor [Handicapped-infants=?^crime=n] gain 0.0
# successor [Handicapped-infants=?^duty-free-exports=?] gain -1.0
# successor [Handicapped-infants=?^duty-free-exports=y] gain 0.0
# successor [Handicapped-infants=?^duty-free-exports=n] gain -1.0
# successor [Handicapped-infants=?^export-administration-act-south-africa=?] gain -1.0
# successor [Handicapped-infants=?^export-administration-act-south-africa=y] gain -1.0
# successor [Handicapped-infants=?^export-administration-act-south-africa=n] gain -0.0
# best successor: [Handicapped-infants=?^Water-project-cost-sharing=y]
# best replacement: [Handicapped-infants=?^Water-project-cost-sharing=y]
#
# rule [synfuels-corporation-cutback=y^export-administration-act-south-africa=n] replacement: [Handicapped-infants=?^Water-project-cost-sharing=y]
#
# grow replacement for rule 2: [el-salvador-aid=n^Water-project-cost-sharing=y]
# successor [Handicapped-infants=?] gain 89.0
# successor [Handicapped-infants=y] gain -20.0
# successor [Handicapped-infants=n] gain -110.0
# successor [Water-project-cost-sharing=?] gain -15.0
# successor [Water-project-cost-sharing=y] gain -59.0
# successor [Water-project-cost-sharing=n] gain -60.0
# successor [adoption-of-the-budget-resolution=?] gain -0.0
# successor [adoption-of-the-budget-resolution=y] gain -15.0
# successor [adoption-of-the-budget-resolution=n] gain -113.0
# successor [physician-fee-freeze=?] gain 1.0
# successor [physician-fee-freeze=y] gain -128.0
# successor [physician-fee-freeze=n] gain 4.0
# successor [el-salvador-aid=?] gain 0.0
# successor [el-salvador-aid=y] gain -125.0
# successor [el-salvador-aid=n] gain 0.0
# successor [religious-groups-in-schools=?] gain 1.0
# successor [religious-groups-in-schools=y] gain -118.0
# successor [religious-groups-in-schools=n] gain -12.0
# successor [anti-satellite-test-ban=?] gain -4.0
# successor [anti-satellite-test-ban=y] gain -31.0
# successor [anti-satellite-test-ban=n] gain -95.0
# successor [aid-to-nicaraguan-contras=?] gain -6.0
# successor [aid-to-nicaraguan-contras=y] gain -15.0
# successor [aid-to-nicaraguan-contras=n] gain -108.0
# successor [mx-missile=?] gain 0.0
# successor [mx-missile=y] gain -7.0
# successor [mx-missile=n] gain -120.0
# successor [immigration=?] gain -0.0
# successor [immigration=y] gain -75.0
# successor [immigration=n] gain -58.0
# successor [synfuels-corporation-cutback=?] gain -6.0
# successor [synfuels-corporation-cutback=y] gain -14.0
# successor [synfuels-corporation-cutback=n] gain -111.0
# successor [education-spending=?] gain -7.0
# successor [education-spending=y] gain -112.0
# successor [education-spending=n] gain -9.0
# successor [superfund-right-to-sue=?] gain -6.0
# successor [superfund-right-to-sue=y] gain -108.0
# successor [superfund-right-to-sue=n] gain -15.0
# successor [crime=?] gain -4.0
# successor [crime=y] gain -126.0
# successor [crime=n] gain 4.0
# successor [duty-free-exports=?] gain -7.0
# successor [duty-free-exports=y] gain -6.0
# successor [duty-free-exports=n] gain -115.0
# successor [export-administration-act-south-africa=?] gain -10.0
# successor [export-administration-act-south-africa=y] gain -81.0
# successor [export-administration-act-south-africa=n] gain -42.0
# best successor: [Handicapped-infants=?]
# successor [Handicapped-infants=?^Water-project-cost-sharing=?] gain 1.0
# successor [Handicapped-infants=?^Water-project-cost-sharing=y] gain 1.0
# successor [Handicapped-infants=?^Water-project-cost-sharing=n] gain -1.0
# successor [Handicapped-infants=?^adoption-of-the-budget-resolution=?] gain -1.0
# successor [Handicapped-infants=?^adoption-of-the-budget-resolution=y] gain -1.0
# successor [Handicapped-infants=?^adoption-of-the-budget-resolution=n] gain 0.0
# successor [Handicapped-infants=?^physician-fee-freeze=?] gain -1.0
# successor [Handicapped-infants=?^physician-fee-freeze=y] gain -1.0
# successor [Handicapped-infants=?^physician-fee-freeze=n] gain 0.0
# successor [Handicapped-infants=?^el-salvador-aid=?] gain -1.0
# successor [Handicapped-infants=?^el-salvador-aid=y] gain -0.0
# successor [Handicapped-infants=?^el-salvador-aid=n] gain -1.0
# successor [Handicapped-infants=?^religious-groups-in-schools=?] gain -1.0
# successor [Handicapped-infants=?^religious-groups-in-schools=y] gain -1.0
# successor [Handicapped-infants=?^religious-groups-in-schools=n] gain 0.0
# successor [Handicapped-infants=?^anti-satellite-test-ban=?] gain -1.0
# successor [Handicapped-infants=?^anti-satellite-test-ban=y] gain -1.0
# successor [Handicapped-infants=?^anti-satellite-test-ban=n] gain -0.0
# successor [Handicapped-infants=?^aid-to-nicaraguan-contras=?] gain -1.0
# successor [Handicapped-infants=?^aid-to-nicaraguan-contras=y] gain -1.0
# successor [Handicapped-infants=?^aid-to-nicaraguan-contras=n] gain 0.0
# successor [Handicapped-infants=?^mx-missile=?] gain -1.0
# successor [Handicapped-infants=?^mx-missile=y] gain -1.0
# successor [Handicapped-infants=?^mx-missile=n] gain 0.0
# successor [Handicapped-infants=?^immigration=?] gain -1.0
# successor [Handicapped-infants=?^immigration=y] gain -1.0
# successor [Handicapped-infants=?^immigration=n] gain 0.0
# successor [Handicapped-infants=?^synfuels-corporation-cutback=?] gain -1.0
# successor [Handicapped-infants=?^synfuels-corporation-cutback=y] gain 0.0
# successor [Handicapped-infants=?^synfuels-corporation-cutback=n] gain -1.0
# successor [Handicapped-infants=?^education-spending=?] gain -1.0
# successor [Handicapped-infants=?^education-spending=y] gain -1.0
# successor [Handicapped-infants=?^education-spending=n] gain 0.0
# successor [Handicapped-infants=?^superfund-right-to-sue=?] gain -1.0
# successor [Handicapped-infants=?^superfund-right-to-sue=y] gain 0.0
# successor [Handicapped-infants=?^superfund-right-to-sue=n] gain -1.0
# successor [Handicapped-infants=?^crime=?] gain -1.0
# successor [Handicapped-infants=?^crime=y] gain -1.0
# successor [Handicapped-infants=?^crime=n] gain 0.0
# successor [Handicapped-infants=?^duty-free-exports=?] gain -1.0
# successor [Handicapped-infants=?^duty-free-exports=y] gain 0.0
# successor [Handicapped-infants=?^duty-free-exports=n] gain -1.0
# successor [Handicapped-infants=?^export-administration-act-south-africa=?] gain -1.0
# successor [Handicapped-infants=?^export-administration-act-south-africa=y] gain -1.0
# successor [Handicapped-infants=?^export-administration-act-south-africa=n] gain -0.0
# best successor: [Handicapped-infants=?^Water-project-cost-sharing=y]
# best replacement: [Handicapped-infants=?^Water-project-cost-sharing=y]
#
# rule [el-salvador-aid=n^Water-project-cost-sharing=y] replacement: [Handicapped-infants=?^Water-project-cost-sharing=y]
#
# grow replacement for rule 3: [mx-missile=y^anti-satellite-test-ban=n]
# successor [Handicapped-infants=?] gain 93.0
# successor [Handicapped-infants=y] gain -20.0
# successor [Handicapped-infants=n] gain -111.0
# successor [Water-project-cost-sharing=?] gain -15.0
# successor [Water-project-cost-sharing=y] gain -60.0
# successor [Water-project-cost-sharing=n] gain -61.0
# successor [adoption-of-the-budget-resolution=?] gain -0.0
# successor [adoption-of-the-budget-resolution=y] gain -15.0
# successor [adoption-of-the-budget-resolution=n] gain -114.0
# successor [physician-fee-freeze=?] gain 1.0
# successor [physician-fee-freeze=y] gain -130.0
# successor [physician-fee-freeze=n] gain 3.0
# successor [el-salvador-aid=?] gain 0.0
# successor [el-salvador-aid=y] gain -127.0
# successor [el-salvador-aid=n] gain 0.0
# successor [religious-groups-in-schools=?] gain 1.0
# successor [religious-groups-in-schools=y] gain -119.0
# successor [religious-groups-in-schools=n] gain -12.0
# successor [anti-satellite-test-ban=?] gain -4.0
# successor [anti-satellite-test-ban=y] gain -32.0
# successor [anti-satellite-test-ban=n] gain -96.0
# successor [aid-to-nicaraguan-contras=?] gain -6.0
# successor [aid-to-nicaraguan-contras=y] gain -15.0
# successor [aid-to-nicaraguan-contras=n] gain -109.0
# successor [mx-missile=?] gain 0.0
# successor [mx-missile=y] gain -7.0
# successor [mx-missile=n] gain -121.0
# successor [immigration=?] gain -0.0
# successor [immigration=y] gain -76.0
# successor [immigration=n] gain -58.0
# successor [synfuels-corporation-cutback=?] gain -6.0
# successor [synfuels-corporation-cutback=y] gain -14.0
# successor [synfuels-corporation-cutback=n] gain -112.0
# successor [education-spending=?] gain -7.0
# successor [education-spending=y] gain -113.0
# successor [education-spending=n] gain -10.0
# successor [superfund-right-to-sue=?] gain -6.0
# successor [superfund-right-to-sue=y] gain -109.0
# successor [superfund-right-to-sue=n] gain -16.0
# successor [crime=?] gain -4.0
# successor [crime=y] gain -127.0
# successor [crime=n] gain 4.0
# successor [duty-free-exports=?] gain -7.0
# successor [duty-free-exports=y] gain -6.0
# successor [duty-free-exports=n] gain -117.0
# successor [export-administration-act-south-africa=?] gain -10.0
# successor [export-administration-act-south-africa=y] gain -82.0
# successor [export-administration-act-south-africa=n] gain -42.0
# best successor: [Handicapped-infants=?]
# successor [Handicapped-infants=?^Water-project-cost-sharing=?] gain 1.0
# successor [Handicapped-infants=?^Water-project-cost-sharing=y] gain 1.0
# successor [Handicapped-infants=?^Water-project-cost-sharing=n] gain -1.0
# successor [Handicapped-infants=?^adoption-of-the-budget-resolution=?] gain -1.0
# successor [Handicapped-infants=?^adoption-of-the-budget-resolution=y] gain -1.0
# successor [Handicapped-infants=?^adoption-of-the-budget-resolution=n] gain 0.0
# successor [Handicapped-infants=?^physician-fee-freeze=?] gain -1.0
# successor [Handicapped-infants=?^physician-fee-freeze=y] gain -1.0
# successor [Handicapped-infants=?^physician-fee-freeze=n] gain 0.0
# successor [Handicapped-infants=?^el-salvador-aid=?] gain -1.0
# successor [Handicapped-infants=?^el-salvador-aid=y] gain -0.0
# successor [Handicapped-infants=?^el-salvador-aid=n] gain -1.0
# successor [Handicapped-infants=?^religious-groups-in-schools=?] gain -1.0
# successor [Handicapped-infants=?^religious-groups-in-schools=y] gain -1.0
# successor [Handicapped-infants=?^religious-groups-in-schools=n] gain 0.0
# successor [Handicapped-infants=?^anti-satellite-test-ban=?] gain -1.0
# successor [Handicapped-infants=?^anti-satellite-test-ban=y] gain -1.0
# successor [Handicapped-infants=?^anti-satellite-test-ban=n] gain -0.0
# successor [Handicapped-infants=?^aid-to-nicaraguan-contras=?] gain -1.0
# successor [Handicapped-infants=?^aid-to-nicaraguan-contras=y] gain -1.0
# successor [Handicapped-infants=?^aid-to-nicaraguan-contras=n] gain 0.0
# successor [Handicapped-infants=?^mx-missile=?] gain -1.0
# successor [Handicapped-infants=?^mx-missile=y] gain -1.0
# successor [Handicapped-infants=?^mx-missile=n] gain 0.0
# successor [Handicapped-infants=?^immigration=?] gain -1.0
# successor [Handicapped-infants=?^immigration=y] gain -1.0
# successor [Handicapped-infants=?^immigration=n] gain 0.0
# successor [Handicapped-infants=?^synfuels-corporation-cutback=?] gain -1.0
# successor [Handicapped-infants=?^synfuels-corporation-cutback=y] gain 0.0
# successor [Handicapped-infants=?^synfuels-corporation-cutback=n] gain -1.0
# successor [Handicapped-infants=?^education-spending=?] gain -1.0
# successor [Handicapped-infants=?^education-spending=y] gain -1.0
# successor [Handicapped-infants=?^education-spending=n] gain 0.0
# successor [Handicapped-infants=?^superfund-right-to-sue=?] gain -1.0
# successor [Handicapped-infants=?^superfund-right-to-sue=y] gain 0.0
# successor [Handicapped-infants=?^superfund-right-to-sue=n] gain -1.0
# successor [Handicapped-infants=?^crime=?] gain -1.0
# successor [Handicapped-infants=?^crime=y] gain -1.0
# successor [Handicapped-infants=?^crime=n] gain 0.0
# successor [Handicapped-infants=?^duty-free-exports=?] gain -1.0
# successor [Handicapped-infants=?^duty-free-exports=y] gain 0.0
# successor [Handicapped-infants=?^duty-free-exports=n] gain -1.0
# successor [Handicapped-infants=?^export-administration-act-south-africa=?] gain -1.0
# successor [Handicapped-infants=?^export-administration-act-south-africa=y] gain -1.0
# successor [Handicapped-infants=?^export-administration-act-south-africa=n] gain -0.0
# best successor: [Handicapped-infants=?^Water-project-cost-sharing=y]
# best replacement: [Handicapped-infants=?^Water-project-cost-sharing=y]
#
# rule [mx-missile=y^anti-satellite-test-ban=n] replacement: [Handicapped-infants=?^Water-project-cost-sharing=y]
#
# grow replacement for rule 4: [physician-fee-freeze=?^Handicapped-infants=n]
# successor [Handicapped-infants=?] gain 94.0
# successor [Handicapped-infants=y] gain -20.0
# successor [Handicapped-infants=n] gain -111.0
# successor [Water-project-cost-sharing=?] gain -15.0
# successor [Water-project-cost-sharing=y] gain -60.0
# successor [Water-project-cost-sharing=n] gain -61.0
# successor [adoption-of-the-budget-resolution=?] gain -0.0
# successor [adoption-of-the-budget-resolution=y] gain -15.0
# successor [adoption-of-the-budget-resolution=n] gain -114.0
# successor [physician-fee-freeze=?] gain 1.0
# successor [physician-fee-freeze=y] gain -130.0
# successor [physician-fee-freeze=n] gain 3.0
# successor [el-salvador-aid=?] gain 0.0
# successor [el-salvador-aid=y] gain -127.0
# successor [el-salvador-aid=n] gain -0.0
# successor [religious-groups-in-schools=?] gain 1.0
# successor [religious-groups-in-schools=y] gain -119.0
# successor [religious-groups-in-schools=n] gain -12.0
# successor [anti-satellite-test-ban=?] gain -4.0
# successor [anti-satellite-test-ban=y] gain -32.0
# successor [anti-satellite-test-ban=n] gain -96.0
# successor [aid-to-nicaraguan-contras=?] gain -6.0
# successor [aid-to-nicaraguan-contras=y] gain -15.0
# successor [aid-to-nicaraguan-contras=n] gain -110.0
# successor [mx-missile=?] gain 0.0
# successor [mx-missile=y] gain -7.0
# successor [mx-missile=n] gain -121.0
# successor [immigration=?] gain -0.0
# successor [immigration=y] gain -76.0
# successor [immigration=n] gain -58.0
# successor [synfuels-corporation-cutback=?] gain -6.0
# successor [synfuels-corporation-cutback=y] gain -14.0
# successor [synfuels-corporation-cutback=n] gain -112.0
# successor [education-spending=?] gain -7.0
# successor [education-spending=y] gain -113.0
# successor [education-spending=n] gain -10.0
# successor [superfund-right-to-sue=?] gain -6.0
# successor [superfund-right-to-sue=y] gain -110.0
# successor [superfund-right-to-sue=n] gain -16.0
# successor [crime=?] gain -4.0
# successor [crime=y] gain -128.0
# successor [crime=n] gain 4.0
# successor [duty-free-exports=?] gain -7.0
# successor [duty-free-exports=y] gain -6.0
# successor [duty-free-exports=n] gain -117.0
# successor [export-administration-act-south-africa=?] gain -10.0
# successor [export-administration-act-south-africa=y] gain -82.0
# successor [export-administration-act-south-africa=n] gain -42.0
# best successor: [Handicapped-infants=?]
# successor [Handicapped-infants=?^Water-project-cost-sharing=?] gain 1.0
# successor [Handicapped-infants=?^Water-project-cost-sharing=y] gain 1.0
# successor [Handicapped-infants=?^Water-project-cost-sharing=n] gain -1.0
# successor [Handicapped-infants=?^adoption-of-the-budget-resolution=?] gain -1.0
# successor [Handicapped-infants=?^adoption-of-the-budget-resolution=y] gain -1.0
# successor [Handicapped-infants=?^adoption-of-the-budget-resolution=n] gain 0.0
# successor [Handicapped-infants=?^physician-fee-freeze=?] gain -1.0
# successor [Handicapped-infants=?^physician-fee-freeze=y] gain -1.0
# successor [Handicapped-infants=?^physician-fee-freeze=n] gain 0.0
# successor [Handicapped-infants=?^el-salvador-aid=?] gain -1.0
# successor [Handicapped-infants=?^el-salvador-aid=y] gain -0.0
# successor [Handicapped-infants=?^el-salvador-aid=n] gain -1.0
# successor [Handicapped-infants=?^religious-groups-in-schools=?] gain -1.0
# successor [Handicapped-infants=?^religious-groups-in-schools=y] gain -1.0
# successor [Handicapped-infants=?^religious-groups-in-schools=n] gain 0.0
# successor [Handicapped-infants=?^anti-satellite-test-ban=?] gain -1.0
# successor [Handicapped-infants=?^anti-satellite-test-ban=y] gain -1.0
# successor [Handicapped-infants=?^anti-satellite-test-ban=n] gain -0.0
# successor [Handicapped-infants=?^aid-to-nicaraguan-contras=?] gain -1.0
# successor [Handicapped-infants=?^aid-to-nicaraguan-contras=y] gain -1.0
# successor [Handicapped-infants=?^aid-to-nicaraguan-contras=n] gain 0.0
# successor [Handicapped-infants=?^mx-missile=?] gain -1.0
# successor [Handicapped-infants=?^mx-missile=y] gain -1.0
# successor [Handicapped-infants=?^mx-missile=n] gain 0.0
# successor [Handicapped-infants=?^immigration=?] gain -1.0
# successor [Handicapped-infants=?^immigration=y] gain -1.0
# successor [Handicapped-infants=?^immigration=n] gain 0.0
# successor [Handicapped-infants=?^synfuels-corporation-cutback=?] gain -1.0
# successor [Handicapped-infants=?^synfuels-corporation-cutback=y] gain 0.0
# successor [Handicapped-infants=?^synfuels-corporation-cutback=n] gain -1.0
# successor [Handicapped-infants=?^education-spending=?] gain -1.0
# successor [Handicapped-infants=?^education-spending=y] gain -1.0
# successor [Handicapped-infants=?^education-spending=n] gain 0.0
# successor [Handicapped-infants=?^superfund-right-to-sue=?] gain -1.0
# successor [Handicapped-infants=?^superfund-right-to-sue=y] gain 0.0
# successor [Handicapped-infants=?^superfund-right-to-sue=n] gain -1.0
# successor [Handicapped-infants=?^crime=?] gain -1.0
# successor [Handicapped-infants=?^crime=y] gain -1.0
# successor [Handicapped-infants=?^crime=n] gain 0.0
# successor [Handicapped-infants=?^duty-free-exports=?] gain -1.0
# successor [Handicapped-infants=?^duty-free-exports=y] gain 0.0
# successor [Handicapped-infants=?^duty-free-exports=n] gain -1.0
# successor [Handicapped-infants=?^export-administration-act-south-africa=?] gain -1.0
# successor [Handicapped-infants=?^export-administration-act-south-africa=y] gain -1.0
# successor [Handicapped-infants=?^export-administration-act-south-africa=n] gain -0.0
# best successor: [Handicapped-infants=?^Water-project-cost-sharing=y]
# best replacement: [Handicapped-infants=?^Water-project-cost-sharing=y]
#
# rule [physician-fee-freeze=?^Handicapped-infants=n] replacement: [Handicapped-infants=?^Water-project-cost-sharing=y]
#
# grow replacement for rule 5: [adoption-of-the-budget-resolution=?^mx-missile=y]
# successor [Handicapped-infants=?] gain 94.0
# successor [Handicapped-infants=y] gain -20.0
# successor [Handicapped-infants=n] gain -111.0
# successor [Water-project-cost-sharing=?] gain -15.0
# successor [Water-project-cost-sharing=y] gain -60.0
# successor [Water-project-cost-sharing=n] gain -61.0
# successor [adoption-of-the-budget-resolution=?] gain -0.0
# successor [adoption-of-the-budget-resolution=y] gain -15.0
# successor [adoption-of-the-budget-resolution=n] gain -114.0
# successor [physician-fee-freeze=?] gain 1.0
# successor [physician-fee-freeze=y] gain -130.0
# successor [physician-fee-freeze=n] gain 3.0
# successor [el-salvador-aid=?] gain 0.0
# successor [el-salvador-aid=y] gain -127.0
# successor [el-salvador-aid=n] gain -0.0
# successor [religious-groups-in-schools=?] gain 1.0
# successor [religious-groups-in-schools=y] gain -119.0
# successor [religious-groups-in-schools=n] gain -12.0
# successor [anti-satellite-test-ban=?] gain -4.0
# successor [anti-satellite-test-ban=y] gain -32.0
# successor [anti-satellite-test-ban=n] gain -96.0
# successor [aid-to-nicaraguan-contras=?] gain -6.0
# successor [aid-to-nicaraguan-contras=y] gain -15.0
# successor [aid-to-nicaraguan-contras=n] gain -110.0
# successor [mx-missile=?] gain 0.0
# successor [mx-missile=y] gain -7.0
# successor [mx-missile=n] gain -121.0
# successor [immigration=?] gain -0.0
# successor [immigration=y] gain -76.0
# successor [immigration=n] gain -58.0
# successor [synfuels-corporation-cutback=?] gain -6.0
# successor [synfuels-corporation-cutback=y] gain -14.0
# successor [synfuels-corporation-cutback=n] gain -112.0
# successor [education-spending=?] gain -7.0
# successor [education-spending=y] gain -113.0
# successor [education-spending=n] gain -10.0
# successor [superfund-right-to-sue=?] gain -6.0
# successor [superfund-right-to-sue=y] gain -110.0
# successor [superfund-right-to-sue=n] gain -16.0
# successor [crime=?] gain -4.0
# successor [crime=y] gain -127.0
# successor [crime=n] gain 4.0
# successor [duty-free-exports=?] gain -7.0
# successor [duty-free-exports=y] gain -6.0
# successor [duty-free-exports=n] gain -117.0
# successor [export-administration-act-south-africa=?] gain -10.0
# successor [export-administration-act-south-africa=y] gain -82.0
# successor [export-administration-act-south-africa=n] gain -42.0
# best successor: [Handicapped-infants=?]
# successor [Handicapped-infants=?^Water-project-cost-sharing=?] gain 1.0
# successor [Handicapped-infants=?^Water-project-cost-sharing=y] gain 1.0
# successor [Handicapped-infants=?^Water-project-cost-sharing=n] gain -1.0
# successor [Handicapped-infants=?^adoption-of-the-budget-resolution=?] gain -1.0
# successor [Handicapped-infants=?^adoption-of-the-budget-resolution=y] gain -1.0
# successor [Handicapped-infants=?^adoption-of-the-budget-resolution=n] gain 0.0
# successor [Handicapped-infants=?^physician-fee-freeze=?] gain -1.0
# successor [Handicapped-infants=?^physician-fee-freeze=y] gain -1.0
# successor [Handicapped-infants=?^physician-fee-freeze=n] gain 0.0
# successor [Handicapped-infants=?^el-salvador-aid=?] gain -1.0
# successor [Handicapped-infants=?^el-salvador-aid=y] gain -0.0
# successor [Handicapped-infants=?^el-salvador-aid=n] gain -1.0
# successor [Handicapped-infants=?^religious-groups-in-schools=?] gain -1.0
# successor [Handicapped-infants=?^religious-groups-in-schools=y] gain -1.0
# successor [Handicapped-infants=?^religious-groups-in-schools=n] gain 0.0
# successor [Handicapped-infants=?^anti-satellite-test-ban=?] gain -1.0
# successor [Handicapped-infants=?^anti-satellite-test-ban=y] gain -1.0
# successor [Handicapped-infants=?^anti-satellite-test-ban=n] gain -0.0
# successor [Handicapped-infants=?^aid-to-nicaraguan-contras=?] gain -1.0
# successor [Handicapped-infants=?^aid-to-nicaraguan-contras=y] gain -1.0
# successor [Handicapped-infants=?^aid-to-nicaraguan-contras=n] gain 0.0
# successor [Handicapped-infants=?^mx-missile=?] gain -1.0
# successor [Handicapped-infants=?^mx-missile=y] gain -1.0
# successor [Handicapped-infants=?^mx-missile=n] gain 0.0
# successor [Handicapped-infants=?^immigration=?] gain -1.0
# successor [Handicapped-infants=?^immigration=y] gain -1.0
# successor [Handicapped-infants=?^immigration=n] gain 0.0
# successor [Handicapped-infants=?^synfuels-corporation-cutback=?] gain -1.0
# successor [Handicapped-infants=?^synfuels-corporation-cutback=y] gain 0.0
# successor [Handicapped-infants=?^synfuels-corporation-cutback=n] gain -1.0
# successor [Handicapped-infants=?^education-spending=?] gain -1.0
# successor [Handicapped-infants=?^education-spending=y] gain -1.0
# successor [Handicapped-infants=?^education-spending=n] gain 0.0
# successor [Handicapped-infants=?^superfund-right-to-sue=?] gain -1.0
# successor [Handicapped-infants=?^superfund-right-to-sue=y] gain 0.0
# successor [Handicapped-infants=?^superfund-right-to-sue=n] gain -1.0
# successor [Handicapped-infants=?^crime=?] gain -1.0
# successor [Handicapped-infants=?^crime=y] gain -1.0
# successor [Handicapped-infants=?^crime=n] gain 0.0
# successor [Handicapped-infants=?^duty-free-exports=?] gain -1.0
# successor [Handicapped-infants=?^duty-free-exports=y] gain 0.0
# successor [Handicapped-infants=?^duty-free-exports=n] gain -1.0
# successor [Handicapped-infants=?^export-administration-act-south-africa=?] gain -1.0
# successor [Handicapped-infants=?^export-administration-act-south-africa=y] gain -1.0
# successor [Handicapped-infants=?^export-administration-act-south-africa=n] gain -0.0
# best successor: [Handicapped-infants=?^Water-project-cost-sharing=y]
# best replacement: [Handicapped-infants=?^Water-project-cost-sharing=y]
#
# rule [adoption-of-the-budget-resolution=?^mx-missile=y] replacement: [Handicapped-infants=?^Water-project-cost-sharing=y]
#
# grow replacement for rule 6: [physician-fee-freeze=n]
# successor [Handicapped-infants=?] gain 75.0
# successor [Handicapped-infants=y] gain -20.0
# successor [Handicapped-infants=n] gain -106.0
# successor [Water-project-cost-sharing=?] gain -15.0
# successor [Water-project-cost-sharing=y] gain -58.0
# successor [Water-project-cost-sharing=n] gain -59.0
# successor [adoption-of-the-budget-resolution=?] gain -0.0
# successor [adoption-of-the-budget-resolution=y] gain -15.0
# successor [adoption-of-the-budget-resolution=n] gain -107.0
# successor [physician-fee-freeze=?] gain 1.0
# successor [physician-fee-freeze=y] gain -121.0
# successor [physician-fee-freeze=n] gain 4.0
# successor [el-salvador-aid=?] gain 0.0
# successor [el-salvador-aid=y] gain -120.0
# successor [el-salvador-aid=n] gain 0.0
# successor [religious-groups-in-schools=?] gain 1.0
# successor [religious-groups-in-schools=y] gain -114.0
# successor [religious-groups-in-schools=n] gain -12.0
# successor [anti-satellite-test-ban=?] gain -4.0
# successor [anti-satellite-test-ban=y] gain -31.0
# successor [anti-satellite-test-ban=n] gain -92.0
# successor [aid-to-nicaraguan-contras=?] gain -6.0
# successor [aid-to-nicaraguan-contras=y] gain -15.0
# successor [aid-to-nicaraguan-contras=n] gain -104.0
# successor [mx-missile=?] gain 0.0
# successor [mx-missile=y] gain -7.0
# successor [mx-missile=n] gain -115.0
# successor [immigration=?] gain -0.0
# successor [immigration=y] gain -74.0
# successor [immigration=n] gain -57.0
# successor [synfuels-corporation-cutback=?] gain -6.0
# successor [synfuels-corporation-cutback=y] gain -14.0
# successor [synfuels-corporation-cutback=n] gain -107.0
# successor [education-spending=?] gain -7.0
# successor [education-spending=y] gain -107.0
# successor [education-spending=n] gain -9.0
# successor [superfund-right-to-sue=?] gain -6.0
# successor [superfund-right-to-sue=y] gain -104.0
# successor [superfund-right-to-sue=n] gain -15.0
# successor [crime=?] gain -4.0
# successor [crime=y] gain -121.0
# successor [crime=n] gain 4.0
# successor [duty-free-exports=?] gain -7.0

# %%
ripper_clf
