# %%
import pandas as pd
from base import Timer
import line_profiler
import pickle

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.metrics import precision_score, recall_score, accuracy_score

# %%
import ripper

def make_ripper_dataset(dataset_filename, random_state=42):
    # Load df
    df = pd.read_csv(dataset_filename)
    
    # Split
    train, test = train_test_split(df, test_size=.33, random_state=random_state)
    
    return train, test

# %%
def make_ripper(train, class_feat, pos_class, k=2, random_state=42, verbosity=0):
    # Train
    irep_clf = ripper.RIPPER(class_feat=class_feat,pos_class=pos_class, k=k, verbosity=verbosity)
    irep_clf.fit(train, n_discretize_bins=5, seed=random_state)
    return irep_clf

# %%
def score_ripper(ripper_clf, test):
    X_test = test.drop(ripper_clf.class_feat,axis=1)
    y_test = test[class_feat]

    precision = ripper_clf.score(X_test, y_test, precision_score)
    recall = ripper_clf.score(X_test, y_test, recall_score)
    total_conds = ripper_clf.ruleset_.count_conds()
    return precision, recall, total_conds

# %%
from sklearn.tree import DecisionTreeClassifier

def make_tree_dataset(dataset_filename, class_feat, pos_class, n_classes, random_state=42):
    
    # Load df
    df = pd.read_csv(dataset_filename)
    
    # sklearn's Tree (of all things!) doesn't directly take categorical features.
    # One-hot preprocess the data to make it work.
    le = LabelEncoder()
    df_le=df.apply(le.fit_transform)
    enc = OneHotEncoder(sparse=False)
    enc.fit(df_le)
    df_hot=enc.transform(df_le)
    
    # Split
    train, test = train_test_split(df_hot, test_size=.33, random_state=random_state)
    train_X = train[:,n_classes:]
    train_y = train[:,0]
    test_X = test[:,n_classes:]
    test_y = test[:,0]
    
    return train_X, train_y, test_X, test_y

# %%
def make_tree(train_X, train_y, max_depth=None, random_state=42):
    tree = DecisionTreeClassifier(max_depth=max_depth, random_state=random_state)
    tree.fit(train_X, train_y)
    return tree

# %%
def score_tree(tree_clf, test_X, test_y):
    predictions = tree_clf.predict(test_X)
    precision = precision_score(test_y, predictions)
    recall = recall_score(test_y, predictions)
    return precision, recall, tree_clf.tree_.node_count

# %%
import numpy as np
import math

def run_experiment(filename, class_feat, pos_class, n_classes, verbosity=0, seed=42, n_runs=10):
    ripper_precision_list = []
    ripper_recall_list = []
    total_conds_list = []
    ripper_models_list = []
    
    tree_precision_list = []
    tree_recall_list = []
    tree_nodes_list = []
    
    for i in range(n_runs):

        print(f'ripper {i+1} of {n_runs}')

        # Set random_state
        random_state = i+seed
        
        # Run ripper
        train, test = make_ripper_dataset(filename, random_state=random_state)
        ripper_clf = make_ripper(train, class_feat, pos_class, verbosity=verbosity, random_state=random_state)
        ripper_precision, ripper_recall, total_conds = score_ripper(ripper_clf, test)
        
        print(f'tree {i+1} of {n_runs}')
        
        # Run tree
        tree_train_X, tree_train_y, tree_test_X, tree_test_y = make_tree_dataset(filename, class_feat, pos_class, n_classes, random_state=random_state)
        tree_clf = make_tree(tree_train_X, tree_train_y, random_state=random_state)
        tree_precision, tree_recall, tree_nodes = score_tree(tree_clf, tree_test_X, tree_test_y)
        
        ripper_precision_list.append(ripper_precision)
        ripper_recall_list.append(ripper_recall)
        total_conds_list.append(total_conds)
        ripper_models_list.append(ripper_clf) 

        tree_precision_list.append(tree_precision)
        tree_recall_list.append(tree_recall)
        tree_nodes_list.append(tree_nodes)
        
    r_means = (np.mean(ripper_precision_list), np.mean(ripper_recall_list), np.mean(total_conds_list))
    r_meds = (np.median(ripper_precision_list), np.median(ripper_recall_list), np.median(total_conds_list))
    t_means = (np.mean(tree_precision_list), np.mean(tree_recall_list), np.mean(tree_nodes_list))
    t_meds = (np.median(tree_precision_list), np.median(tree_recall_list), np.median(tree_nodes_list))
    print(f'ripper means {r_means}')
    print(f'ripper medians {r_meds}')
    print(f'tree means {t_means}')
    print(f'tree medians {t_meds}')
    
    max_tree_precision_list = []
    max_tree_recall_list = []
    max_tree_nodes_list = []
    
    for i in range(n_runs):
        
        print(f'max-tree {i+1} of {n_runs}')
        
        # Set random state
        random_state = i+seed
        
        # Run max_depth-specified tree
        max_depth = max(1,int(math.log2(np.median(total_conds_list)))) # limit n_nodes to approx n_conds
        tree_train_X, tree_train_y, tree_test_X, tree_test_y = make_tree_dataset(filename, class_feat, pos_class, n_classes, random_state=random_state)
        tree_clf = make_tree(tree_train_X, tree_train_y, max_depth=max_depth, random_state=random_state)
        tree_precision, tree_recall, tree_nodes = score_tree(tree_clf, tree_test_X, tree_test_y)
        tree_precision, tree_recall, tree_nodes

        #irep_precision_list.append(irep_precision)
        #irep_recall_list.append(irep_recall)
        #total_conds_list.append(total_conds)

        max_tree_precision_list.append(tree_precision)
        max_tree_recall_list.append(tree_recall)
        max_tree_nodes_list.append(tree_nodes)
    
    max_t_means = (np.mean(max_tree_precision_list), np.mean(max_tree_recall_list), np.mean(max_tree_nodes_list))
    max_t_meds = (np.median(max_tree_precision_list), np.median(max_tree_recall_list), np.median(max_tree_nodes_list))
 
    print(f'maxtree means {max_t_means}')
    print(f'maxtree medians {max_t_meds}')
    
    print()
    print(ripper_models_list)
    
    return {'r_means':r_means,
            'r_meds':r_meds,
            't_means':t_means,
            't_meds':t_meds,
            'max_t_means':max_t_means,
            'max_t_meds':max_t_meds,
            'r_models':ripper_models_list,
            'n':n_runs
           }

# %%
datasets_path = '../datasets/'
random_state = 42

# %%
# Set up
dataset = 'balance-scale.csv'
filename = datasets_path + dataset
class_feat = 'class'
pos_class = 'B' #???
n_classes = 3
k=2
verbosity=1
n_runs=1

# %%
# Set up
dataset = 'breast-cancer.csv'
filename = datasets_path + dataset
class_feat = 'Recurrence'
pos_class = 'recurrence-events'
n_classes = 2
n_runs=10

timer = Timer()
breast_cancer_results = run_experiment(filename, class_feat, pos_class, n_classes, verbosity=verbosity, seed=42, n_runs=n_runs)
timer.stop()
pickle.dump(breast_cancer_results,open(filename.replace('.csv','.pkl'),'wb'))
breast_cancer_results
# Out:
# ripper 1 of 10
# tree 1 of 10
# ripper 2 of 10
# tree 2 of 10
# ripper 3 of 10
# tree 3 of 10
# ripper 4 of 10
# tree 4 of 10
# ripper 5 of 10
# tree 5 of 10
# ripper 6 of 10
# tree 6 of 10
# ripper 7 of 10
# tree 7 of 10
# ripper 8 of 10
# tree 8 of 10
# ripper 9 of 10
# tree 9 of 10
# ripper 10 of 10
# tree 10 of 10
# ripper means (0.6102525742231625, 0.310242006729118, 4.0)
# ripper medians (0.6066433566433567, 0.26903225806451614, 4.0)
# tree means (0.7573734254388288, 0.7323903419508938, 127.6)
# tree medians (0.7573529411764706, 0.74824016563147, 128.0)
# max-tree 1 of 10
# max-tree 2 of 10
# max-tree 3 of 10
# max-tree 4 of 10
# max-tree 5 of 10
# max-tree 6 of 10
# max-tree 7 of 10
# max-tree 8 of 10
# max-tree 9 of 10
# max-tree 10 of 10
# maxtree means (0.76902223248098, 0.9304058895554647, 7.0)
# maxtree medians (0.7810485001401739, 0.9541744402985075, 7.0)
# {'max_t_means': (0.76902223248098, 0.9304058895554647, 7.0),
#  'max_t_meds': (0.7810485001401739, 0.9541744402985075, 7.0),
#  'n': 10,
#  'r_means': (0.6102525742231625, 0.310242006729118, 4.0),
#  'r_meds': (0.6066433566433567, 0.26903225806451614, 4.0),
#  't_means': (0.7573734254388288, 0.7323903419508938, 127.6),
#  't_meds': (0.7573529411764706, 0.74824016563147, 128.0)}

# %%
# Set up

# Merge good, vgood
dataset = 'car.csv'
filename = datasets_path + dataset
class_feat = 'class'
pos_class = 'recurrence-events'
n_classes = #4, 5
random_state=30

# %%
# Set up
dataset = 'breast-cancer.csv'
filename = datasets_path + dataset
class_feat = 'Recurrence'
pos_class = 'recurrence-events'
n_classes = 2
random_state=30

# %%
# Set up
dataset = 'connect-4.csv'
filename = datasets_path + dataset
class_feat = 'class'
pos_class = 'win'
n_classes = 3
verbosity=2
n_runs=5

timer = Timer()
connect4 = run_experiment(filename, class_feat, pos_class, n_classes, verbosity=verbosity, seed=42, n_runs=n_runs)
timer.stop()
pickle.dump(connect4,open(filename.replace('.csv','.pkl'),'wb'))
connect4
# Out:
# ripper 1 of 5
# updated dl for rule size 1: 4.2241579747998905
# updated dl for rule size 2: 7.942680364767357
# updated dl for rule size 3: 11.070560293584009
# updated dl for rule size 4: 13.862640183419453
# updated dl for rule size 5: 16.4201305410389
# updated dl for rule size 6: 18.79710964463375
# updated dl for rule size 7: 21.027115617291013
# updated dl for rule size 8: 23.13293211968692
# updated dl for rule size 9: 25.131022232519527
# updated dl for rule size 10: 27.033824630984114
# updated dl for rule size 11: 28.851059969264767
# updated dl for rule size 12: 30.590528125204354
# updated dl for rule size 13: 32.25862194855415
# updated dl for rule size 14: 33.860673052123886
# updated dl for rule size 15: 35.40119299814999
# growing ruleset...
#
# pos_growset 19976 pos_pruneset 9839
# neg_growset 10350 neg_pruneset 5098
# grew rule: [a1=o^d1=x^d2=b^c2=b^b1=o^g1=b^a3=b]
# pruned rule unchanged
# updated ruleset: [a1=o^d1=x^d2=b^c2=b^b1=o^g1=b^a3=b]
#
# pos_growset 19870 pos_pruneset 9787
# neg_growset 10350 neg_pruneset 5098
# grew rule: [a1=o^d1=x^a2=o^e1=b^d3=b^b1=b]
# pruned rule unchanged
# updated ruleset: ...[a1=o^d1=x^d2=b^c2=b^b1=o^g1=b^a3=b] V [a1=o^d1=x^a2=o^e1=b^d3=b^b1=b]
#
# pos_growset 19718 pos_pruneset 9712
# neg_growset 10349 neg_pruneset 5098
# grew rule: [a1=o^b1=o^g1=b^a2=b^c2=b^d5=b]
# pruned rule: [a1=o^b1=o^g1=b^a2=b^c2=b]
# updated ruleset: ...[a1=o^d1=x^a2=o^e1=b^d3=b^b1=b] V [a1=o^b1=o^g1=b^a2=b^c2=b]
#
# pos_growset 19529 pos_pruneset 9619
# neg_growset 10346 neg_pruneset 5097
# grew rule: [g1=o^a1=o^b1=o^d3=b^g2=b]
# pruned rule unchanged
# updated ruleset: ...[a1=o^b1=o^g1=b^a2=b^c2=b] V [g1=o^a1=o^b1=o^d3=b^g2=b]
#
# pos_growset 19335 pos_pruneset 9524
# neg_growset 10346 neg_pruneset 5097
# grew rule: [g1=o^g2=o^d1=b^c1=x^g3=b^a2=b^f4=b^a1=b]
# pruned rule: [g1=o^g2=o^d1=b^c1=x^g3=b^a2=b]
# updated ruleset: ...[g1=o^a1=o^b1=o^d3=b^g2=b] V [g1=o^g2=o^d1=b^c1=x^g3=b^a2=b]
#
# pos_growset 19119 pos_pruneset 9417
# neg_growset 10345 neg_pruneset 5096
# grew rule: [a1=o^d1=x^d2=b^a2=o^a4=b^g2=b]
# pruned rule unchanged
# updated ruleset: ...[g1=o^g2=o^d1=b^c1=x^g3=b^a2=b] V [a1=o^d1=x^d2=b^a2=o^a4=b^g2=b]
#
# pos_growset 19003 pos_pruneset 9360
# neg_growset 10344 neg_pruneset 5095
# grew rule: [g1=o^a1=o^b1=b^a2=o]
# pruned rule unchanged
# updated ruleset: ...[a1=o^d1=x^d2=b^a2=o^a4=b^g2=b] V [g1=o^a1=o^b1=b^a2=o]
#
# pos_growset 18909 pos_pruneset 9314
# neg_growset 10343 neg_pruneset 5095
# grew rule: [d1=x^d3=b^d2=x^c3=b^e3=b]
# pruned rule: [d1=x^d3=b^d2=x^c3=b]
# updated ruleset: ...[g1=o^a1=o^b1=b^a2=o] V [d1=x^d3=b^d2=x^c3=b]
#
# pos_growset 18036 pos_pruneset 8884
# neg_growset 10340 neg_pruneset 5094
# grew rule: [a1=o^c2=x^c3=b^d3=b^e1=o^e4=b]
# pruned rule unchanged
# updated ruleset: ...[d1=x^d3=b^d2=x^c3=b] V [a1=o^c2=x^c3=b^d3=b^e1=o^e4=b]
#
# pos_growset 17741 pos_pruneset 8739
# neg_growset 10340 neg_pruneset 5094
# grew rule: [g1=o^b2=x^a1=o^b3=b^d2=b^f3=b^c3=b]
# pruned rule unchanged
# updated ruleset: ...[a1=o^c2=x^c3=b^d3=b^e1=o^e4=b] V [g1=o^b2=x^a1=o^b3=b^d2=b^f3=b^c3=b]
#
# pos_growset 17578 pos_pruneset 8658
# neg_growset 10340 neg_pruneset 5093
# grew rule: [g1=o^b2=x^d1=x^d2=b^e2=b^c3=b^b1=o^f2=b]
# pruned rule: [g1=o^b2=x^d1=x^d2=b^e2=b^c3=b^b1=o]
# updated ruleset: ...[g1=o^b2=x^a1=o^b3=b^d2=b^f3=b^c3=b] V [g1=o^b2=x^d1=x^d2=b^e2=b^c3=b^b1=o]
#
# pos_growset 17433 pos_pruneset 8587
# neg_growset 10339 neg_pruneset 5093
# grew rule: [g1=o^g2=o^d1=b^c1=x^e1=b^b1=x]
# pruned rule unchanged
# updated ruleset: ...[g1=o^b2=x^d1=x^d2=b^e2=b^c3=b^b1=o] V [g1=o^g2=o^d1=b^c1=x^e1=b^b1=x]
#
# pos_growset 17381 pos_pruneset 8561
# neg_growset 10339 neg_pruneset 5093
# grew rule: [a1=o^b1=o^g1=b^a2=o^d3=b]
# pruned rule: [a1=o^b1=o^g1=b^a2=o]
# updated ruleset: ...[g1=o^g2=o^d1=b^c1=x^e1=b^b1=x] V [a1=o^b1=o^g1=b^a2=o]
#
# pos_growset 17259 pos_pruneset 8501
# neg_growset 10337 neg_pruneset 5092
# grew rule: [g1=o^g2=o^d1=b^c1=x^e1=b^b2=b^a2=b]
# pruned rule: [g1=o^g2=o^d1=b^c1=x^e1=b^b2=b]
# updated ruleset: ...[a1=o^b1=o^g1=b^a2=o] V [g1=o^g2=o^d1=b^c1=x^e1=b^b2=b]
#
# pos_growset 17125 pos_pruneset 8435
# neg_growset 10333 neg_pruneset 5090
# grew rule: [a1=o^d1=x^d2=b^g2=o^c2=b]
# pruned rule: [a1=o^d1=x^d2=b^g2=o]
# updated ruleset: ...[g1=o^g2=o^d1=b^c1=x^e1=b^b2=b] V [a1=o^d1=x^d2=b^g2=o]
#
# pos_growset 17003 pos_pruneset 8376
# neg_growset 10331 neg_pruneset 5089
# grew rule: [g1=o^f1=o^a1=b^g2=b^c3=x]
# pruned rule unchanged
# updated ruleset: ...[a1=o^d1=x^d2=b^g2=o] V [g1=o^f1=o^a1=b^g2=b^c3=x]
#
# pos_growset 16947 pos_pruneset 8348
# neg_growset 10331 neg_pruneset 5089
# grew rule: [g1=o^e1=o^c1=o^a1=b^f3=b^d3=b]
# pruned rule: [g1=o^e1=o^c1=o^a1=b]
# updated ruleset: ...[g1=o^f1=o^a1=b^g2=b^c3=x] V [g1=o^e1=o^c1=o^a1=b]
#
# pos_growset 16827 pos_pruneset 8289
# neg_growset 10329 neg_pruneset 5088
# grew rule: [a1=o^d1=x^d2=b^b1=o^c1=o]
# pruned rule unchanged
# updated ruleset: ...[g1=o^e1=o^c1=o^a1=b] V [a1=o^d1=x^d2=b^b1=o^c1=o]
#
# pos_growset 16747 pos_pruneset 8249
# neg_growset 10329 neg_pruneset 5088
# grew rule: [g1=o^d1=b^c1=x^g2=b^a1=b^c5=b^e2=x^f1=b]
# pruned rule: [g1=o^d1=b^c1=x^g2=b^a1=b^c5=b^e2=x]
# updated ruleset: ...[a1=o^d1=x^d2=b^b1=o^c1=o] V [g1=o^d1=b^c1=x^g2=b^a1=b^c5=b^e2=x]
#
# pos_growset 16671 pos_pruneset 8212
# neg_growset 10326 neg_pruneset 5086
# grew rule: [a1=o^b2=x^b3=b^d2=b^c2=b^a2=o^d1=b]
# pruned rule unchanged
# updated ruleset: ...[g1=o^d1=b^c1=x^g2=b^a1=b^c5=b^e2=x] V [a1=o^b2=x^b3=b^d2=b^c2=b^a2=o^d1=b]
#
# pos_growset 16613 pos_pruneset 8183
# neg_growset 10326 neg_pruneset 5086
# grew rule: [g1=o^f1=o^b1=x^c1=x^a1=b]
# pruned rule unchanged
# updated ruleset: ...[a1=o^b2=x^b3=b^d2=b^c2=b^a2=o^d1=b] V [g1=o^f1=o^b1=x^c1=x^a1=b]
#
# pos_growset 16557 pos_pruneset 8156
# neg_growset 10325 neg_pruneset 5086
# grew rule: [a1=o^c2=x^c3=b^d3=b^c1=x^a2=o]
# pruned rule unchanged
# updated ruleset: ...[g1=o^f1=o^b1=x^c1=x^a1=b] V [a1=o^c2=x^c3=b^d3=b^c1=x^a2=o]
#
# pos_growset 16479 pos_pruneset 8118
# neg_growset 10325 neg_pruneset 5086
# grew rule: [g1=o^f1=o^f2=x^a1=o]
# pruned rule unchanged
# updated ruleset: ...[a1=o^c2=x^c3=b^d3=b^c1=x^a2=o] V [g1=o^f1=o^f2=x^a1=o]
#
# pos_growset 16412 pos_pruneset 8084
# neg_growset 10324 neg_pruneset 5086
# grew rule: [a1=o^d1=x^d2=b^a3=o^c2=b^b1=b]
# pruned rule: [a1=o^d1=x^d2=b^a3=o^c2=b]
# updated ruleset: ...[g1=o^f1=o^f2=x^a1=o] V [a1=o^d1=x^d2=b^a3=o^c2=b]
#
# pos_growset 16307 pos_pruneset 8032
# neg_growset 10321 neg_pruneset 5084
# grew rule: [g1=o^g2=o^b1=o^d1=x^e1=b]
# pruned rule: [g1=o^g2=o^b1=o^d1=x]
# updated ruleset: ...[a1=o^d1=x^d2=b^a3=o^c2=b] V [g1=o^g2=o^b1=o^d1=x]
#
# pos_growset 16219 pos_pruneset 7989
# neg_growset 10320 neg_pruneset 5083
# grew rule: [g1=o^e1=o^e2=x^e3=x^b4=b]
# pruned rule: [g1=o^e1=o^e2=x^e3=x]
# updated ruleset: ...[g1=o^g2=o^b1=o^d1=x] V [g1=o^e1=o^e2=x^e3=x]
#
# pos_growset 16135 pos_pruneset 7948
# neg_growset 10319 neg_pruneset 5083
# grew rule: [g1=o^b2=x^f1=o^c1=b^b3=b]
# pruned rule unchanged
# updated ruleset: ...[g1=o^e1=o^e2=x^e3=x] V [g1=o^b2=x^f1=o^c1=b^b3=b]
#
# pos_growset 16088 pos_pruneset 7925
# neg_growset 10319 neg_pruneset 5083
# grew rule: [a1=o^d1=x^b1=b^d2=b^c3=x]
# pruned rule unchanged
# updated ruleset: ...[g1=o^b2=x^f1=o^c1=b^b3=b] V [a1=o^d1=x^b1=b^d2=b^c3=x]
#
# pos_growset 16030 pos_pruneset 7896
# neg_growset 10319 neg_pruneset 5083
# grew rule: [a1=o^b1=o^g1=b^a2=b^b3=b^c2=x^c3=b]
# pruned rule: [a1=o^b1=o^g1=b^a2=b^b3=b]
# updated ruleset: ...[a1=o^d1=x^b1=b^d2=b^c3=x] V [a1=o^b1=o^g1=b^a2=b^b3=b]
#
# pos_growset 15897 pos_pruneset 7831
# neg_growset 10313 neg_pruneset 5080
# grew rule: [g1=o^c3=x^c2=x^d3=b^f2=b^c4=o]
# pruned rule unchanged
# updated ruleset: ...[a1=o^b1=o^g1=b^a2=b^b3=b] V [g1=o^c3=x^c2=x^d3=b^f2=b^c4=o]
#
# pos_growset 15803 pos_pruneset 7785
# neg_growset 10313 neg_pruneset 5080
# grew rule: [a1=o^b2=x^b3=x^d2=b^b1=o]
# pruned rule: [a1=o^b2=x^b3=x]
# updated ruleset: ...[g1=o^c3=x^c2=x^d3=b^f2=b^c4=o] V [a1=o^b2=x^b3=x]
#
# pos_growset 15675 pos_pruneset 7722
# neg_growset 10305 neg_pruneset 5076
# grew rule: [d1=x^d3=x^d2=x]
# pruned rule unchanged
# updated ruleset: ...[a1=o^b2=x^b3=x] V [d1=x^d3=x^d2=x]
#
# pos_growset 15547 pos_pruneset 7658
# neg_growset 10305 neg_pruneset 5076
# grew rule: [g1=o^e1=o^g2=o^g4=b^f1=b^a3=b]
# pruned rule: [g1=o^e1=o^g2=o^g4=b^f1=b]
# updated ruleset: ...[d1=x^d3=x^d2=x] V [g1=o^e1=o^g2=o^g4=b^f1=b]
#
# pos_growset 15471 pos_pruneset 7621
# neg_growset 10304 neg_pruneset 5076
# grew rule: [g1=o^g2=b^b1=o^a1=b^b2=o]
# pruned rule unchanged
# updated ruleset: ...[g1=o^e1=o^g2=o^g4=b^f1=b] V [g1=o^g2=b^b1=o^a1=b^b2=o]
# pos_growset 15401 pos_pruneset 7587
# neg_growset 10304 neg_pruneset 5076
# grew rule: [a1=o^d2=x^d3=b^a3=b^g3=b^e1=b^c3=b^g1=x]
# pruned rule: [a1=o^d2=x^d3=b^a3=b^g3=b^e1=b^c3=b]
# updated ruleset: ...[g1=o^g2=b^b1=o^a1=b^b2=o] V [a1=o^d2=x^d3=b^a3=b^g3=b^e1=b^c3=b]
#
# pos_growset 15275 pos_pruneset 7524
# neg_growset 10301 neg_pruneset 5074
# grew rule: [c2=x^c3=b^d2=b^b1=o^b2=o^a1=b]
# pruned rule: [c2=x^c3=b^d2=b^b1=o^b2=o]
# updated ruleset: ...[a1=o^d2=x^d3=b^a3=b^g3=b^e1=b^c3=b] V [c2=x^c3=b^d2=b^b1=o^b2=o]
#
# pos_growset 15087 pos_pruneset 7431
# neg_growset 10296 neg_pruneset 5072
# grew rule: [d1=x^d2=b^b1=o^c1=o^g1=b^a1=b^c3=b^f5=b]
# pruned rule: [d1=x^d2=b^b1=o^c1=o^g1=b^a1=b^c3=b]
# updated ruleset: ...[c2=x^c3=b^d2=b^b1=o^b2=o] V [d1=x^d2=b^b1=o^c1=o^g1=b^a1=b^c3=b]
#
# pos_growset 15010 pos_pruneset 7394
# neg_growset 10295 neg_pruneset 5072
# grew rule: [a1=o^b1=b^d1=x^d3=x^c1=o]
# pruned rule unchanged
# updated ruleset: ...[d1=x^d2=b^b1=o^c1=o^g1=b^a1=b^c3=b] V [a1=o^b1=b^d1=x^d3=x^c1=o]
#
# pos_growset 14961 pos_pruneset 7370
# neg_growset 10295 neg_pruneset 5072
# grew rule: [g1=o^b2=x^b3=x^b4=o^a1=x]
# pruned rule unchanged
# updated ruleset: ...[a1=o^b1=b^d1=x^d3=x^c1=o] V [g1=o^b2=x^b3=x^b4=o^a1=x]
#
# pos_growset 14936 pos_pruneset 7357
# neg_growset 10295 neg_pruneset 5071
# grew rule: [g1=o^b2=x^g2=o^c1=b^a1=b]
# pruned rule: [g1=o^b2=x^g2=o^c1=b]
# updated ruleset: ...[g1=o^b2=x^b3=x^b4=o^a1=x] V [g1=o^b2=x^g2=o^c1=b]
#
# pos_growset 14871 pos_pruneset 7325
# neg_growset 10291 neg_pruneset 5069
# grew rule: [c3=x^c2=x^d3=b^f2=b^d2=b^b3=b^e4=b]
# pruned rule: [c3=x^c2=x^d3=b^f2=b^d2=b^b3=b]
# updated ruleset: ...[g1=o^b2=x^g2=o^c1=b] V [c3=x^c2=x^d3=b^f2=b^d2=b^b3=b]
#
# pos_growset 14541 pos_pruneset 7162
# neg_growset 10289 neg_pruneset 5069
# grew rule: [g1=o^f2=x^b1=b^f3=b^d3=b^c3=b]
# pruned rule unchanged
# updated ruleset: ...[c3=x^c2=x^d3=b^f2=b^d2=b^b3=b] V [g1=o^f2=x^b1=b^f3=b^d3=b^c3=b]
#
# pos_growset 14441 pos_pruneset 7114
# neg_growset 10287 neg_pruneset 5068
# grew rule: [a1=o^d1=x^a2=o^b1=b^c2=b^g1=b]
# pruned rule unchanged
# updated ruleset: ...[g1=o^f2=x^b1=b^f3=b^d3=b^c3=b] V [a1=o^d1=x^a2=o^b1=b^c2=b^g1=b]
#
# pos_growset 14386 pos_pruneset 7087
# neg_growset 10287 neg_pruneset 5067
# grew rule: [b2=x^f1=o^a1=o^f2=x^b3=b^d2=b]
# pruned rule unchanged
# updated ruleset: ...[a1=o^d1=x^a2=o^b1=b^c2=b^g1=b] V [b2=x^f1=o^a1=o^f2=x^b3=b^d2=b]
#
# pos_growset 14359 pos_pruneset 7073
# neg_growset 10285 neg_pruneset 5067
# grew rule: [b2=x^b3=x^c3=b^f2=b^e2=b^d2=b^g2=b^e1=b]
# pruned rule unchanged
# updated ruleset: ...[b2=x^f1=o^a1=o^f2=x^b3=b^d2=b] V [b2=x^b3=x^c3=b^f2=b^e2=b^d2=b^g2=b^e1=b]
#
# pos_growset 14253 pos_pruneset 7021
# neg_growset 10284 neg_pruneset 5066
# grew rule: [a1=o^b1=b^g1=o^a2=b^c1=x^g2=b^c6=b]
# pruned rule: [a1=o^b1=b^g1=o^a2=b^c1=x^g2=b]
# updated ruleset: ...[b2=x^b3=x^c3=b^f2=b^e2=b^d2=b^g2=b^e1=b] V [a1=o^b1=b^g1=o^a2=b^c1=x^g2=b]
#
# pos_growset 14195 pos_pruneset 6992
# neg_growset 10283 neg_pruneset 5066
# grew rule: [a1=o^d1=x^d2=b^c2=b^e1=b^f1=o]
# pruned rule: [a1=o^d1=x^d2=b^c2=b^e1=b]
# updated ruleset: ...[a1=o^b1=b^g1=o^a2=b^c1=x^g2=b] V [a1=o^d1=x^d2=b^c2=b^e1=b]
#
# pos_growset 14043 pos_pruneset 6917
# neg_growset 10261 neg_pruneset 5055
# grew rule: [f1=o^e1=o^c2=x^c3=b^d3=b^a2=b]
# pruned rule: [f1=o^e1=o^c2=x^c3=b]
# updated ruleset: ...[a1=o^d1=x^d2=b^c2=b^e1=b] V [f1=o^e1=o^c2=x^c3=b]
#
# pos_growset 13905 pos_pruneset 6850
# neg_growset 10259 neg_pruneset 5053
# grew rule: [g1=o^g2=b^a1=b^b1=o^d2=o^d5=b]
# pruned rule: [g1=o^g2=b^a1=b^b1=o^d2=o]
# updated ruleset: ...[f1=o^e1=o^c2=x^c3=b] V [g1=o^g2=b^a1=b^b1=o^d2=o]
#
# pos_growset 13859 pos_pruneset 6827
# neg_growset 10257 neg_pruneset 5053
# grew rule: [g1=o^d1=b^c1=x^f1=x^e1=b^b2=b^g2=b^c3=b]
# pruned rule unchanged
# updated ruleset: ...[g1=o^g2=b^a1=b^b1=o^d2=o] V [g1=o^d1=b^c1=x^f1=x^e1=b^b2=b^g2=b^c3=b]
#
# pos_growset 13814 pos_pruneset 6805
# neg_growset 10255 neg_pruneset 5052
# grew rule: [a1=o^d3=x^d2=x]
# pruned rule unchanged
# updated ruleset: ...[g1=o^d1=b^c1=x^f1=x^e1=b^b2=b^g2=b^c3=b] V [a1=o^d3=x^d2=x]
#
# pos_growset 13688 pos_pruneset 6743
# neg_growset 10255 neg_pruneset 5052
# grew rule: [b2=x^b3=b^d2=b^c3=b^a2=o^d1=b^c2=b^f1=o]
# pruned rule: [b2=x^b3=b^d2=b^c3=b^a2=o^d1=b^c2=b]
# updated ruleset: ...[a1=o^d3=x^d2=x] V [b2=x^b3=b^d2=b^c3=b^a2=o^d1=b^c2=b]
#
# pos_growset 13594 pos_pruneset 6696
# neg_growset 10250 neg_pruneset 5050
# grew rule: [g1=o^f1=o^b1=x^g2=b^a1=b^f3=x]
# pruned rule unchanged
# updated ruleset: ...[b2=x^b3=b^d2=b^c3=b^a2=o^d1=b^c2=b] V [g1=o^f1=o^b1=x^g2=b^a1=b^f3=x]
#
# pos_growset 13579 pos_pruneset 6689
# neg_growset 10250 neg_pruneset 5049
# grew rule: [d1=x^d2=b^b1=o^c2=b^a2=o^c1=o]
# pruned rule unchanged
# updated ruleset: ...[g1=o^f1=o^b1=x^g2=b^a1=b^f3=x] V [d1=x^d2=b^b1=o^c2=b^a2=o^c1=o]
#
# pos_growset 13546 pos_pruneset 6672
# neg_growset 10250 neg_pruneset 5049
# grew rule: [f1=o^e1=o^e3=x^e2=x^f3=b]
# pruned rule unchanged
# updated ruleset: ...[d1=x^d2=b^b1=o^c2=b^a2=o^c1=o] V [f1=o^e1=o^e3=x^e2=x^f3=b]
#
# pos_growset 13455 pos_pruneset 6628
# neg_growset 10250 neg_pruneset 5049
# grew rule: [g1=o^f1=o^b1=x^c1=b^b2=b^g6=b^f4=b^a4=b]
# pruned rule: [g1=o^f1=o^b1=x^c1=b^b2=b]
# updated ruleset: ...[f1=o^e1=o^e3=x^e2=x^f3=b] V [g1=o^f1=o^b1=x^c1=b^b2=b]
#
# pos_growset 13392 pos_pruneset 6597
# neg_growset 10245 neg_pruneset 5047
# grew rule: [g1=o^g2=b^b1=o^a1=b^d3=b^f1=x^e3=b]
# pruned rule: [g1=o^g2=b^b1=o^a1=b^d3=b]
# updated ruleset: ...[g1=o^f1=o^b1=x^c1=b^b2=b] V [g1=o^g2=b^b1=o^a1=b^d3=b]
#
# pos_growset 13244 pos_pruneset 6524
# neg_growset 10230 neg_pruneset 5039
# grew rule: [d1=x^c1=b^d2=b^e1=b^a1=b]
# pruned rule unchanged
# updated ruleset: ...[g1=o^g2=b^b1=o^a1=b^d3=b] V [d1=x^c1=b^d2=b^e1=b^a1=b]
#
# pos_growset 13176 pos_pruneset 6490
# neg_growset 10229 neg_pruneset 5039
# grew rule: [a1=o^b1=b^d1=x^a2=b^e1=b^c2=o^f1=b]
# pruned rule: [a1=o^b1=b^d1=x^a2=b^e1=b^c2=o]
# updated ruleset: ...[d1=x^c1=b^d2=b^e1=b^a1=b] V [a1=o^b1=b^d1=x^a2=b^e1=b^c2=o]
#
# pos_growset 13136 pos_pruneset 6470
# neg_growset 10228 neg_pruneset 5038
# grew rule: [d1=x^d2=b^b1=o^c1=o^a1=b^g1=x^e1=b]
# pruned rule unchanged
# updated ruleset: ...[a1=o^b1=b^d1=x^a2=b^e1=b^c2=o] V [d1=x^d2=b^b1=o^c1=o^a1=b^g1=x^e1=b]
#
# pos_growset 13085 pos_pruneset 6445
# neg_growset 10226 neg_pruneset 5037
# grew rule: [a1=o^b2=x^b3=b^d2=b^c1=o^c2=o^a3=b]
# pruned rule unchanged
# updated ruleset: ...[d1=x^d2=b^b1=o^c1=o^a1=b^g1=x^e1=b] V [a1=o^b2=x^b3=b^d2=b^c1=o^c2=o^a3=b]
#
# pos_growset 13052 pos_pruneset 6430
# neg_growset 10224 neg_pruneset 5037
# grew rule: [a1=o^b1=b^e2=x^d2=b^e3=b^f3=b^a2=b]
# pruned rule: [a1=o^b1=b^e2=x^d2=b^e3=b^f3=b]
# updated ruleset: ...[a1=o^b2=x^b3=b^d2=b^c1=o^c2=o^a3=b] V [a1=o^b1=b^e2=x^d2=b^e3=b^f3=b]
#
# pos_growset 12957 pos_pruneset 6382
# neg_growset 10223 neg_pruneset 5036
# grew rule: [a1=b^d3=x^d2=x^e3=b^b4=b]
# pruned rule: [a1=b^d3=x^d2=x^e3=b]
# updated ruleset: ...[a1=o^b1=b^e2=x^d2=b^e3=b^f3=b] V [a1=b^d3=x^d2=x^e3=b]
#
# pos_growset 12760 pos_pruneset 6285
# neg_growset 10222 neg_pruneset 5036
# grew rule: [b2=x^b3=b^d2=b^c3=b^c1=o^f2=b^e1=o]
# pruned rule: [b2=x^b3=b^d2=b^c3=b^c1=o^f2=b]
# updated ruleset: ...[a1=b^d3=x^d2=x^e3=b] V [b2=x^b3=b^d2=b^c3=b^c1=o^f2=b]
#
# pos_growset 12593 pos_pruneset 6203
# neg_growset 10204 neg_pruneset 5027
# grew rule: [d1=x^d3=x^d4=x^c2=b^d5=b]
# pruned rule: [d1=x^d3=x^d4=x^c2=b]
# updated ruleset: ...[b2=x^b3=b^d2=b^c3=b^c1=o^f2=b] V [d1=x^d3=x^d4=x^c2=b]
#
# pos_growset 12506 pos_pruneset 6161
# neg_growset 10203 neg_pruneset 5026
# grew rule: [f1=o^e1=o^a2=o^c2=b^a1=x^f3=b]
# pruned rule: [f1=o^e1=o^a2=o^c2=b^a1=x]
# updated ruleset: ...[d1=x^d3=x^d4=x^c2=b] V [f1=o^e1=o^a2=o^c2=b^a1=x]
#
# pos_growset 12431 pos_pruneset 6123
# neg_growset 10199 neg_pruneset 5024
# grew rule: [a1=o^a2=o^f2=x^c2=b^f3=b^d2=b]
# pruned rule unchanged
# updated ruleset: ...[f1=o^e1=o^a2=o^c2=b^a1=x] V [a1=o^a2=o^f2=x^c2=b^f3=b^d2=b]
#
# pos_growset 12391 pos_pruneset 6104
# neg_growset 10198 neg_pruneset 5024
# grew rule: [c3=x^b2=x^b3=b^f3=b^d3=b]
# pruned rule: [c3=x^b2=x^b3=b]
# updated ruleset: ...[a1=o^a2=o^f2=x^c2=b^f3=b^d2=b] V [c3=x^b2=x^b3=b]
#
# pos_growset 12266 pos_pruneset 6042
# neg_growset 10196 neg_pruneset 5022
# grew rule: [a1=o^c2=x^c3=b^d3=b^f2=b^b2=b^c1=x]
# pruned rule: [a1=o^c2=x^c3=b^d3=b^f2=b]
# updated ruleset: ...[c3=x^b2=x^b3=b] V [a1=o^c2=x^c3=b^d3=b^f2=b]
#
# pos_growset 12023 pos_pruneset 5923
# neg_growset 10186 neg_pruneset 5017
# grew rule: [f2=x^f3=x^b1=b^c2=b^c1=x^d3=b]
# pruned rule: [f2=x^f3=x^b1=b^c2=b^c1=x]
# updated ruleset: ...[a1=o^c2=x^c3=b^d3=b^f2=b] V [f2=x^f3=x^b1=b^c2=b^c1=x]
# pos_growset 11975 pos_pruneset 5899
# neg_growset 10185 neg_pruneset 5017
# grew rule: [d1=x^c1=b^d2=b^a2=o^b2=b]
# pruned rule: [d1=x^c1=b^d2=b^a2=o]
# updated ruleset: ...[f2=x^f3=x^b1=b^c2=b^c1=x] V [d1=x^c1=b^d2=b^a2=o]
#
# pos_growset 11873 pos_pruneset 5848
# neg_growset 10181 neg_pruneset 5015
# grew rule: [e1=o^c2=x^c3=b^d3=b^e3=b^f3=b^e2=b^a2=b]
# pruned rule unchanged
# updated ruleset: ...[d1=x^c1=b^d2=b^a2=o] V [e1=o^c2=x^c3=b^d3=b^e3=b^f3=b^e2=b^a2=b]
#
# pos_growset 11767 pos_pruneset 5796
# neg_growset 10179 neg_pruneset 5015
# grew rule: [f1=o^f2=x^f3=x^c2=b^b2=b^d1=b^e2=b^g3=b]
# pruned rule: [f1=o^f2=x^f3=x^c2=b^b2=b^d1=b^e2=b]
# updated ruleset: ...[e1=o^c2=x^c3=b^d3=b^e3=b^f3=b^e2=b^a2=b] V [f1=o^f2=x^f3=x^c2=b^b2=b^d1=b^e2=b]
#
# pos_growset 11690 pos_pruneset 5759
# neg_growset 10178 neg_pruneset 5014
# grew rule: [c3=x^c2=x^d3=b^g1=b^d1=x]
# pruned rule: [c3=x^c2=x^d3=b^g1=b]
# updated ruleset: ...[f1=o^f2=x^f3=x^c2=b^b2=b^d1=b^e2=b] V [c3=x^c2=x^d3=b^g1=b]
#
# pos_growset 11530 pos_pruneset 5679
# neg_growset 10170 neg_pruneset 5010
# grew rule: [a1=b^f1=o^e1=o^c1=x^d1=o^g2=b]
# pruned rule unchanged
# updated ruleset: ...[c3=x^c2=x^d3=b^g1=b] V [a1=b^f1=o^e1=o^c1=x^d1=o^g2=b]
#
# pos_growset 11501 pos_pruneset 5665
# neg_growset 10170 neg_pruneset 5010
# grew rule: [d1=x^d3=x^d4=b^c2=b^a1=o^e1=b]
# pruned rule: [d1=x^d3=x^d4=b^c2=b^a1=o]
# updated ruleset: ...[a1=b^f1=o^e1=o^c1=x^d1=o^g2=b] V [d1=x^d3=x^d4=b^c2=b^a1=o]
#
# pos_growset 11434 pos_pruneset 5632
# neg_growset 10169 neg_pruneset 5009
# grew rule: [g1=o^d1=b^c1=x^g3=o^b1=x]
# pruned rule unchanged
# updated ruleset: ...[d1=x^d3=x^d4=b^c2=b^a1=o] V [g1=o^d1=b^c1=x^g3=o^b1=x]
#
# pos_growset 11390 pos_pruneset 5611
# neg_growset 10168 neg_pruneset 5009
# grew rule: [g1=o^d1=b^c1=x^b1=b^f1=b^e1=x]
# pruned rule unchanged
# updated ruleset: ...[g1=o^d1=b^c1=x^g3=o^b1=x] V [g1=o^d1=b^c1=x^b1=b^f1=b^e1=x]
#
# pos_growset 11342 pos_pruneset 5587
# neg_growset 10168 neg_pruneset 5009
# grew rule: [f1=o^e1=o^c1=x^c2=b^g1=b^a1=b^e3=b^f4=b^b5=b]
# pruned rule: [f1=o^e1=o^c1=x^c2=b^g1=b^a1=b]
# updated ruleset: ...[g1=o^d1=b^c1=x^b1=b^f1=b^e1=x] V [f1=o^e1=o^c1=x^c2=b^g1=b^a1=b]
#
# pos_growset 11285 pos_pruneset 5559
# neg_growset 10161 neg_pruneset 5006
# grew rule: [g1=o^e1=o^g2=b^a2=o^a6=b^c2=b]
# pruned rule unchanged
# updated ruleset: ...[f1=o^e1=o^c1=x^c2=b^g1=b^a1=b] V [g1=o^e1=o^g2=b^a2=o^a6=b^c2=b]
#
# pos_growset 11254 pos_pruneset 5544
# neg_growset 10161 neg_pruneset 5005
# grew rule: [d1=x^c1=b^a1=b^e1=b^b1=x]
# pruned rule unchanged
# updated ruleset: ...[g1=o^e1=o^g2=b^a2=o^a6=b^c2=b] V [d1=x^c1=b^a1=b^e1=b^b1=x]
#
# pos_growset 11144 pos_pruneset 5490
# neg_growset 10161 neg_pruneset 5005
# grew rule: [g1=o^f1=o^a1=b^b1=b^c4=b^d2=o]
# pruned rule unchanged
# updated ruleset: ...[d1=x^c1=b^a1=b^e1=b^b1=x] V [g1=o^f1=o^a1=b^b1=b^c4=b^d2=o]
#
# pos_growset 11126 pos_pruneset 5480
# neg_growset 10161 neg_pruneset 5005
# grew rule: [d1=x^d2=b^c2=b^b1=o^b2=x^a1=x]
# pruned rule unchanged
# updated ruleset: ...[g1=o^f1=o^a1=b^b1=b^c4=b^d2=o] V [d1=x^d2=b^c2=b^b1=o^b2=x^a1=x]
#
# pos_growset 11092 pos_pruneset 5464
# neg_growset 10160 neg_pruneset 5005
# grew rule: [e1=o^e3=x^e2=x^d2=b^b2=b^f3=b^d1=b^c3=b]
# pruned rule: [e1=o^e3=x^e2=x^d2=b^b2=b]
# updated ruleset: ...[d1=x^d2=b^c2=b^b1=o^b2=x^a1=x] V [e1=o^e3=x^e2=x^d2=b^b2=b]
#
# pos_growset 10952 pos_pruneset 5395
# neg_growset 10156 neg_pruneset 5003
# grew rule: [g1=o^e1=o^g2=b^a2=b^d1=o^a1=b]
# pruned rule unchanged
# updated ruleset: ...[e1=o^e3=x^e2=x^d2=b^b2=b] V [g1=o^e1=o^g2=b^a2=b^d1=o^a1=b]
#
# pos_growset 10924 pos_pruneset 5381
# neg_growset 10156 neg_pruneset 5003
# grew rule: [g1=o^e1=o^a2=o^a3=b^g3=b]
# pruned rule: [g1=o^e1=o^a2=o^a3=b]
# updated ruleset: ...[g1=o^e1=o^g2=b^a2=b^d1=o^a1=b] V [g1=o^e1=o^a2=o^a3=b]
#
# pos_growset 10888 pos_pruneset 5364
# neg_growset 10155 neg_pruneset 5002
# grew rule: [g1=o^d1=b^c1=x^e1=b^b1=b^c3=x^f2=b^a3=b]
# pruned rule: [g1=o^d1=b^c1=x^e1=b^b1=b^c3=x]
# updated ruleset: ...[g1=o^e1=o^a2=o^a3=b] V [g1=o^d1=b^c1=x^e1=b^b1=b^c3=x]
#
# pos_growset 10843 pos_pruneset 5342
# neg_growset 10153 neg_pruneset 5001
# grew rule: [f1=o^e1=o^g2=o^g3=b^c1=x^f3=b]
# pruned rule: [f1=o^e1=o^g2=o^g3=b^c1=x]
# updated ruleset: ...[g1=o^d1=b^c1=x^e1=b^b1=b^c3=x] V [f1=o^e1=o^g2=o^g3=b^c1=x]
#
# pos_growset 10811 pos_pruneset 5325
# neg_growset 10152 neg_pruneset 5001
# grew rule: [a1=o^b2=x^b1=o^g1=b^d2=b^c2=b]
# pruned rule unchanged
# updated ruleset: ...[f1=o^e1=o^g2=o^g3=b^c1=x] V [a1=o^b2=x^b1=o^g1=b^d2=b^c2=b]
#
# pos_growset 10784 pos_pruneset 5313
# neg_growset 10151 neg_pruneset 5001
# grew rule: [a1=o^b2=x^b3=b^d2=b^c3=b^f2=b^c2=b^e3=b^a5=b^b1=x]
# pruned rule: [a1=o^b2=x^b3=b^d2=b^c3=b^f2=b^c2=b^e3=b]
# updated ruleset: ...[a1=o^b2=x^b1=o^g1=b^d2=b^c2=b] V [a1=o^b2=x^b3=b^d2=b^c3=b^f2=b^c2=b^e3=b]
#
# pos_growset 10716 pos_pruneset 5279
# neg_growset 10144 neg_pruneset 4997
# grew rule: [a1=b^b1=o^g1=b^c3=b^c1=b^e1=x]
# pruned rule unchanged
# updated ruleset: ...[a1=o^b2=x^b3=b^d2=b^c3=b^f2=b^c2=b^e3=b] V [a1=b^b1=o^g1=b^c3=b^c1=b^e1=x]
#
# pos_growset 10679 pos_pruneset 5260
# neg_growset 10143 neg_pruneset 4996
# grew rule: [a1=b^f1=o^g1=b^e1=b^c3=x^c4=x^b3=b]
# pruned rule: [a1=b^f1=o^g1=b^e1=b^c3=x]
# updated ruleset: ...[a1=b^b1=o^g1=b^c3=b^c1=b^e1=x] V [a1=b^f1=o^g1=b^e1=b^c3=x]
#
# pos_growset 10612 pos_pruneset 5228
# neg_growset 10131 neg_pruneset 4990
# grew rule: [f2=x^d1=x^d2=b^b1=b^e1=b^a1=b]
# pruned rule unchanged
# updated ruleset: ...[a1=b^f1=o^g1=b^e1=b^c3=x] V [f2=x^d1=x^d2=b^b1=b^e1=b^a1=b]
#
# pos_growset 10586 pos_pruneset 5215
# neg_growset 10129 neg_pruneset 4989
# grew rule: [f2=x^a2=o^c2=b^c1=x^f1=x^e1=b]
# pruned rule: [f2=x^a2=o^c2=b^c1=x]
# updated ruleset: ...[f2=x^d1=x^d2=b^b1=b^e1=b^a1=b] V [f2=x^a2=o^c2=b^c1=x]
#
# pos_growset 10536 pos_pruneset 5190
# neg_growset 10119 neg_pruneset 4985
# grew rule: [g1=o^f1=o^g2=b^a2=b^e1=b^c1=b^f3=b]
# pruned rule unchanged
# updated ruleset: ...[f2=x^a2=o^c2=b^c1=x] V [g1=o^f1=o^g2=b^a2=b^e1=b^c1=b^f3=b]
#
# pos_growset 10523 pos_pruneset 5183
# neg_growset 10119 neg_pruneset 4984
# grew rule: [g1=o^e1=o^g2=b^f1=b^c1=o^c2=b]
# pruned rule unchanged
# updated ruleset: ...[g1=o^f1=o^g2=b^a2=b^e1=b^c1=b^f3=b] V [g1=o^e1=o^g2=b^f1=b^c1=o^c2=b]
#
# pos_growset 10502 pos_pruneset 5174
# neg_growset 10117 neg_pruneset 4984
# grew rule: [e1=o^f1=o^a2=b^g1=b^a1=x^b1=x^e5=b^b4=b]
# pruned rule: [e1=o^f1=o^a2=b^g1=b^a1=x^b1=x]
# updated ruleset: ...[g1=o^e1=o^g2=b^f1=b^c1=o^c2=b] V [e1=o^f1=o^a2=b^g1=b^a1=x^b1=x]
#
# pos_growset 10464 pos_pruneset 5155
# neg_growset 10114 neg_pruneset 4983
# grew rule: [g1=o^d1=b^c1=x^a1=b^g2=b^e1=b^b1=x]
# pruned rule unchanged
# updated ruleset: ...[e1=o^f1=o^a2=b^g1=b^a1=x^b1=x] V [g1=o^d1=b^c1=x^a1=b^g2=b^e1=b^b1=x]
#
# pos_growset 10425 pos_pruneset 5135
# neg_growset 10114 neg_pruneset 4983
# grew rule: [g1=o^d1=b^c1=x^g3=o^c3=b^g4=b^f1=b]
# pruned rule: [g1=o^d1=b^c1=x^g3=o^c3=b^g4=b]
# updated ruleset: ...[g1=o^d1=b^c1=x^a1=b^g2=b^e1=b^b1=x] V [g1=o^d1=b^c1=x^g3=o^c3=b^g4=b]
#
# pos_growset 10371 pos_pruneset 5109
# neg_growset 10111 neg_pruneset 4981
# grew rule: [a1=o^d2=x^d3=b^e1=o^a2=b^g3=b]
# pruned rule: [a1=o^d2=x^d3=b^e1=o]
# updated ruleset: ...[g1=o^d1=b^c1=x^g3=o^c3=b^g4=b] V [a1=o^d2=x^d3=b^e1=o]
#
# pos_growset 10302 pos_pruneset 5075
# neg_growset 10106 neg_pruneset 4979
# grew rule: [g1=o^e1=o^g2=b^a2=b^f1=b^e3=x]
# pruned rule unchanged
# updated ruleset: ...[a1=o^d2=x^d3=b^e1=o] V [g1=o^e1=o^g2=b^a2=b^f1=b^e3=x]
#
# pos_growset 10283 pos_pruneset 5065
# neg_growset 10106 neg_pruneset 4979
# grew rule: [g2=o^d1=b^g3=o^g4=x^b1=x^b3=b]
# pruned rule: [g2=o^d1=b^g3=o^g4=x^b1=x]
# updated ruleset: ...[g1=o^e1=o^g2=b^a2=b^f1=b^e3=x] V [g2=o^d1=b^g3=o^g4=x^b1=x]
#
# pos_growset 10244 pos_pruneset 5046
# neg_growset 10104 neg_pruneset 4978
# grew rule: [d1=x^d3=x^d4=b^c2=x^c3=b]
# pruned rule unchanged
# updated ruleset: ...[g2=o^d1=b^g3=o^g4=x^b1=x] V [d1=x^d3=x^d4=b^c2=x^c3=b]
#
# pos_growset 10212 pos_pruneset 5030
# neg_growset 10104 neg_pruneset 4978
# grew rule: [b1=o^c1=o^d1=x^d3=x^c3=b^g1=b]
# pruned rule: [b1=o^c1=o^d1=x^d3=x]
# updated ruleset: ...[d1=x^d3=x^d4=b^c2=x^c3=b] V [b1=o^c1=o^d1=x^d3=x]
#
# pos_growset 10166 pos_pruneset 5008
# neg_growset 10103 neg_pruneset 4977
# grew rule: [f2=x^b1=o^d1=o^c1=x^f1=o^d3=b]
# pruned rule unchanged
# updated ruleset: ...[b1=o^c1=o^d1=x^d3=x] V [f2=x^b1=o^d1=o^c1=x^f1=o^d3=b]
#
# pos_growset 10117 pos_pruneset 4984
# neg_growset 10102 neg_pruneset 4977
# grew rule: [g1=o^f1=o^g2=b^b1=x^d1=b^b2=b]
# pruned rule unchanged
# updated ruleset: ...[f2=x^b1=o^d1=o^c1=x^f1=o^d3=b] V [g1=o^f1=o^g2=b^b1=x^d1=b^b2=b]
# pos_growset 10102 pos_pruneset 4976
# neg_growset 10100 neg_pruneset 4976
# grew rule: [a1=o^c3=x^c4=b^b1=o^b2=b]
# pruned rule: [a1=o^c3=x^c4=b^b1=o]
# updated ruleset: ...[g1=o^f1=o^g2=b^b1=x^d1=b^b2=b] V [a1=o^c3=x^c4=b^b1=o]
#
# pos_growset 10074 pos_pruneset 4962
# neg_growset 10098 neg_pruneset 4975
# grew rule: [a1=o^a2=o^d1=b^b1=b^c2=b^f1=b]
# pruned rule unchanged
# updated ruleset: ...[a1=o^c3=x^c4=b^b1=o] V [a1=o^a2=o^d1=b^b1=b^c2=b^f1=b]
#
# pos_growset 10052 pos_pruneset 4951
# neg_growset 10098 neg_pruneset 4975
# grew rule: [a1=b^f1=o^e1=o^g1=b^f2=b^c1=x^e5=b]
# pruned rule: [a1=b^f1=o^e1=o]
# updated ruleset: ...[a1=o^a2=o^d1=b^b1=b^c2=b^f1=b] V [a1=b^f1=o^e1=o]
#
#
# GREW INITIAL RULESET:
# [[a1=o^d1=x^d2=b^c2=b^b1=o^g1=b^a3=b] V
# [a1=o^d1=x^a2=o^e1=b^d3=b^b1=b] V
# [a1=o^b1=o^g1=b^a2=b^c2=b] V
# [g1=o^a1=o^b1=o^d3=b^g2=b] V
# [g1=o^g2=o^d1=b^c1=x^g3=b^a2=b] V
# [a1=o^d1=x^d2=b^a2=o^a4=b^g2=b] V
# [g1=o^a1=o^b1=b^a2=o] V
# [d1=x^d3=b^d2=x^c3=b] V
# [a1=o^c2=x^c3=b^d3=b^e1=o^e4=b] V
# [g1=o^b2=x^a1=o^b3=b^d2=b^f3=b^c3=b] V
# [g1=o^b2=x^d1=x^d2=b^e2=b^c3=b^b1=o] V
# [g1=o^g2=o^d1=b^c1=x^e1=b^b1=x] V
# [a1=o^b1=o^g1=b^a2=o] V
# [g1=o^g2=o^d1=b^c1=x^e1=b^b2=b] V
# [a1=o^d1=x^d2=b^g2=o] V
# [g1=o^f1=o^a1=b^g2=b^c3=x] V
# [g1=o^e1=o^c1=o^a1=b] V
# [a1=o^d1=x^d2=b^b1=o^c1=o] V
# [g1=o^d1=b^c1=x^g2=b^a1=b^c5=b^e2=x] V
# [a1=o^b2=x^b3=b^d2=b^c2=b^a2=o^d1=b] V
# [g1=o^f1=o^b1=x^c1=x^a1=b] V
# [a1=o^c2=x^c3=b^d3=b^c1=x^a2=o] V
# [g1=o^f1=o^f2=x^a1=o] V
# [a1=o^d1=x^d2=b^a3=o^c2=b] V
# [g1=o^g2=o^b1=o^d1=x] V
# [g1=o^e1=o^e2=x^e3=x] V
# [g1=o^b2=x^f1=o^c1=b^b3=b] V
# [a1=o^d1=x^b1=b^d2=b^c3=x] V
# [a1=o^b1=o^g1=b^a2=b^b3=b] V
# [g1=o^c3=x^c2=x^d3=b^f2=b^c4=o] V
# [a1=o^b2=x^b3=x] V
# [d1=x^d3=x^d2=x] V
# [g1=o^e1=o^g2=o^g4=b^f1=b] V
# [g1=o^g2=b^b1=o^a1=b^b2=o] V
# [a1=o^d2=x^d3=b^a3=b^g3=b^e1=b^c3=b] V
# [c2=x^c3=b^d2=b^b1=o^b2=o] V
# [d1=x^d2=b^b1=o^c1=o^g1=b^a1=b^c3=b] V
# [a1=o^b1=b^d1=x^d3=x^c1=o] V
# [g1=o^b2=x^b3=x^b4=o^a1=x] V
# [g1=o^b2=x^g2=o^c1=b] V
# [c3=x^c2=x^d3=b^f2=b^d2=b^b3=b] V
# [g1=o^f2=x^b1=b^f3=b^d3=b^c3=b] V
# [a1=o^d1=x^a2=o^b1=b^c2=b^g1=b] V
# [b2=x^f1=o^a1=o^f2=x^b3=b^d2=b] V
# [b2=x^b3=x^c3=b^f2=b^e2=b^d2=b^g2=b^e1=b] V
# [a1=o^b1=b^g1=o^a2=b^c1=x^g2=b] V
# [a1=o^d1=x^d2=b^c2=b^e1=b] V
# [f1=o^e1=o^c2=x^c3=b] V
# [g1=o^g2=b^a1=b^b1=o^d2=o] V
# [g1=o^d1=b^c1=x^f1=x^e1=b^b2=b^g2=b^c3=b] V
# [a1=o^d3=x^d2=x] V
# [b2=x^b3=b^d2=b^c3=b^a2=o^d1=b^c2=b] V
# [g1=o^f1=o^b1=x^g2=b^a1=b^f3=x] V
# [d1=x^d2=b^b1=o^c2=b^a2=o^c1=o] V
# [f1=o^e1=o^e3=x^e2=x^f3=b] V
# [g1=o^f1=o^b1=x^c1=b^b2=b] V
# [g1=o^g2=b^b1=o^a1=b^d3=b] V
# [d1=x^c1=b^d2=b^e1=b^a1=b] V
# [a1=o^b1=b^d1=x^a2=b^e1=b^c2=o] V
# [d1=x^d2=b^b1=o^c1=o^a1=b^g1=x^e1=b] V
# [a1=o^b2=x^b3=b^d2=b^c1=o^c2=o^a3=b] V
# [a1=o^b1=b^e2=x^d2=b^e3=b^f3=b] V
# [a1=b^d3=x^d2=x^e3=b] V
# [b2=x^b3=b^d2=b^c3=b^c1=o^f2=b] V
# [d1=x^d3=x^d4=x^c2=b] V
# [f1=o^e1=o^a2=o^c2=b^a1=x] V
# [a1=o^a2=o^f2=x^c2=b^f3=b^d2=b] V
# [c3=x^b2=x^b3=b] V
# [a1=o^c2=x^c3=b^d3=b^f2=b] V
# [f2=x^f3=x^b1=b^c2=b^c1=x] V
# [d1=x^c1=b^d2=b^a2=o] V
# [e1=o^c2=x^c3=b^d3=b^e3=b^f3=b^e2=b^a2=b] V
# [f1=o^f2=x^f3=x^c2=b^b2=b^d1=b^e2=b] V
# [c3=x^c2=x^d3=b^g1=b] V
# [a1=b^f1=o^e1=o^c1=x^d1=o^g2=b] V
# [d1=x^d3=x^d4=b^c2=b^a1=o] V
# [g1=o^d1=b^c1=x^g3=o^b1=x] V
# [g1=o^d1=b^c1=x^b1=b^f1=b^e1=x] V
# [f1=o^e1=o^c1=x^c2=b^g1=b^a1=b] V
# [g1=o^e1=o^g2=b^a2=o^a6=b^c2=b] V
# [d1=x^c1=b^a1=b^e1=b^b1=x] V
# [g1=o^f1=o^a1=b^b1=b^c4=b^d2=o] V
# [d1=x^d2=b^c2=b^b1=o^b2=x^a1=x] V
# [e1=o^e3=x^e2=x^d2=b^b2=b] V
# [g1=o^e1=o^g2=b^a2=b^d1=o^a1=b] V
# [g1=o^e1=o^a2=o^a3=b] V
# [g1=o^d1=b^c1=x^e1=b^b1=b^c3=x] V
# [f1=o^e1=o^g2=o^g3=b^c1=x] V
# [a1=o^b2=x^b1=o^g1=b^d2=b^c2=b] V
# [a1=o^b2=x^b3=b^d2=b^c3=b^f2=b^c2=b^e3=b] V
# [a1=b^b1=o^g1=b^c3=b^c1=b^e1=x] V
# [a1=b^f1=o^g1=b^e1=b^c3=x] V
# [f2=x^d1=x^d2=b^b1=b^e1=b^a1=b] V
# [f2=x^a2=o^c2=b^c1=x] V
# [g1=o^f1=o^g2=b^a2=b^e1=b^c1=b^f3=b] V
# [g1=o^e1=o^g2=b^f1=b^c1=o^c2=b] V
# [e1=o^f1=o^a2=b^g1=b^a1=x^b1=x] V
# [g1=o^d1=b^c1=x^a1=b^g2=b^e1=b^b1=x] V
# [g1=o^d1=b^c1=x^g3=o^c3=b^g4=b] V
# [a1=o^d2=x^d3=b^e1=o] V
# [g1=o^e1=o^g2=b^a2=b^f1=b^e3=x] V
# [g2=o^d1=b^g3=o^g4=x^b1=x] V
# [d1=x^d3=x^d4=b^c2=x^c3=b] V
# [b1=o^c1=o^d1=x^d3=x] V
# [f2=x^b1=o^d1=o^c1=x^f1=o^d3=b] V
# [g1=o^f1=o^g2=b^b1=x^d1=b^b2=b] V
# [a1=o^c3=x^c4=b^b1=o] V
# [a1=o^a2=o^d1=b^b1=b^c2=b^f1=b] V
# [a1=b^f1=o^e1=o]]
#
# optimization run 1 of 2
# optimizing ruleset...
#
# grew rule: [a1=o^d1=x^a2=o^b1=b^c2=b^e1=b]
# grew rule: [a1=o^d1=x^d2=b^c2=b^b1=o^g1=b^a3=b]
#
# rule 1 of 109
# original: [a1=o^d1=x^d2=b^c2=b^b1=o^g1=b^a3=b]
# replacement: [a1=o]
# revision: [a1=o]
# *best: unchanged
#
# grew rule: [a1=o^d1=x^a2=o^b1=b^c2=b^e1=b]
# grew rule: [a1=o^d1=x^a2=o^e1=b^d3=b^b1=b^c2=b]
#
# rule 2 of 109
# original: [a1=o^d1=x^a2=o^e1=b^d3=b^b1=b]
# replacement: [a1=o]
# revision: [a1=o]
# *best: unchanged
#
# grew rule: [a1=o^d1=x^b1=o^c1=b^f1=x]
# grew rule: [a1=o^b1=o^g1=b^a2=b^c2=b^d3=b]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-baa7d4542ce6> in <module>()
#       9
#      10 timer = Timer()
# ---> 11 connect4 = run_experiment(filename, class_feat, pos_class, n_classes, verbosity=verbosity, seed=42, n_runs=n_runs)
#      12 timer.stop()
#      13 pickle.dump(connect4,open(filename.replace('.csv','.pkl'),'wb'))
#
# <ipython-input-33-83cfba31dd8c> in run_experiment(filename, class_feat, pos_class, n_classes, verbosity, seed, n_runs)
#      21         # Run ripper
#      22         train, test = make_ripper_dataset(filename, random_state=random_state)
# ---> 23         ripper_clf = make_ripper(train, class_feat, pos_class, verbosity=verbosity, random_state=random_state)
#      24         ripper_precision, ripper_recall, total_conds = score_ripper(ripper_clf, test)
#      25
#
# <ipython-input-4-d40489e9d975> in make_ripper(train, class_feat, pos_class, k, random_state, verbosity)
#       2     # Train
#       3     irep_clf = ripper.RIPPER(class_feat=class_feat,pos_class=pos_class, k=k, verbosity=verbosity)
# ----> 4     irep_clf.fit(train, n_discretize_bins=5, seed=random_state)
#       5     return irep_clf
#
# ~/Documents/Metis/Projects/ruleset/ruleset/ripper.py in fit(self, df, n_discretize_bins, seed)
#     106             # Run optimization iteration
#     107             if self.verbosity>=1: print(f'optimization run {iter+1} of {self.k}')
# --> 108             newset = self.optimize_ruleset(self.ruleset_, pos_df, neg_df, prune_size=self.prune_size, seed=iter_seed)
#     109
#     110             if self.verbosity>=1:
#
# ~/Documents/Metis/Projects/ruleset/ruleset/ripper.py in optimize_ruleset(self, ruleset, pos_df, neg_df, prune_size, seed)
#     303             if self.verbosity>=3: print(f'calculate potential dl for ds with revision {pr_revision}')
#     304             revision_dl = rs_total_bits(revision_ruleset, original_ruleset.possible_conds, pos_df, neg_df, bestsubset_dl=True, verbosity=self.verbosity)\
# --> 305                           if pr_revision!=rule else original_dl
#     306             best_rule = [rule, pr_replacement, pr_revision][base.argmin([original_dl, replacement_dl, revision_dl])]
#     307
#
# ~/Documents/Metis/Projects/ruleset/ruleset/ripper.py in rs_total_bits(ruleset, possible_conds, pos_df, neg_df, bestsubset_dl, ret_bestsubset, verbosity)
#     438             rule_theory_dl = r_theory_bits(rule, possible_conds, verbosity=verbosity)
#     439             theory_dl += rule_theory_dl
# --> 440             exceptions_dl = exceptions_bits(subset, pos_df, neg_df, verbosity=verbosity)
#     441             subset_dls.append(theory_dl + exceptions_dl)
#     442             if verbosity>=5: print(f'subset 0-{i} | dl: {rnd(subset_dls[i])}')
#
# ~/Documents/Metis/Projects/ruleset/ruleset/ripper.py in exceptions_bits(ruleset, pos_df, neg_df, verbosity)
#     400     p = ruleset.num_covered(pos_df) + ruleset.num_covered(neg_df) # Total number of examples classified as positive = total covered
#     401     fp = ruleset.num_covered(neg_df)                              # Number false positives = negatives covered by the ruleset
# --> 402     fn = len(pos_df) - ruleset.num_covered(pos_df)                # Number false negatives = positives not covered by the ruleset
#     403     exceptions_dl = math.log2(base.nCr(p,fp)) + math.log2(base.nCr((N-p),fn))
#     404     if verbosity>=5: print(f'exceptions_bits| {ruleset.truncstr()}: \n N {N} p {p} fp {fp} fn {fn}: exceptions_bits {rnd(exceptions_dl)}')
#
# ~/Documents/Metis/Projects/ruleset/ruleset/base.py in num_covered(self, df)
#      82
#      83     def num_covered(self, df):
# ---> 84         return len(self.covers(df))
#      85
#      86     def add(self, rule):
#
# ~/Documents/Metis/Projects/ruleset/ruleset/base.py in covers(self, df)
#      77             covered = self.rules[0].covers(df).copy()
#      78             for rule in self.rules[1:]:
# ---> 79                 covered = covered.append(rule.covers(df))
#      80             covered = covered.drop_duplicates()
#      81             return covered
#
# ~/Documents/Metis/Projects/ruleset/ruleset/base.py in covers(self, df)
#     135     def covers(self, df):
#     136         """ Returns instances covered by the Rule. """
# --> 137         covered = df.copy()
#     138         for cond in self.conds:
#     139             covered = cond.covers(covered)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in copy(self, deep)
#    4024         copy : type of caller
#    4025         """
# -> 4026         data = self._data.copy(deep=deep)
#    4027         return self._constructor(data).__finalize__(self)
#    4028
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in copy(self, deep, mgr)
#    3662             new_axes = list(self.axes)
#    3663         return self.apply('copy', axes=new_axes, deep=deep,
# -> 3664                           do_integrity_check=False)
#    3665
#    3666     def as_matrix(self, items=None):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3327
#    3328             kwargs['mgr'] = self
# -> 3329             applied = getattr(b, f)(**kwargs)
#    3330             result_blocks = _extend_blocks(applied, result_blocks)
#    3331
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in copy(self, deep, mgr)
#     734         values = self.values
#     735         if deep:
# --> 736             values = values.copy()
#     737         return self.make_block_same_class(values)
#     738
#
# KeyboardInterrupt:

# %%
# Set up
dataset = 'house-votes-84.csv'
filename = datasets_path + dataset
class_feat = 'Party'
pos_class = 'democrat'
n_classes = 2
verbosity=0
n_runs=10

timer = Timer()
congress_results = run_experiment(filename, class_feat, pos_class, n_classes, verbosity=verbosity, seed=42, n_runs=n_runs)
timer.stop()
pickle.dump(congress_results,open(filename.replace('.csv','.pkl'),'wb'))
congress_results
# Out:
# ripper 1 of 10
# tree 1 of 10
# ripper 2 of 10
# tree 2 of 10
# ripper 3 of 10
# tree 3 of 10
# ripper 4 of 10
# tree 4 of 10
# ripper 5 of 10
# tree 5 of 10
# ripper 6 of 10
# tree 6 of 10
# ripper 7 of 10
# tree 7 of 10
# ripper 8 of 10
# tree 8 of 10
# ripper 9 of 10
# tree 9 of 10
# ripper 10 of 10
# tree 10 of 10
# ripper means (0.9822343858411969, 0.8574556909273443, 2.9)
# ripper medians (0.9869275461380724, 0.8539714151827553, 3.0)
# tree means (0.9541566437840467, 0.9564409277290078, 39.8)
# tree medians (0.9612237420615535, 0.9662878787878788, 40.0)
# max-tree 1 of 10
# max-tree 2 of 10
# max-tree 3 of 10
# max-tree 4 of 10
# max-tree 5 of 10
# max-tree 6 of 10
# max-tree 7 of 10
# max-tree 8 of 10
# max-tree 9 of 10
# max-tree 10 of 10
# maxtree means (0.9798652374805726, 0.9582411320379064, 3.0)
# maxtree medians (0.9826122672508215, 0.9562828475871954, 3.0)
#
# [<RIPPER object fit ruleset=[physician-fee-freeze=n]>, <RIPPER object fit ruleset=[physician-fee-freeze=n] V [synfuels-corporation-cutback=y^mx-missile=y] V [education-spending=n^physician-fee-freeze=?]>, <RIPPER object fit ruleset=[physician-fee-freeze=n] V [adoption-of-the-budget-resolution=y^anti-satellite-test-ban=n^Water-project-cost-sharing=y] V [synfuels-corporation-cutback=y^mx-missile=y]>, <RIPPER object fit ruleset=[physician-fee-freeze=n] V [synfuels-corporation-cutback=y^adoption-of-the-budget-resolution=y^anti-satellite-test-ban=n]>, <RIPPER object fit ruleset=[physician-fee-freeze=n] V [synfuels-corporation-cutback=y^adoption-of-the-budget-resolution=y]>, <RIPPER object fit ruleset=[physician-fee-freeze=n]>, <RIPPER object fit ruleset=[physician-fee-freeze=n] V [synfuels-corporation-cutback=y^adoption-of-the-budget-resolution=y]>, <RIPPER object fit ruleset=[physician-fee-freeze=n]>, <RIPPER object fit ruleset=[physician-fee-freeze=n]>, <RIPPER object fit ruleset=[physician-fee-freeze=n] V [adoption-of-the-budget-resolution=y^anti-satellite-test-ban=n^Water-project-cost-sharing=y]>]
# {'max_t_means': (0.9798652374805726, 0.9582411320379064, 3.0),
#  'max_t_meds': (0.9826122672508215, 0.9562828475871954, 3.0),
#  'n': 10,
#  'r_means': (0.9822343858411969, 0.8574556909273443, 2.9),
#  'r_meds': (0.9869275461380724, 0.8539714151827553, 3.0),
#  'r_models': [<RIPPER object fit ruleset=[physician-fee-freeze=n]>,
#   <RIPPER object fit ruleset=[physician-fee-freeze=n] V [synfuels-corporation-cutback=y^mx-missile=y] V [education-spending=n^physician-fee-freeze=?]>,
#   <RIPPER object fit ruleset=[physician-fee-freeze=n] V [adoption-of-the-budget-resolution=y^anti-satellite-test-ban=n^Water-project-cost-sharing=y] V [synfuels-corporation-cutback=y^mx-missile=y]>,
#   <RIPPER object fit ruleset=[physician-fee-freeze=n] V [synfuels-corporation-cutback=y^adoption-of-the-budget-resolution=y^anti-satellite-test-ban=n]>,
#   <RIPPER object fit ruleset=[physician-fee-freeze=n] V [synfuels-corporation-cutback=y^adoption-of-the-budget-resolution=y]>,
#   <RIPPER object fit ruleset=[physician-fee-freeze=n]>,
#   <RIPPER object fit ruleset=[physician-fee-freeze=n] V [synfuels-corporation-cutback=y^adoption-of-the-budget-resolution=y]>,
#   <RIPPER object fit ruleset=[physician-fee-freeze=n]>,
#   <RIPPER object fit ruleset=[physician-fee-freeze=n]>,
#   <RIPPER object fit ruleset=[physician-fee-freeze=n] V [adoption-of-the-budget-resolution=y^anti-satellite-test-ban=n^Water-project-cost-sharing=y]>],
#  't_means': (0.9541566437840467, 0.9564409277290078, 39.8),
#  't_meds': (0.9612237420615535, 0.9662878787878788, 40.0)}

# %%
congress_results['r_models'][0].ruleset_
# Out:
# <Ruleset object: [physician-fee-freeze=n]>

# %%
timer = Timer()
results = run_experiment(filename, class_feat, pos_class, n_classes, verbosity=verbosity, seed=42, n_runs=1)
pickle.dump(results,open(filename.replace('.csv','.pkl'),'wb'))
timer.buzz()

# %%
# Set up
dataset = 'kr-vs-kp.csv'
filename = datasets_path + dataset
class_feat = 'won/lost'
pos_class = 'won'
n_classes = 2
k=2
verbosity=1
n_runs=5

timer = Timer()
chess_results = run_experiment(filename, class_feat, pos_class, n_classes, verbosity=verbosity, seed=42, n_runs=n_runs)
pickle.dump(chess_results,open(filename.replace('.csv','.pkl'),'wb'))
timer.stop()
chess_results
# Out:
# ripper 1 of 5
#
# GREW INITIAL RULESET:
# [[10=f^33=f^35=t^6=t] V
# [10=f^33=f^35=t^23=f^13=l^15=n] V
# [15=w^31=t^1=f^10=f] V
# [10=f^33=f^32=f^15=w] V
# [7=f^18=f^26=f^27=f^2=f] V
# [7=f^18=f^33=t^2=t^36=t] V
# [7=f^31=t^15=w^1=f] V
# [7=f^10=f^33=f^35=t^15=n^23=f] V
# [8=f^1=t^11=t^34=t^33=f] V
# [8=f^18=f^7=f^2=f^10=t] V
# [7=f^31=t^18=f^24=f^20=f] V
# [8=f^32=f^33=f^10=f^6=t] V
# [7=f^32=f^8=f^5=t^10=t] V
# [7=f^10=f^34=f^16=f^32=f^27=f^4=f^33=t^30=f^3=f^20=f] V
# [7=f^32=f^6=f^17=t^12=t^10=f] V
# [34=t^35=t^33=f^10=f^15=n^7=t] V
# [7=f^32=f^10=f^18=f^31=t^9=t] V
# [7=f^2=f^8=f^24=f^10=t^36=t^33=t] V
# [7=f^17=t^33=f^10=f] V
# [8=f^36=t^13=l^5=f^18=t^12=f^34=t^23=f^26=f^2=f^10=t] V
# [7=f^32=f^31=t^22=t] V
# [7=f^36=t^13=l^10=f^9=t^26=t^24=f] V
# [36=t^30=t^7=f^34=f^6=t] V
# [26=f^34=t^33=f^6=f^5=t^24=t]]
#
# optimization run 1 of 2
#
# OPTIMIZED RULESET:
# [[10=f^33=f^35=t^6=t] V
# [10=f^33=f^35=t^18=f] V
# [15=w^31=t^1=f] V
# [10=f^33=f^32=f^15=w] V
# [7=f^18=f^36=t^27=f^24=f^10=f] V
# [7=f^18=f^33=t^2=t^36=t] V
# [7=f^31=t^15=w^1=f] V
# [33=f^10=f^35=t^15=n^23=f] V
# [8=f^1=t^11=t^34=t^33=f] V
# [7=f^31=t^22=t] V
# [7=f^31=t^18=f^24=f^20=f] V
# [8=f^32=f^33=f^10=f^6=t] V
# [7=f^32=f^8=f^5=t^10=t] V
# [7=f^10=f^34=f^16=f^32=f^27=f^4=f^33=t^30=f] V
# [34=t^35=t^33=f^10=f^15=n^7=t] V
# [34=t^35=t^33=f^10=f^15=n^7=t] V
# [7=f^36=t^13=l^5=f^34=t^12=f^10=t^6=f^26=f] V
# [7=f^2=f^8=f^24=f^10=t^36=t^33=t] V
# [7=f^17=t^33=f^10=f] V
# [8=f^36=t^13=l^5=f^18=t^12=f^34=t^23=f^26=f^2=f^10=t] V
# [7=f^32=f^31=t^22=t] V
# [7=f^36=t^13=l^10=f^9=t^26=t^24=f] V
# [6=t^33=f^10=f] V
# [26=f^34=t^33=f^6=f^5=t^24=t]]
#
# optimization run 2 of 2
#
# OPTIMIZED RULESET:
# [[10=f^33=f^35=t^6=t] V
# [10=f^33=f^35=t^18=f] V
# [15=w^31=t^1=f] V
# [10=f^33=f^32=f^15=w] V
# [7=f^18=f^36=t^27=f^24=f^10=f] V
# [7=f^18=f^33=t^2=t^36=t] V
# [7=f^31=t^15=w^1=f] V
# [33=f^10=f^35=t^15=n^23=f] V
# [8=f^1=t^11=t^34=t^33=f] V
# [7=f^31=t^22=t^12=f^24=t] V
# [9=f^18=f^2=f^10=t] V
# [7=f^18=f^2=f^26=f^9=f^16=f^27=f] V
# [7=f^32=f^8=f^5=t^10=t] V
# [7=f^10=f^34=f^16=f^32=f^27=f^4=f^33=t^30=f] V
# [34=t^35=t^33=f^10=f^15=n^7=t] V
# [34=t^35=t^33=f^10=f^15=n^7=t] V
# [7=f^36=t^13=l^5=f^34=t^12=f^10=t^6=f^26=f] V
# [7=f^2=f^8=f^24=f^10=t^36=t^33=t] V
# [7=f^17=t^33=f^10=f] V
# [8=f^36=t^13=l^5=f^18=t^12=f^34=t^23=f^26=f^2=f^10=t] V
# [7=f^32=f^31=t^22=t] V
# [7=f^36=t^13=l^10=f^9=t^26=t^24=f] V
# [6=t^33=f^10=f] V
# [7=f^35=t^34=t^18=f^2=f^8=f]]
#
# GREW FINAL RULES
# [[10=f^33=f^35=t^6=t] V
# [10=f^33=f^35=t^18=f] V
# [15=w^31=t^1=f] V
# [10=f^33=f^32=f^15=w] V
# [7=f^18=f^36=t^27=f^24=f^10=f] V
# [7=f^18=f^33=t^2=t^36=t] V
# [7=f^31=t^15=w^1=f] V
# [33=f^10=f^35=t^15=n^23=f] V
# [8=f^1=t^11=t^34=t^33=f] V
# [7=f^31=t^22=t^12=f^24=t] V
# [9=f^18=f^2=f^10=t] V
# [7=f^18=f^2=f^26=f^9=f^16=f^27=f] V
# [7=f^32=f^8=f^5=t^10=t] V
# [7=f^10=f^34=f^16=f^32=f^27=f^4=f^33=t^30=f] V
# [34=t^35=t^33=f^10=f^15=n^7=t] V
# [34=t^35=t^33=f^10=f^15=n^7=t] V
# [7=f^36=t^13=l^5=f^34=t^12=f^10=t^6=f^26=f] V
# [7=f^2=f^8=f^24=f^10=t^36=t^33=t] V
# [7=f^17=t^33=f^10=f] V
# [8=f^36=t^13=l^5=f^18=t^12=f^34=t^23=f^26=f^2=f^10=t] V
# [7=f^32=f^31=t^22=t] V
# [7=f^36=t^13=l^10=f^9=t^26=t^24=f] V
# [6=t^33=f^10=f] V
# [7=f^35=t^34=t^18=f^2=f^8=f] V
# [10=f^33=f^35=t^6=t] V
# [10=f^33=f^35=t^23=f^13=l^15=n] V
# [15=w^31=t^1=f^10=f] V
# [10=f^33=f^32=f^15=w] V
# [7=f^18=f^26=f^27=f^2=f]]
#
# FINAL RULESET:
# [[10=f^33=f^35=t^6=t] V
# [10=f^33=f^35=t^18=f] V
# [15=w^31=t^1=f] V
# [10=f^33=f^32=f^15=w] V
# [7=f^18=f^36=t^27=f^24=f^10=f] V
# [33=f^10=f^35=t^15=n^23=f] V
# [8=f^1=t^11=t^34=t^33=f] V
# [7=f^31=t^22=t^12=f^24=t] V
# [9=f^18=f^2=f^10=t] V
# [7=f^18=f^2=f^26=f^9=f^16=f^27=f] V
# [7=f^32=f^8=f^5=t^10=t] V
# [7=f^10=f^34=f^16=f^32=f^27=f^4=f^33=t^30=f] V
# [7=f^17=t^33=f^10=f] V
# [6=t^33=f^10=f]]
#
# tree 1 of 5
# ripper 2 of 5
#
# GREW INITIAL RULESET:
# [[33=f^10=f^35=t^6=t] V
# [10=f^33=f^35=t^13=l^18=f] V
# [10=f^33=f^32=f^15=w] V
# [7=f^10=f^33=f^35=t^15=n^23=f] V
# [18=f^7=f^33=t^24=f^36=t^27=f] V
# [7=f^18=f^33=t^6=f^30=f^2=f^24=t] V
# [31=t^15=w] V
# [8=f^18=f^24=f^6=t^35=f] V
# [33=f^10=f^32=f^6=t] V
# [7=f^18=f^26=f^16=f^24=t^12=t] V
# [7=f^18=f^26=f^16=f^10=f^36=n] V
# [7=f^1=t^34=t^11=t^13=g] V
# [7=f^26=f^33=f^5=t^8=f] V
# [33=f^35=t^10=f^15=n^7=t] V
# [7=f^18=f^6=f^11=t^5=t] V
# [7=f^12=t^33=f^31=t^9=f] V
# [7=f^36=t^10=t^33=t^8=f] V
# [7=f^17=t^10=f^33=f] V
# [7=f^31=t^10=f^11=t^4=f^1=t] V
# [8=f^6=t^33=f^24=f^5=t] V
# [7=f^16=f^8=f^6=t^4=f^10=f^34=f] V
# [7=f^12=t^24=f^6=t^13=l] V
# [8=f^7=f^24=f^18=f^2=f^10=t] V
# [7=f^32=f^6=f^1=t] V
# [7=f^33=t^22=t^13=l^26=t] V
# [35=t^34=t^33=f^11=f^6=f^23=f^12=f^24=t] V
# [9=f^35=t^24=f^2=f^18=f^4=t] V
# [9=f^5=f^24=f^13=g^10=t^6=t^23=f^11=t] V
# [9=f^24=f^18=f^10=f^2=t] V
# [35=t^5=f^34=t^9=f^23=f^10=f^1=t] V
# [26=f^18=f^22=t^2=t] V
# [35=t^34=t^10=t^13=g^24=f^26=f^12=t^33=f]]
#
# optimization run 1 of 2
#
# OPTIMIZED RULESET:
# [[33=f^10=f^35=t^6=t] V
# [10=f^33=f^35=t^13=l^18=f] V
# [10=f^33=f^32=f^15=w] V
# [7=f^10=f^33=f^35=t^15=n^23=f] V
# [18=f^7=f^33=t^24=f^36=t^27=f] V
# [7=f^18=f^33=t^6=f^30=f^2=f^24=t] V
# [8=f^11=t^1=t^33=f] V
# [8=f^11=t^10=f^33=f^6=t] V
# [33=f^10=f^32=f^6=t] V
# [7=f^18=f^26=f^16=f^24=t^12=t] V
# [7=f^18=f^26=f^16=f^10=f^36=n] V
# [34=t^35=t^33=f^10=f^15=n^7=t] V
# [7=f^26=f^33=f^5=t^8=f] V
# [33=f^35=t^10=f^15=n^7=t] V
# [7=f^31=t^22=t^33=t] V
# [7=f^12=t^33=f^31=t^9=f] V
# [7=f^36=t^10=t^33=t^8=f] V
# [7=f^17=t^10=f^33=f] V
# [7=f^18=f^9=f^2=f^10=t] V
# [7=f^18=f^36=t^22=t^2=t] V
# [7=f^18=f^36=t^16=f^30=f^2=f^33=f] V
# [7=f^12=t^24=f^6=t^13=l] V
# [8=f^7=f^24=f^18=f^2=f^10=t] V
# [8=f^7=f^16=f^31=t^9=t^33=t] V
# [7=f^33=t^22=t^13=l^26=t] V
# [35=t^34=t^33=f^11=f^6=f^23=f^12=f^24=t] V
# [9=f^35=t^24=f^2=f^18=f^4=t] V
# [9=f^5=f^24=f^13=g^10=t^6=t^23=f^11=t] V
# [9=f^24=f^18=f^10=f^2=t] V
# [35=t^5=f^34=t^9=f^23=f^10=f^1=t] V
# [9=f^26=f^16=f^6=t^18=f^2=f^36=n] V
# [35=t^34=t^10=t^13=g^24=f^26=f^12=t^33=f]]
#
# optimization run 2 of 2
#
# OPTIMIZED RULESET:
# [[33=f^10=f^35=t^6=t] V
# [10=f^33=f^35=t^13=l^18=f] V
# [10=f^33=f^32=f^15=w] V
# [7=f^10=f^33=f^35=t^15=n^23=f] V
# [18=f^7=f^33=t^16=f^27=f^10=f] V
# [31=t^15=w] V
# [8=f^11=t^1=t^33=f] V
# [31=t^15=w^7=f] V
# [7=f^18=f^31=t^15=w] V
# [7=f^18=f^31=t^15=w] V
# [7=f^31=t^15=w] V
# [7=f^31=t^15=w] V
# [7=f^31=t^15=w] V
# [7=f^31=t^15=w] V
# [7=f^31=t^15=w] V
# [7=f^18=f^31=t^15=w] V
# [7=f^18=f^31=t^15=w] V
# [7=f^17=t^10=f^33=f] V
# [7=f^18=f^31=t^15=w] V
# [7=f^15=w^31=t] V
# [15=w^31=t] V
# [15=w^31=t] V
# [15=w^31=t^7=f] V
# [15=w^31=t^7=f] V
# [15=w^31=t^7=f] V
# [9=f^31=t^15=w] V
# [15=w^31=t] V
# [15=w^31=t^7=f] V
# [31=t^15=w^7=f] V
# [15=w^31=t^7=f] V
# [15=w^31=t^7=f] V
# [15=w^31=t^7=f]]
#
# GREW FINAL RULES
# [[33=f^10=f^35=t^6=t] V
# [10=f^33=f^35=t^13=l^18=f] V
# [10=f^33=f^32=f^15=w] V
# [7=f^10=f^33=f^35=t^15=n^23=f] V
# [18=f^7=f^33=t^16=f^27=f^10=f] V
# [31=t^15=w] V
# [8=f^11=t^1=t^33=f] V
# [31=t^15=w^7=f] V
# [7=f^18=f^31=t^15=w] V
# [7=f^18=f^31=t^15=w] V
# [7=f^31=t^15=w] V
# [7=f^31=t^15=w] V
# [7=f^31=t^15=w] V
# [7=f^31=t^15=w] V
# [7=f^31=t^15=w] V
# [7=f^18=f^31=t^15=w] V
# [7=f^18=f^31=t^15=w] V
# [7=f^17=t^10=f^33=f] V
# [7=f^18=f^31=t^15=w] V
# [7=f^15=w^31=t] V
# [15=w^31=t] V
# [15=w^31=t] V
# [15=w^31=t^7=f] V
# [15=w^31=t^7=f] V
# [15=w^31=t^7=f] V
# [9=f^31=t^15=w] V
# [15=w^31=t] V
# [15=w^31=t^7=f] V
# [31=t^15=w^7=f] V
# [15=w^31=t^7=f] V
# [15=w^31=t^7=f] V
# [15=w^31=t^7=f] V
# [33=f^10=f^35=t^6=t] V
# [10=f^33=f^35=t^13=l^18=f] V
# [10=f^33=f^32=f^15=w] V
# [7=f^10=f^33=f^35=t^15=n^23=f] V
# [18=f^7=f^33=t^24=f^36=t^27=f] V
# [7=f^18=f^33=t^6=f^30=f^2=f^24=t] V
# [31=t^15=w] V
# [8=f^18=f^24=f^6=t^35=f]]
#
# FINAL RULESET:
# [[33=f^10=f^35=t^6=t] V
# [10=f^33=f^35=t^13=l^18=f] V
# [10=f^33=f^32=f^15=w] V
# [7=f^10=f^33=f^35=t^15=n^23=f] V
# [18=f^7=f^33=t^16=f^27=f^10=f] V
# [31=t^15=w] V
# [8=f^11=t^1=t^33=f] V
# [7=f^17=t^10=f^33=f] V
# [18=f^7=f^33=t^24=f^36=t^27=f]]
#
# tree 2 of 5
# ripper 3 of 5
#
# GREW INITIAL RULESET:
# [[33=f^10=f^35=t^6=t] V
# [33=f^10=f^35=t^15=n^23=f] V
# [15=w^31=t^1=f] V
# [10=f^11=t^15=w] V
# [7=f^18=f^36=t^27=f^10=f] V
# [7=f^18=f^2=f^27=f^8=f^20=f^24=f] V
# [7=f^17=t^10=f^33=f] V
# [7=f^11=t^10=f^9=t^33=t] V
# [8=f^1=t^11=t^33=f^14=f] V
# [8=f^6=t^33=f^10=f] V
# [9=f^26=f^10=t^33=t^36=t] V
# [7=f^35=t^8=f^2=f^13=l^26=t^18=f^27=f] V
# [9=f^35=t^2=f^7=f^10=t^5=t] V
# [5=f^6=t^16=f^10=f^33=f] V
# [9=f^7=f^2=f^18=f^10=t] V
# [5=f^33=t^10=f^11=f^13=l^26=t^9=t] V
# [9=f^35=t^24=f^17=t^11=t^12=t] V
# [9=f^5=f^33=t^10=f^27=f^16=f^34=f^3=f^12=f^7=f] V
# [35=t^34=t^5=f^10=f^13=l^9=t^36=t^24=t] V
# [9=f^35=t^12=t^10=f^36=n^26=f^13=l]]
#
# optimization run 1 of 2
#
# OPTIMIZED RULESET:
# [[33=f^10=f^35=t^6=t] V
# [33=f^10=f^35=t^15=n^23=f] V
# [15=w^31=t^1=f] V
# [10=f^11=t^15=w^33=f] V
# [7=f^18=f^10=f^4=f^24=f^2=t] V
# [7=f^18=f^2=f^9=f^10=t] V
# [7=f^17=t^10=f^33=f] V
# [7=f^11=t^10=f^9=t^33=t] V
# [8=f^1=t^11=t^33=f^14=f] V
# [6=t^33=f^10=f] V
# [9=f^26=f^10=t^33=t^36=t^7=f] V
# [7=f^35=t^8=f^2=f^13=l^26=t^18=f^27=f] V
# [9=f^35=t^2=f^7=f^10=t^5=t] V
# [5=f^6=t^16=f^10=f^33=f] V
# [9=f^7=f^2=f^18=f^10=t] V
# [5=f^33=t^10=f^11=f^13=l^26=t^9=t] V
# [9=f^33=t^18=f^7=f^4=f^10=f^27=f^16=f^20=f] V
# [9=f^5=f^33=t^10=f^27=f^16=f^34=f^3=f^12=f^7=f] V
# [35=t^34=t^5=f^10=f^13=l^9=t^36=t^24=t] V
# [9=f^35=t^12=t^10=f^36=n^26=f^13=l]]
#
# optimization run 2 of 2
# OPTIMIZED RULESET:
# [[33=f^10=f^35=t^6=t] V
# [33=f^10=f^35=t^15=n^23=f] V
# [15=w^31=t^1=f] V
# [10=f^11=t^15=w^33=f] V
# [7=f^18=f^10=f^4=f^24=f] V
# [7=f^18=f^2=f^9=f^27=f^35=t^24=f] V
# [7=f^17=t^10=f^33=f] V
# [7=f^18=f^10=f^27=f^33=t^16=f] V
# [8=f^1=t^11=t^33=f^14=f] V
# [7=f^18=f^10=f^27=f^35=t^16=f] V
# [9=f^26=f^10=t^33=t^36=t^7=f] V
# [7=f^18=f^10=f^27=f^35=t^16=f] V
# [9=f^35=t^2=f^7=f^10=t^5=t] V
# [5=f^6=t^16=f^10=f^33=f] V
# [9=f^7=f^2=f^18=f^10=t] V
# [5=f^33=t^10=f^11=f^13=l^26=t^9=t] V
# [9=f^33=t^18=f^7=f^4=f^10=f^27=f^16=f^20=f] V
# [9=f^5=f^33=t^10=f^27=f^16=f^34=f^3=f^12=f^7=f] V
# [35=t^34=t^5=f^10=f^13=l^9=t^36=t^24=t] V
# [9=f^35=t^12=t^10=f^36=n^26=f^13=l]]
#
# GREW FINAL RULES
# [[33=f^10=f^35=t^6=t] V
# [33=f^10=f^35=t^15=n^23=f] V
# [15=w^31=t^1=f] V
# [10=f^11=t^15=w^33=f] V
# [7=f^18=f^10=f^4=f^24=f] V
# [7=f^18=f^2=f^9=f^27=f^35=t^24=f] V
# [7=f^17=t^10=f^33=f] V
# [7=f^18=f^10=f^27=f^33=t^16=f] V
# [8=f^1=t^11=t^33=f^14=f] V
# [7=f^18=f^10=f^27=f^35=t^16=f] V
# [9=f^26=f^10=t^33=t^36=t^7=f] V
# [7=f^18=f^10=f^27=f^35=t^16=f] V
# [9=f^35=t^2=f^7=f^10=t^5=t] V
# [5=f^6=t^16=f^10=f^33=f] V
# [9=f^7=f^2=f^18=f^10=t] V
# [5=f^33=t^10=f^11=f^13=l^26=t^9=t] V
# [9=f^33=t^18=f^7=f^4=f^10=f^27=f^16=f^20=f] V
# [9=f^5=f^33=t^10=f^27=f^16=f^34=f^3=f^12=f^7=f] V
# [35=t^34=t^5=f^10=f^13=l^9=t^36=t^24=t] V
# [9=f^35=t^12=t^10=f^36=n^26=f^13=l] V
# [33=f^10=f^35=t^6=t] V
# [33=f^10=f^35=t^15=n^23=f] V
# [15=w^31=t^1=f] V
# [10=f^11=t^15=w] V
# [7=f^18=f^36=t^27=f^10=f]]
#
# FINAL RULESET:
# [[33=f^10=f^35=t^6=t] V
# [33=f^10=f^35=t^15=n^23=f] V
# [15=w^31=t^1=f] V
# [10=f^11=t^15=w^33=f] V
# [7=f^18=f^2=f^9=f^27=f^35=t^24=f] V
# [7=f^17=t^10=f^33=f] V
# [7=f^18=f^10=f^27=f^33=t^16=f] V
# [8=f^1=t^11=t^33=f^14=f] V
# [9=f^26=f^10=t^33=t^36=t^7=f] V
# [9=f^35=t^2=f^7=f^10=t^5=t] V
# [5=f^6=t^16=f^10=f^33=f]]
#
# tree 3 of 5
# ripper 4 of 5
#
# GREW INITIAL RULESET:
# [[33=f^10=f^35=t^6=t] V
# [10=f^33=f^35=t^15=n^23=f] V
# [15=w^10=f^11=t^33=f] V
# [7=f^18=f^22=t^2=t] V
# [7=f^18=f^33=t^24=f^10=f^27=f^20=f] V
# [7=f^1=t^11=t^33=f^14=f] V
# [7=f^36=t^10=t^33=t^8=f] V
# [8=f^18=f^2=f^10=t^7=f] V
# [8=f^31=t^15=w^6=t] V
# [8=f^26=f^17=t^33=f^10=f] V
# [8=f^31=t^15=w^1=f] V
# [8=f^6=t^33=f^10=f] V
# [7=f^35=t^10=f^13=l^26=t^17=t] V
# [7=f^35=t^10=f^13=l^5=f^26=t^11=f^24=t^3=f^36=n] V
# [8=f^35=t^12=t^13=l^6=t^26=f] V
# [7=f^35=t^6=f^36=t^24=t^12=f^27=f^18=f] V
# [7=f^12=t^13=l^26=t^36=t] V
# [26=f^34=t^33=f^5=t^6=f^24=t] V
# [9=f^35=t^15=n^7=f^2=f^33=f^5=t] V
# [8=f^35=t^5=f^2=f^15=n^6=f^18=f^27=f] V
# [7=f^33=t^10=f^13=l^16=f^27=f^34=f^12=f^3=f] V
# [9=f^35=t^24=f^5=f^33=t^6=t^11=t^15=n^4=t] V
# [8=f^35=t^24=f^5=f^10=f^13=l^23=f^7=f^30=t]]
#
# optimization run 1 of 2
#
# OPTIMIZED RULESET:
# [[33=f^10=f^35=t^6=t] V
# [10=f^33=f^35=t^15=n^23=f] V
# [15=w^10=f^11=t^33=f] V
# [7=f^18=f^22=t^2=t] V
# [7=f^18=f^33=t^24=f^10=f^27=f^20=f] V
# [7=f^1=t^11=t^33=f^14=f] V
# [7=f^36=t^10=t^33=t^8=f] V
# [8=f^18=f^2=f^10=t^7=f] V
# [7=f^31=t^15=w] V
# [8=f^26=f^17=t^33=f^10=f] V
# [8=f^31=t^15=w^1=f] V
# [8=f^6=t^33=f^10=f] V
# [7=f^35=t^10=f^13=l^26=t^17=t] V
# [7=f^35=t^10=f^13=l^5=f^26=t^11=f^24=t^3=f^36=n] V
# [8=f^35=t^12=t^13=l^6=t^26=f] V
# [7=f^35=t^6=f^36=t^24=t^12=f^27=f^18=f] V
# [7=f^35=t^9=f^2=f^10=t^5=t] V
# [26=f^34=t^33=f^5=t^6=f^24=t] V
# [9=f^35=t^15=n^7=f^2=f^33=f^5=t] V
# [8=f^35=t^5=f^2=f^15=n^6=f^18=f^27=f] V
# [7=f^33=t^10=f^13=l^16=f^27=f^34=f^12=f^3=f] V
# [9=f^35=t^24=f^5=f^33=t^6=t^11=t^15=n^4=t] V
# [8=f^35=t^24=f^5=f^10=f^13=l^23=f^7=f^30=t]]
#
# optimization run 2 of 2
#
# OPTIMIZED RULESET:
# [[33=f^10=f^35=t^6=t] V
# [10=f^33=f^35=t^15=n^23=f] V
# [15=w^10=f^11=t^33=f] V
# [7=f^18=f^22=t^2=t] V
# [7=f^18=f^33=t^24=f^10=f^27=f^20=f] V
# [7=f^1=t^11=t^33=f^14=f] V
# [7=f^36=t^10=t^33=t^8=f] V
# [8=f^18=f^2=f^10=t^7=f] V
# [7=f^31=t^15=w] V
# [8=f^26=f^17=t^33=f^10=f] V
# [8=f^31=t^15=w^1=f] V
# [8=f^6=t^33=f^10=f] V
# [7=f^35=t^10=f^13=l^26=t^17=t] V
# [7=f^35=t^10=f^13=l^5=f^26=t^11=f^24=t^3=f^36=n] V
# [8=f^35=t^12=t^13=l^6=t^26=f] V
# [7=f^35=t^6=f^36=t^24=t^12=f^27=f^18=f] V
# [7=f^35=t^9=f^2=f^10=t^5=t] V
# [26=f^34=t^33=f^5=t^6=f^24=t] V
# [9=f^35=t^15=n^7=f^2=f^33=f^5=t] V
# [8=f^35=t^5=f^2=f^15=n^6=f^18=f^27=f] V
# [7=f^33=t^10=f^13=l^16=f^27=f^34=f^12=f^3=f] V
# [9=f^35=t^24=f^5=f^33=t^6=t^11=t^15=n^4=t] V
# [8=f^35=t^24=f^5=f^10=f^13=l^23=f^7=f^30=t]]
#
# GREW FINAL RULES
# [[33=f^10=f^35=t^6=t] V
# [10=f^33=f^35=t^15=n^23=f] V
# [15=w^10=f^11=t^33=f] V
# [7=f^18=f^22=t^2=t] V
# [7=f^18=f^33=t^24=f^10=f^27=f^20=f] V
# [7=f^1=t^11=t^33=f^14=f] V
# [7=f^36=t^10=t^33=t^8=f] V
# [8=f^18=f^2=f^10=t^7=f] V
# [7=f^31=t^15=w] V
# [8=f^26=f^17=t^33=f^10=f] V
# [8=f^31=t^15=w^1=f] V
# [8=f^6=t^33=f^10=f] V
# [7=f^35=t^10=f^13=l^26=t^17=t] V
# [7=f^35=t^10=f^13=l^5=f^26=t^11=f^24=t^3=f^36=n] V
# [8=f^35=t^12=t^13=l^6=t^26=f] V
# [7=f^35=t^6=f^36=t^24=t^12=f^27=f^18=f] V
# [7=f^35=t^9=f^2=f^10=t^5=t] V
# [26=f^34=t^33=f^5=t^6=f^24=t] V
# [9=f^35=t^15=n^7=f^2=f^33=f^5=t] V
# [8=f^35=t^5=f^2=f^15=n^6=f^18=f^27=f] V
# [7=f^33=t^10=f^13=l^16=f^27=f^34=f^12=f^3=f] V
# [9=f^35=t^24=f^5=f^33=t^6=t^11=t^15=n^4=t] V
# [8=f^35=t^24=f^5=f^10=f^13=l^23=f^7=f^30=t] V
# [33=f^10=f^35=t^6=t] V
# [10=f^33=f^35=t^15=n^23=f] V
# [15=w^10=f^11=t^33=f] V
# [7=f^18=f^22=t^2=t] V
# [7=f^18=f^33=t^24=f^10=f^27=f^20=f] V
# [7=f^1=t^11=t^33=f^14=f]]
#
# FINAL RULESET:
# [[33=f^10=f^35=t^6=t] V
# [10=f^33=f^35=t^15=n^23=f] V
# [15=w^10=f^11=t^33=f] V
# [7=f^18=f^22=t^2=t] V
# [7=f^18=f^33=t^24=f^10=f^27=f^20=f] V
# [7=f^1=t^11=t^33=f^14=f] V
# [7=f^36=t^10=t^33=t^8=f] V
# [8=f^18=f^2=f^10=t^7=f] V
# [7=f^31=t^15=w] V
# [8=f^26=f^17=t^33=f^10=f] V
# [8=f^6=t^33=f^10=f] V
# [7=f^35=t^10=f^13=l^26=t^17=t] V
# [7=f^35=t^9=f^2=f^10=t^5=t] V
# [7=f^33=t^10=f^13=l^16=f^27=f^34=f^12=f^3=f]]
#
# tree 4 of 5
# ripper 5 of 5
#
# GREW INITIAL RULESET:
# [[33=f^10=f^35=t^6=t] V
# [33=f^10=f^35=t^15=n^23=f] V
# [15=w^10=f^11=t] V
# [18=f^7=f^33=t^24=f^27=f^10=f^11=f] V
# [8=f^18=f^7=f^9=t^2=t] V
# [7=f^18=f^27=f^2=f^35=t^6=f^36=n] V
# [7=f^18=f^27=f^33=t^16=f^10=f^25=f^4=f^20=f] V
# [8=f^33=f^32=f^1=t^14=f] V
# [7=f^35=t^9=f^36=t^10=t^33=t] V
# [8=f^12=t^23=t^10=f^6=t] V
# [7=f^15=w^33=t^8=f] V
# [8=f^33=f^6=t^10=f] V
# [7=f^35=t^12=t^10=f^11=t] V
# [7=f^35=t^33=f^36=t^13=l^2=f^18=f] V
# [7=f^35=t^17=t^10=f^33=f] V
# [7=f^35=t^12=t^10=f^13=l^9=t] V
# [7=f^35=t^5=t^10=t^8=f] V
# [31=t^22=t^33=t^12=f^7=f] V
# [35=t^9=f^30=t^26=t^18=f] V
# [9=f^35=t^7=f^36=n^13=g^6=t^12=f^23=f^15=n^33=f] V
# [9=f^11=f^24=f^6=t^34=f^36=n^10=f^7=f] V
# [24=f^12=t^13=l^26=f^34=t]]
#
# optimization run 1 of 2
#
# OPTIMIZED RULESET:
# [[33=f^10=f^35=t^6=t] V
# [33=f^10=f^35=t^15=n^23=f] V
# [15=w^10=f^11=t^27=f] V
# [18=f^7=f^10=f^24=f^20=f^27=f] V
# [7=f^18=f^6=f^33=t^24=f^34=f^20=f] V
# [7=f^18=f^16=f^33=t^27=f^26=f^24=t] V
# [7=f^18=f^27=f^33=t^16=f^10=f^25=f^4=f^20=f] V
# [8=f^33=f^32=f^1=t^14=f] V
# [7=f^35=t^9=f^36=t^10=t^33=t] V
# [7=f^17=t^10=f^33=f] V
# [7=f^15=w^33=t^8=f] V
# [8=f^33=f^6=t^10=f] V
# [7=f^17=t^10=f^33=f] V
# [7=f^35=t^33=f^36=t^13=l^2=f^18=f] V
# [7=f^17=t^33=f^10=f] V
# [7=f^35=t^12=t^10=f^13=l^9=t] V
# [7=f^35=t^5=t^10=t^8=f] V
# [31=t^22=t^33=t^12=f^7=f] V
# [35=t^9=f^30=t^26=t^18=f] V
# [9=f^35=t^7=f^36=n^13=g^6=t^12=f^23=f^15=n^33=f] V
# [9=f^11=f^24=f^6=t^34=f^36=n^10=f^7=f] V
# [24=f^12=t^13=l^26=f^34=t]]
#
# optimization run 2 of 2
#
# OPTIMIZED RULESET:
# [[33=f^10=f^35=t^6=t] V
# [33=f^10=f^35=t^15=n^23=f] V
# [15=w^10=f^11=t^27=f] V
# [18=f^7=f^10=f^24=f^20=f^27=f] V
# [7=f^18=f^6=f^9=t^2=t] V
# [8=f^18=f^15=w^31=t] V
# [7=f^18=f^15=w^31=t] V
# [8=f^33=f^32=f^1=t^14=f] V
# [7=f^35=t^9=f^36=t^10=t^33=t] V
# [7=f^17=t^10=f^33=f] V
# [7=f^15=w^33=t^8=f] V
# [8=f^33=f^6=t^10=f] V
# [7=f^17=t^10=f^33=f] V
# [7=f^35=t^33=f^36=t^13=l^2=f^18=f] V
# [7=f^17=t^33=f^10=f] V
# [7=f^35=t^12=t^10=f^13=l^9=t] V
# [7=f^35=t^5=t^10=t^8=f] V
# [31=t^22=t^33=t^12=f^7=f] V
# [8=f^11=f^15=w^2=t] V
# [6=t^33=f^10=f] V
# [6=t^33=f^10=f] V
# [24=f^12=t^13=l^26=f^34=t]]
#
# GREW FINAL RULES
# [[33=f^10=f^35=t^6=t] V
# [33=f^10=f^35=t^15=n^23=f] V
# [15=w^10=f^11=t^27=f] V
# [18=f^7=f^10=f^24=f^20=f^27=f] V
# [7=f^18=f^6=f^9=t^2=t] V
# [8=f^18=f^15=w^31=t] V
# [7=f^18=f^15=w^31=t] V
# [8=f^33=f^32=f^1=t^14=f] V
# [7=f^35=t^9=f^36=t^10=t^33=t] V
# [7=f^17=t^10=f^33=f] V
# [7=f^15=w^33=t^8=f] V
# [8=f^33=f^6=t^10=f] V
# [7=f^17=t^10=f^33=f] V
# [7=f^35=t^33=f^36=t^13=l^2=f^18=f] V
# [7=f^17=t^33=f^10=f] V
# [7=f^35=t^12=t^10=f^13=l^9=t] V
# [7=f^35=t^5=t^10=t^8=f] V
# [31=t^22=t^33=t^12=f^7=f] V
# [8=f^11=f^15=w^2=t] V
# [6=t^33=f^10=f] V
# [6=t^33=f^10=f] V
# [24=f^12=t^13=l^26=f^34=t] V
# [33=f^10=f^35=t^6=t] V
# [33=f^10=f^35=t^15=n^23=f] V
# [15=w^10=f^11=t] V
# [18=f^7=f^33=t^24=f^27=f^10=f^11=f] V
# [8=f^18=f^7=f^9=t^2=t]]
# FINAL RULESET:
# [[33=f^10=f^35=t^6=t] V
# [33=f^10=f^35=t^15=n^23=f] V
# [15=w^10=f^11=t^27=f] V
# [18=f^7=f^10=f^24=f^20=f^27=f] V
# [7=f^18=f^6=f^9=t^2=t] V
# [8=f^18=f^15=w^31=t] V
# [8=f^33=f^32=f^1=t^14=f] V
# [7=f^35=t^9=f^36=t^10=t^33=t] V
# [7=f^17=t^10=f^33=f] V
# [7=f^15=w^33=t^8=f] V
# [8=f^33=f^6=t^10=f] V
# [7=f^35=t^5=t^10=t^8=f] V
# [31=t^22=t^33=t^12=f^7=f] V
# [6=t^33=f^10=f]]
#
# tree 5 of 5
# ripper means (0.9639305558397989, 0.8230942165066917, 60.0)
# ripper medians (0.9651639344262295, 0.8456014362657092, 64.0)
# tree means (0.9733270743264821, 0.9658035812497255, 279.8)
# tree medians (0.9717698154180239, 0.9692144373673036, 279.0)
# max-tree 1 of 5
# max-tree 2 of 5
# max-tree 3 of 5
# max-tree 4 of 5
# max-tree 5 of 5
# maxtree means (0.9452411293887681, 0.9892874726299489, 53.4)
# maxtree medians (0.9473684210526315, 0.9893617021276596, 53.0)
#
# [<IREP object fit ruleset=[10=f^33=f^35=t^6=t] V [10=f^33=f^35=t^18=f] V [15=w^31=t^1=f] V [10=f^33=f^32=f^15=w] V [7=f^18=f^36=t^27=f^24=f^10=f] V [33=f^10=f^35=t^15=n^23=f] V [8=f^1=t^11=t^34=t^33=f] V [7=f^31=t^22=t^12=f^24=t] V [9=f^18=f^2=f^10=t] V [7=f^18=f^2=f^26=f^9=f^16=f^27=f] V [7=f^32=f^8=f^5=t^10=t] V [7=f^10=f^34=f^16=f^32=f^27=f^4=f^33=t^30=f] V [7=f^17=t^33=f^10=f] V [6=t^33=f^10=f]>, <IREP object fit ruleset=[33=f^10=f^35=t^6=t] V [10=f^33=f^35=t^13=l^18=f] V [10=f^33=f^32=f^15=w] V [7=f^10=f^33=f^35=t^15=n^23=f] V [18=f^7=f^33=t^16=f^27=f^10=f] V [31=t^15=w] V [8=f^11=t^1=t^33=f] V [7=f^17=t^10=f^33=f] V [18=f^7=f^33=t^24=f^36=t^27=f]>, <IREP object fit ruleset=[33=f^10=f^35=t^6=t] V [33=f^10=f^35=t^15=n^23=f] V [15=w^31=t^1=f] V [10=f^11=t^15=w^33=f] V [7=f^18=f^2=f^9=f^27=f^35=t^24=f] V [7=f^17=t^10=f^33=f] V [7=f^18=f^10=f^27=f^33=t^16=f] V [8=f^1=t^11=t^33=f^14=f] V [9=f^26=f^10=t^33=t^36=t^7=f] V [9=f^35=t^2=f^7=f^10=t^5=t] V [5=f^6=t^16=f^10=f^33=f]>, <IREP object fit ruleset=[33=f^10=f^35=t^6=t] V [10=f^33=f^35=t^15=n^23=f] V [15=w^10=f^11=t^33=f] V [7=f^18=f^22=t^2=t] V [7=f^18=f^33=t^24=f^10=f^27=f^20=f] V [7=f^1=t^11=t^33=f^14=f] V [7=f^36=t^10=t^33=t^8=f] V [8=f^18=f^2=f^10=t^7=f] V [7=f^31=t^15=w] V [8=f^26=f^17=t^33=f^10=f] V [8=f^6=t^33=f^10=f] V [7=f^35=t^10=f^13=l^26=t^17=t] V [7=f^35=t^9=f^2=f^10=t^5=t] V [7=f^33=t^10=f^13=l^16=f^27=f^34=f^12=f^3=f]>, <IREP object fit ruleset=[33=f^10=f^35=t^6=t] V [33=f^10=f^35=t^15=n^23=f] V [15=w^10=f^11=t^27=f] V [18=f^7=f^10=f^24=f^20=f^27=f] V [7=f^18=f^6=f^9=t^2=t] V [8=f^18=f^15=w^31=t] V [8=f^33=f^32=f^1=t^14=f] V [7=f^35=t^9=f^36=t^10=t^33=t] V [7=f^17=t^10=f^33=f] V [7=f^15=w^33=t^8=f] V [8=f^33=f^6=t^10=f] V [7=f^35=t^5=t^10=t^8=f] V [31=t^22=t^33=t^12=f^7=f] V [6=t^33=f^10=f]>]
# {'max_t_means': (0.9452411293887681, 0.9892874726299489, 53.4),
#  'max_t_meds': (0.9473684210526315, 0.9893617021276596, 53.0),
#  'n': 5,
#  'r_means': (0.9639305558397989, 0.8230942165066917, 60.0),
#  'r_meds': (0.9651639344262295, 0.8456014362657092, 64.0),
#  'r_models': [<IREP object fit ruleset=[10=f^33=f^35=t^6=t] V [10=f^33=f^35=t^18=f] V [15=w^31=t^1=f] V [10=f^33=f^32=f^15=w] V [7=f^18=f^36=t^27=f^24=f^10=f] V [33=f^10=f^35=t^15=n^23=f] V [8=f^1=t^11=t^34=t^33=f] V [7=f^31=t^22=t^12=f^24=t] V [9=f^18=f^2=f^10=t] V [7=f^18=f^2=f^26=f^9=f^16=f^27=f] V [7=f^32=f^8=f^5=t^10=t] V [7=f^10=f^34=f^16=f^32=f^27=f^4=f^33=t^30=f] V [7=f^17=t^33=f^10=f] V [6=t^33=f^10=f]>,
#   <IREP object fit ruleset=[33=f^10=f^35=t^6=t] V [10=f^33=f^35=t^13=l^18=f] V [10=f^33=f^32=f^15=w] V [7=f^10=f^33=f^35=t^15=n^23=f] V [18=f^7=f^33=t^16=f^27=f^10=f] V [31=t^15=w] V [8=f^11=t^1=t^33=f] V [7=f^17=t^10=f^33=f] V [18=f^7=f^33=t^24=f^36=t^27=f]>,
#   <IREP object fit ruleset=[33=f^10=f^35=t^6=t] V [33=f^10=f^35=t^15=n^23=f] V [15=w^31=t^1=f] V [10=f^11=t^15=w^33=f] V [7=f^18=f^2=f^9=f^27=f^35=t^24=f] V [7=f^17=t^10=f^33=f] V [7=f^18=f^10=f^27=f^33=t^16=f] V [8=f^1=t^11=t^33=f^14=f] V [9=f^26=f^10=t^33=t^36=t^7=f] V [9=f^35=t^2=f^7=f^10=t^5=t] V [5=f^6=t^16=f^10=f^33=f]>,
#   <IREP object fit ruleset=[33=f^10=f^35=t^6=t] V [10=f^33=f^35=t^15=n^23=f] V [15=w^10=f^11=t^33=f] V [7=f^18=f^22=t^2=t] V [7=f^18=f^33=t^24=f^10=f^27=f^20=f] V [7=f^1=t^11=t^33=f^14=f] V [7=f^36=t^10=t^33=t^8=f] V [8=f^18=f^2=f^10=t^7=f] V [7=f^31=t^15=w] V [8=f^26=f^17=t^33=f^10=f] V [8=f^6=t^33=f^10=f] V [7=f^35=t^10=f^13=l^26=t^17=t] V [7=f^35=t^9=f^2=f^10=t^5=t] V [7=f^33=t^10=f^13=l^16=f^27=f^34=f^12=f^3=f]>,
#   <IREP object fit ruleset=[33=f^10=f^35=t^6=t] V [33=f^10=f^35=t^15=n^23=f] V [15=w^10=f^11=t^27=f] V [18=f^7=f^10=f^24=f^20=f^27=f] V [7=f^18=f^6=f^9=t^2=t] V [8=f^18=f^15=w^31=t] V [8=f^33=f^32=f^1=t^14=f] V [7=f^35=t^9=f^36=t^10=t^33=t] V [7=f^17=t^10=f^33=f] V [7=f^15=w^33=t^8=f] V [8=f^33=f^6=t^10=f] V [7=f^35=t^5=t^10=t^8=f] V [31=t^22=t^33=t^12=f^7=f] V [6=t^33=f^10=f]>],
#  't_means': (0.9733270743264821, 0.9658035812497255, 279.8),
#  't_meds': (0.9717698154180239, 0.9692144373673036, 279.0)}

# %%
len(chess_results['r_models'])
# Out:
# 5

# %%
# Set up
dataset = 'mushroom.csv'
filename = datasets_path + dataset
class_feat = 'Poisonous/Edible'
pos_class = 'p'
n_classes = 2
k=2
verbosity=1
n_runs=10

timer = Timer()
mushroom_results = run_experiment(filename, class_feat, pos_class, n_classes, verbosity=verbosity, seed=42, n_runs=n_runs)
timer.stop()
pickle.dump(mushroom_results,open(filename.replace('.csv','.pkl'),'wb'))
mushroom_results
# Out:
# ripper 1 of 10
#
# GREW INITIAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Cap-surface=s^Stalk-shape=e] V
# [Gill-size=n^Habitat=g] V
# [Gill-size=n^Sport-print-color=k^Stalk-root=b] V
# [Population=v^Stalk-shape=e^Bruises?=t^Cap-shape=b] V
# [Gill-size=n^Cap-surface=y^Bruises?=t] V
# [Gill-size=n^Stalk-root=c] V
# [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Cap-surface=f] V
# [Ring-number=t^Population=v^Cap-shape=f^Gill-color=g] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Habitat=m^Cap-shape=f] V
# [Habitat=l^Cap-color=w]]
#
# optimization run 1 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Cap-surface=s^Stalk-shape=e] V
# [Gill-size=n^Sport-print-color=k^Stalk-root=b] V
# [Gill-size=n^Stalk-shape=e^Bruises?=t] V
# [Population=v^Stalk-shape=e^Bruises?=t^Cap-shape=b] V
# [Gill-size=n^Cap-surface=y^Bruises?=t] V
# [Gill-size=n^Population=c] V
# [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Cap-surface=f] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Habitat=m^Cap-shape=f] V
# [Habitat=l^Cap-color=w]]
#
# optimization run 2 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Cap-surface=s^Stalk-shape=e] V
# [Gill-size=n^Sport-print-color=k^Stalk-root=b] V
# [Gill-size=n^Stalk-shape=e^Bruises?=t] V
# [Ring-number=t^Population=v^Cap-shape=b] V
# [Gill-size=n^Cap-surface=y^Bruises?=t] V
# [Gill-size=n^Population=c] V
# [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Cap-surface=f] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Habitat=m^Cap-shape=f] V
# [Habitat=l^Cap-color=w]]
#
# All pos covered
#
# FINAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Cap-surface=s^Stalk-shape=e] V
# [Gill-size=n^Sport-print-color=k^Stalk-root=b] V
# [Gill-size=n^Stalk-shape=e^Bruises?=t] V
# [Ring-number=t^Population=v^Cap-shape=b] V
# [Gill-size=n^Population=c] V
# [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Cap-surface=f] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Habitat=m^Cap-shape=f]]
#
# tree 1 of 10
# ripper 2 of 10
#
# GREW INITIAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Habitat=g] V
# [Gill-size=n^Sport-print-color=k^Stalk-root=b] V
# [Gill-size=n^Bruises?=t^Stalk-shape=e] V
# [Population=v^Ring-number=t^Habitat=m] V
# [Gill-size=n^Sport-print-color=n^Stalk-root=b^Bruises?=f] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Stalk-surface-above-ring=y^Cap-shape=k] V
# [Stalk-surface-above-ring=y^Cap-surface=y]]
#
# optimization run 1 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Bruises?=t^Stalk-shape=e] V
# [Gill-size=n^Sport-print-color=k^Stalk-root=b] V
# [Gill-size=n^Bruises?=t^Stalk-shape=e] V
# [Population=v^Ring-number=t^Habitat=m] V
# [Gill-size=n^Sport-print-color=n^Stalk-root=b^Bruises?=f] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Stalk-surface-above-ring=y^Cap-color=y] V
# [Stalk-surface-above-ring=y^Cap-color=y]]
#
# optimization run 2 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Bruises?=t^Stalk-shape=e] V
# [Gill-size=n^Sport-print-color=k^Stalk-root=b] V
# [Gill-size=n^Bruises?=t^Stalk-shape=e] V
# [Population=v^Ring-number=t^Habitat=m] V
# [Gill-size=n^Sport-print-color=n^Stalk-root=b^Bruises?=f] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Stalk-surface-above-ring=y^Cap-color=y] V
# [Stalk-surface-above-ring=y^Cap-color=y]]
#
# All pos covered
#
# FINAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Bruises?=t^Stalk-shape=e] V
# [Gill-size=n^Sport-print-color=k^Stalk-root=b] V
# [Population=v^Ring-number=t^Habitat=m] V
# [Gill-size=n^Sport-print-color=n^Stalk-root=b^Bruises?=f] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Stalk-surface-above-ring=y^Cap-color=y]]
#
# tree 2 of 10
# ripper 3 of 10
#
# GREW INITIAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Cap-surface=s^Stalk-shape=e] V
# [Gill-size=n^Cap-surface=y^Bruises?=t] V
# [Population=v^Ring-number=t^Cap-shape=b] V
# [Gill-size=n^Population=c] V
# [Gill-size=n^Cap-shape=x^Gill-color=g^Stalk-root=b] V
# [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Cap-surface=f] V
# [Ring-number=t^Population=v^Habitat=m] V
# [Ring-number=t^Population=v^Habitat=g]]
#
# optimization run 1 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Cap-surface=s^Stalk-shape=e] V
# [Gill-size=n^Cap-surface=y^Bruises?=t] V
# [Gill-size=n^Cap-color=p] V
# [Gill-size=n^Population=c] V
# [Cap-color=p^Population=v] V
# [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Cap-surface=f] V
# [Ring-number=t^Population=v^Habitat=m] V
# [Ring-number=t^Population=v^Habitat=g]]
#
# optimization run 2 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Cap-surface=s^Stalk-shape=e] V
# [Gill-size=n^Cap-surface=y^Bruises?=t] V
# [Gill-size=n^Cap-color=p] V
# [Gill-size=n^Population=c] V
# [Cap-color=p^Population=v] V
# [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Cap-surface=f] V
# [Ring-number=t^Population=v^Habitat=m] V
# [Ring-number=t^Population=v^Habitat=g]]
#
# All pos covered
#
# FINAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Cap-surface=s^Stalk-shape=e] V
# [Gill-size=n^Cap-surface=y^Bruises?=t] V
# [Gill-size=n^Cap-color=p] V
# [Gill-size=n^Population=c] V
# [Cap-color=p^Population=v] V
# [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Cap-surface=f] V
# [Ring-number=t^Population=v^Habitat=m] V
# [Ring-number=t^Population=v^Habitat=g]]
#
# tree 3 of 10
# ripper 4 of 10
#
# GREW INITIAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Stalk-root=?^Stalk-shape=t] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Cap-surface=s^Stalk-shape=e] V
# [Gill-size=n^Habitat=g] V
# [Population=v^Stalk-shape=e^Bruises?=t] V
# [Gill-size=n^Stalk-root=b^Gill-spacing=c] V
# [Gill-size=n^Population=c] V
# [Gill-size=n^Cap-shape=x^Cap-color=p] V
# [Gill-size=n^Gill-color=u^Cap-surface=f] V
# [Gill-size=n^Cap-color=g^Gill-spacing=w] V
# [Gill-color=g^Stalk-root=b]]
#
# optimization run 1 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Stalk-root=?^Stalk-shape=t] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Cap-surface=s^Stalk-shape=e] V
# [Gill-size=n^Habitat=g] V
# [Population=v^Stalk-shape=e^Bruises?=t] V
# [Gill-size=n^Stalk-root=b^Gill-spacing=c] V
# [Gill-size=n^Population=c] V
# [Gill-size=n^Cap-color=p] V
# [Gill-size=n^Gill-color=u^Cap-surface=f] V
# [Gill-size=n^Cap-color=g^Gill-spacing=w] V
# [Gill-color=g^Stalk-root=b]]
#
# optimization run 2 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Stalk-root=?^Stalk-shape=t] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Cap-surface=s^Stalk-shape=e] V
# [Gill-size=n^Habitat=g] V
# [Population=v^Stalk-shape=e^Bruises?=t] V
# [Gill-size=n^Stalk-root=b^Gill-spacing=c] V
# [Gill-size=n^Population=c] V
# [Gill-size=n^Cap-color=p] V
# [Gill-size=n^Gill-color=u^Cap-surface=f] V
# [Gill-size=n^Cap-color=g^Gill-spacing=w] V
# [Gill-color=g^Stalk-root=b]]
# GREW FINAL RULES
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Stalk-root=?^Stalk-shape=t] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Cap-surface=s^Stalk-shape=e] V
# [Gill-size=n^Habitat=g] V
# [Population=v^Stalk-shape=e^Bruises?=t] V
# [Gill-size=n^Stalk-root=b^Gill-spacing=c] V
# [Gill-size=n^Population=c] V
# [Gill-size=n^Cap-color=p] V
# [Gill-size=n^Gill-color=u^Cap-surface=f] V
# [Gill-size=n^Cap-color=g^Gill-spacing=w] V
# [Gill-color=g^Stalk-root=b] V
# [Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Stalk-root=?^Stalk-shape=t] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Cap-surface=s^Stalk-shape=e] V
# [Gill-size=n^Habitat=g] V
# [Population=v^Stalk-shape=e^Bruises?=t] V
# [Gill-size=n^Stalk-root=b^Gill-spacing=c] V
# [Gill-size=n^Population=c]]
#
# FINAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Stalk-root=?^Stalk-shape=t] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Cap-surface=s^Stalk-shape=e] V
# [Gill-size=n^Habitat=g] V
# [Population=v^Stalk-shape=e^Bruises?=t] V
# [Gill-size=n^Stalk-root=b^Gill-spacing=c] V
# [Gill-size=n^Population=c] V
# [Gill-size=n^Cap-color=p] V
# [Gill-size=n^Gill-color=u^Cap-surface=f] V
# [Gill-size=n^Cap-color=g^Gill-spacing=w] V
# [Gill-color=g^Stalk-root=b]]
#
# tree 4 of 10
# ripper 5 of 10
#
# GREW INITIAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Habitat=g] V
# [Gill-size=n^Sport-print-color=k^Stalk-root=b] V
# [Population=v^Stalk-shape=e^Bruises?=t^Cap-color=w] V
# [Gill-size=n^Population=c] V
# [Population=v^Stalk-shape=e^Bruises?=t^Cap-shape=b] V
# [Gill-size=n^Sport-print-color=n^Cap-shape=x^Stalk-shape=e^Stalk-root=b] V
# [Habitat=u^Bruises?=t] V
# [Cap-color=b^Stalk-root=b] V
# [Cap-color=p^Population=v]]
#
# optimization run 1 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Habitat=g] V
# [Gill-size=n^Sport-print-color=k^Stalk-root=b] V
# [Population=v^Stalk-shape=e^Bruises?=t^Cap-color=w] V
# [Gill-size=n^Population=c] V
# [Population=v^Stalk-shape=e^Bruises?=t^Cap-shape=b] V
# [Gill-size=n^Sport-print-color=n^Stalk-shape=e^Stalk-root=b] V
# [Habitat=u^Bruises?=t] V
# [Cap-color=b^Stalk-root=b] V
# [Cap-color=p^Population=v]]
#
# optimization run 2 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Habitat=g] V
# [Gill-size=n^Sport-print-color=k^Stalk-root=b] V
# [Population=v^Stalk-shape=e^Bruises?=t^Cap-color=w] V
# [Gill-size=n^Population=c] V
# [Population=v^Stalk-shape=e^Bruises?=t^Cap-shape=b] V
# [Gill-size=n^Sport-print-color=n^Stalk-shape=e^Stalk-root=b] V
# [Habitat=u^Bruises?=t] V
# [Cap-color=b^Stalk-root=b] V
# [Cap-color=p^Population=v]]
#
# All pos covered
#
# FINAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Habitat=g] V
# [Gill-size=n^Sport-print-color=k^Stalk-root=b] V
# [Population=v^Stalk-shape=e^Bruises?=t^Cap-color=w] V
# [Gill-size=n^Population=c] V
# [Population=v^Stalk-shape=e^Bruises?=t^Cap-shape=b] V
# [Gill-size=n^Sport-print-color=n^Stalk-shape=e^Stalk-root=b] V
# [Habitat=u^Bruises?=t] V
# [Cap-color=b^Stalk-root=b] V
# [Cap-color=p^Population=v]]
#
# tree 5 of 10
# ripper 6 of 10
#
# GREW INITIAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Stalk-root=?^Stalk-shape=t] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Ring-type=p^Stalk-shape=e^Bruises?=t] V
# [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Bruises?=f] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Habitat=m^Odor=n] V
# [Stalk-surface-above-ring=y^Cap-color=y]]
#
# optimization run 1 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Stalk-root=?^Stalk-shape=t] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Ring-type=p^Stalk-shape=e^Bruises?=t] V
# [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Bruises?=f] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Habitat=m^Odor=n] V
# [Stalk-surface-above-ring=y^Cap-color=y]]
#
# optimization run 2 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Stalk-root=?^Stalk-shape=t] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Ring-type=p^Stalk-shape=e^Bruises?=t] V
# [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Bruises?=f] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Habitat=m^Odor=n] V
# [Stalk-surface-above-ring=y^Cap-color=y]]
#
# All pos covered
#
# FINAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Stalk-root=?^Stalk-shape=t] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Ring-type=p^Stalk-shape=e^Bruises?=t] V
# [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Bruises?=f] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Habitat=m^Odor=n] V
# [Stalk-surface-above-ring=y^Cap-color=y]]
#
# tree 6 of 10
# ripper 7 of 10
#
# GREW INITIAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Stalk-root=?^Stalk-shape=t] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Stalk-shape=e^Bruises?=t] V
# [Gill-size=n^Cap-shape=x^Bruises?=f^Stalk-root=b^Stalk-color-below-ring=w] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Habitat=m^Odor=n] V
# [Stalk-surface-above-ring=y^Cap-color=y]]
#
# optimization run 1 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Stalk-root=?^Stalk-shape=t] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Stalk-shape=e^Bruises?=t] V
# [Gill-size=n^Cap-shape=x^Bruises?=f^Stalk-root=b^Stalk-color-below-ring=w] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Habitat=m^Odor=n] V
# [Stalk-surface-above-ring=y^Cap-color=y]]
#
# optimization run 2 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Stalk-root=?^Stalk-shape=t] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Stalk-shape=e^Bruises?=t] V
# [Gill-size=n^Cap-shape=x^Bruises?=f^Stalk-root=b^Stalk-color-below-ring=w] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Habitat=m^Odor=n] V
# [Stalk-surface-above-ring=y^Cap-color=y]]
#
# All pos covered
#
# FINAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Stalk-root=?^Stalk-shape=t] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Stalk-shape=e^Bruises?=t] V
# [Gill-size=n^Cap-shape=x^Bruises?=f^Stalk-root=b^Stalk-color-below-ring=w] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Habitat=m^Odor=n] V
# [Stalk-surface-above-ring=y^Cap-color=y]]
#
# tree 7 of 10
# ripper 8 of 10
#
# GREW INITIAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Sport-print-color=k^Bruises?=t] V
# [Gill-size=n^Cap-color=p] V
# [Gill-size=n^Sport-print-color=n^Stalk-shape=e^Bruises?=t] V
# [Gill-size=n^Cap-shape=x^Sport-print-color=k^Stalk-root=b] V
# [Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w] V
# [Stalk-surface-above-ring=y^Cap-color=y]]
#
# optimization run 1 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Sport-print-color=k^Bruises?=t] V
# [Gill-size=n^Sport-print-color=n^Stalk-shape=e^Bruises?=t] V
# [Gill-size=n^Sport-print-color=n^Stalk-shape=e^Bruises?=t] V
# [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w] V
# [Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w] V
# [Stalk-surface-above-ring=y^Cap-color=y]]
#
# optimization run 2 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Sport-print-color=k^Bruises?=t] V
# [Gill-size=n^Sport-print-color=n^Stalk-shape=e^Bruises?=t] V
# [Gill-size=n^Sport-print-color=n^Stalk-shape=e^Bruises?=t] V
# [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w] V
# [Habitat=l^Cap-color=w] V
# [Stalk-surface-above-ring=y^Cap-color=y]]
#
# All pos covered
# FINAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Sport-print-color=k^Bruises?=t] V
# [Gill-size=n^Sport-print-color=n^Stalk-shape=e^Bruises?=t] V
# [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w] V
# [Habitat=l^Cap-color=w] V
# [Stalk-surface-above-ring=y^Cap-color=y]]
#
# tree 8 of 10
# ripper 9 of 10
#
# GREW INITIAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Habitat=g] V
# [Gill-size=n^Cap-surface=s^Stalk-shape=e] V
# [Gill-size=n^Cap-surface=y^Bruises?=t] V
# [Population=v^Ring-number=t^Cap-shape=b] V
# [Gill-size=n^Population=c] V
# [Gill-size=n^Cap-shape=x^Stalk-root=b^Bruises?=f^Cap-surface=f] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Habitat=m^Cap-shape=f]]
#
# optimization run 1 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Stalk-shape=e^Bruises?=t] V
# [Gill-size=n^Cap-surface=s^Stalk-shape=e] V
# [Gill-size=n^Cap-surface=y^Bruises?=t] V
# [Population=v^Ring-number=t^Cap-shape=b] V
# [Gill-size=n^Population=c] V
# [Gill-size=n^Cap-shape=x^Stalk-root=b^Bruises?=f^Stalk-color-below-ring=w] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Habitat=m^Cap-shape=f]]
#
# optimization run 2 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Stalk-shape=e^Bruises?=t] V
# [Gill-size=n^Cap-shape=x^Stalk-root=b^Bruises?=f^Stalk-color-below-ring=w] V
# [Gill-size=n^Cap-surface=y^Bruises?=t] V
# [Population=v^Ring-number=t^Cap-shape=b] V
# [Gill-size=n^Population=c] V
# [Gill-size=n^Cap-shape=x^Stalk-root=b^Bruises?=f^Stalk-color-below-ring=w] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Habitat=m^Cap-shape=f]]
#
# All pos covered
#
# FINAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Stalk-shape=e^Bruises?=t] V
# [Gill-size=n^Cap-shape=x^Stalk-root=b^Bruises?=f^Stalk-color-below-ring=w] V
# [Population=v^Ring-number=t^Cap-shape=b] V
# [Gill-size=n^Population=c] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Habitat=m^Cap-shape=f]]
#
# tree 9 of 10
# ripper 10 of 10
#
# GREW INITIAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Habitat=g] V
# [Gill-size=n^Sport-print-color=k^Stalk-root=b] V
# [Gill-size=n^Stalk-shape=e^Bruises?=t] V
# [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Bruises?=f] V
# [Ring-number=t^Population=v^Habitat=m] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Stalk-surface-above-ring=y^Cap-color=y]]
#
# optimization run 1 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Habitat=g] V
# [Gill-size=n^Sport-print-color=k^Stalk-root=b] V
# [Gill-size=n^Stalk-shape=e^Bruises?=t] V
# [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Bruises?=f] V
# [Ring-number=t^Population=v^Habitat=m] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Stalk-surface-above-ring=y^Cap-color=y]]
#
# optimization run 2 of 2
#
# OPTIMIZED RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Habitat=g] V
# [Gill-size=n^Sport-print-color=k^Stalk-root=b] V
# [Gill-size=n^Stalk-shape=e^Bruises?=t] V
# [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Bruises?=f] V
# [Ring-number=t^Population=v^Habitat=m] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Stalk-surface-above-ring=y^Cap-color=y]]
#
# All pos covered
#
# FINAL RULESET:
# [[Stalk-surface-above-ring=k^Gill-spacing=c] V
# [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V
# [Gill-size=n^Population=s] V
# [Sport-print-color=h^Cap-surface=s] V
# [Gill-size=n^Habitat=g] V
# [Gill-size=n^Sport-print-color=k^Stalk-root=b] V
# [Gill-size=n^Stalk-shape=e^Bruises?=t] V
# [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Bruises?=f] V
# [Ring-number=t^Population=v^Habitat=m] V
# [Ring-number=t^Population=v^Habitat=g] V
# [Stalk-surface-above-ring=y^Cap-color=y]]
#
# tree 10 of 10
# ripper means (0.9985686906328078, 0.9997701149425288, 28.8)
# ripper medians (1.0, 1.0, 28.5)
# tree means (0.9997101449275363, 1.0, 25.8)
# tree medians (1.0, 1.0, 27.0)
# max-tree 1 of 10
# max-tree 2 of 10
# max-tree 3 of 10
# max-tree 4 of 10
# max-tree 5 of 10
# max-tree 6 of 10
# max-tree 7 of 10
# max-tree 8 of 10
# max-tree 9 of 10
# max-tree 10 of 10
# maxtree means (0.9961124907561201, 0.9904823381289631, 18.4)
# maxtree medians (0.9992519626887717, 0.9869280976811692, 19.0)
#
# [<IREP object fit ruleset=[Stalk-surface-above-ring=k^Gill-spacing=c] V [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V [Gill-size=n^Population=s] V [Sport-print-color=h^Cap-surface=s] V [Gill-size=n^Cap-surface=s^Stalk-shape=e] V [Gill-size=n^Sport-print-color=k^Stalk-root=b] V [Gill-size=n^Stalk-shape=e^Bruises?=t] V [Ring-number=t^Population=v^Cap-shape=b] V [Gill-size=n^Population=c] V [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Cap-surface=f] V [Ring-number=t^Population=v^Habitat=g] V [Habitat=m^Cap-shape=f]>, <IREP object fit ruleset=[Stalk-surface-above-ring=k^Gill-spacing=c] V [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V [Gill-size=n^Population=s] V [Sport-print-color=h^Cap-surface=s] V [Gill-size=n^Bruises?=t^Stalk-shape=e] V [Gill-size=n^Sport-print-color=k^Stalk-root=b] V [Population=v^Ring-number=t^Habitat=m] V [Gill-size=n^Sport-print-color=n^Stalk-root=b^Bruises?=f] V [Ring-number=t^Population=v^Habitat=g] V [Stalk-surface-above-ring=y^Cap-color=y]>, <IREP object fit ruleset=[Stalk-surface-above-ring=k^Gill-spacing=c] V [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V [Gill-size=n^Population=s] V [Sport-print-color=h^Cap-surface=s] V [Gill-size=n^Cap-surface=s^Stalk-shape=e] V [Gill-size=n^Cap-surface=y^Bruises?=t] V [Gill-size=n^Cap-color=p] V [Gill-size=n^Population=c] V [Cap-color=p^Population=v] V [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Cap-surface=f] V [Ring-number=t^Population=v^Habitat=m] V [Ring-number=t^Population=v^Habitat=g]>, <IREP object fit ruleset=[Stalk-surface-above-ring=k^Gill-spacing=c] V [Gill-size=n^Stalk-root=?^Stalk-shape=t] V [Gill-size=n^Population=s] V [Sport-print-color=h^Cap-surface=s] V [Gill-size=n^Cap-surface=s^Stalk-shape=e] V [Gill-size=n^Habitat=g] V [Population=v^Stalk-shape=e^Bruises?=t] V [Gill-size=n^Stalk-root=b^Gill-spacing=c] V [Gill-size=n^Population=c] V [Gill-size=n^Cap-color=p] V [Gill-size=n^Gill-color=u^Cap-surface=f] V [Gill-size=n^Cap-color=g^Gill-spacing=w] V [Gill-color=g^Stalk-root=b]>, <IREP object fit ruleset=[Stalk-surface-above-ring=k^Gill-spacing=c] V [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V [Gill-size=n^Population=s] V [Sport-print-color=h^Cap-surface=s] V [Gill-size=n^Habitat=g] V [Gill-size=n^Sport-print-color=k^Stalk-root=b] V [Population=v^Stalk-shape=e^Bruises?=t^Cap-color=w] V [Gill-size=n^Population=c] V [Population=v^Stalk-shape=e^Bruises?=t^Cap-shape=b] V [Gill-size=n^Sport-print-color=n^Stalk-shape=e^Stalk-root=b] V [Habitat=u^Bruises?=t] V [Cap-color=b^Stalk-root=b] V [Cap-color=p^Population=v]>, <IREP object fit ruleset=[Stalk-surface-above-ring=k^Gill-spacing=c] V [Gill-size=n^Stalk-root=?^Stalk-shape=t] V [Gill-size=n^Population=s] V [Sport-print-color=h^Cap-surface=s] V [Gill-size=n^Ring-type=p^Stalk-shape=e^Bruises?=t] V [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Bruises?=f] V [Ring-number=t^Population=v^Habitat=g] V [Habitat=m^Odor=n] V [Stalk-surface-above-ring=y^Cap-color=y]>, <IREP object fit ruleset=[Stalk-surface-above-ring=k^Gill-spacing=c] V [Gill-size=n^Stalk-root=?^Stalk-shape=t] V [Gill-size=n^Population=s] V [Sport-print-color=h^Cap-surface=s] V [Gill-size=n^Stalk-shape=e^Bruises?=t] V [Gill-size=n^Cap-shape=x^Bruises?=f^Stalk-root=b^Stalk-color-below-ring=w] V [Ring-number=t^Population=v^Habitat=g] V [Habitat=m^Odor=n] V [Stalk-surface-above-ring=y^Cap-color=y]>, <IREP object fit ruleset=[Stalk-surface-above-ring=k^Gill-spacing=c] V [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V [Gill-size=n^Population=s] V [Sport-print-color=h^Cap-surface=s] V [Gill-size=n^Sport-print-color=k^Bruises?=t] V [Gill-size=n^Sport-print-color=n^Stalk-shape=e^Bruises?=t] V [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w] V [Habitat=l^Cap-color=w] V [Stalk-surface-above-ring=y^Cap-color=y]>, <IREP object fit ruleset=[Stalk-surface-above-ring=k^Gill-spacing=c] V [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V [Gill-size=n^Population=s] V ...
# {'max_t_means': (0.9961124907561201, 0.9904823381289631, 18.4),
#  'max_t_meds': (0.9992519626887717, 0.9869280976811692, 19.0),
#  'n': 10,
#  'r_means': (0.9985686906328078, 0.9997701149425288, 28.8),
#  'r_meds': (1.0, 1.0, 28.5),
#  'r_models': [<IREP object fit ruleset=[Stalk-surface-above-ring=k^Gill-spacing=c] V [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V [Gill-size=n^Population=s] V [Sport-print-color=h^Cap-surface=s] V [Gill-size=n^Cap-surface=s^Stalk-shape=e] V [Gill-size=n^Sport-print-color=k^Stalk-root=b] V [Gill-size=n^Stalk-shape=e^Bruises?=t] V [Ring-number=t^Population=v^Cap-shape=b] V [Gill-size=n^Population=c] V [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Cap-surface=f] V [Ring-number=t^Population=v^Habitat=g] V [Habitat=m^Cap-shape=f]>,
#   <IREP object fit ruleset=[Stalk-surface-above-ring=k^Gill-spacing=c] V [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V [Gill-size=n^Population=s] V [Sport-print-color=h^Cap-surface=s] V [Gill-size=n^Bruises?=t^Stalk-shape=e] V [Gill-size=n^Sport-print-color=k^Stalk-root=b] V [Population=v^Ring-number=t^Habitat=m] V [Gill-size=n^Sport-print-color=n^Stalk-root=b^Bruises?=f] V [Ring-number=t^Population=v^Habitat=g] V [Stalk-surface-above-ring=y^Cap-color=y]>,
#   <IREP object fit ruleset=[Stalk-surface-above-ring=k^Gill-spacing=c] V [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V [Gill-size=n^Population=s] V [Sport-print-color=h^Cap-surface=s] V [Gill-size=n^Cap-surface=s^Stalk-shape=e] V [Gill-size=n^Cap-surface=y^Bruises?=t] V [Gill-size=n^Cap-color=p] V [Gill-size=n^Population=c] V [Cap-color=p^Population=v] V [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Cap-surface=f] V [Ring-number=t^Population=v^Habitat=m] V [Ring-number=t^Population=v^Habitat=g]>,
#   <IREP object fit ruleset=[Stalk-surface-above-ring=k^Gill-spacing=c] V [Gill-size=n^Stalk-root=?^Stalk-shape=t] V [Gill-size=n^Population=s] V [Sport-print-color=h^Cap-surface=s] V [Gill-size=n^Cap-surface=s^Stalk-shape=e] V [Gill-size=n^Habitat=g] V [Population=v^Stalk-shape=e^Bruises?=t] V [Gill-size=n^Stalk-root=b^Gill-spacing=c] V [Gill-size=n^Population=c] V [Gill-size=n^Cap-color=p] V [Gill-size=n^Gill-color=u^Cap-surface=f] V [Gill-size=n^Cap-color=g^Gill-spacing=w] V [Gill-color=g^Stalk-root=b]>,
#   <IREP object fit ruleset=[Stalk-surface-above-ring=k^Gill-spacing=c] V [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V [Gill-size=n^Population=s] V [Sport-print-color=h^Cap-surface=s] V [Gill-size=n^Habitat=g] V [Gill-size=n^Sport-print-color=k^Stalk-root=b] V [Population=v^Stalk-shape=e^Bruises?=t^Cap-color=w] V [Gill-size=n^Population=c] V [Population=v^Stalk-shape=e^Bruises?=t^Cap-shape=b] V [Gill-size=n^Sport-print-color=n^Stalk-shape=e^Stalk-root=b] V [Habitat=u^Bruises?=t] V [Cap-color=b^Stalk-root=b] V [Cap-color=p^Population=v]>,
#   <IREP object fit ruleset=[Stalk-surface-above-ring=k^Gill-spacing=c] V [Gill-size=n^Stalk-root=?^Stalk-shape=t] V [Gill-size=n^Population=s] V [Sport-print-color=h^Cap-surface=s] V [Gill-size=n^Ring-type=p^Stalk-shape=e^Bruises?=t] V [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Bruises?=f] V [Ring-number=t^Population=v^Habitat=g] V [Habitat=m^Odor=n] V [Stalk-surface-above-ring=y^Cap-color=y]>,
#   <IREP object fit ruleset=[Stalk-surface-above-ring=k^Gill-spacing=c] V [Gill-size=n^Stalk-root=?^Stalk-shape=t] V [Gill-size=n^Population=s] V [Sport-print-color=h^Cap-surface=s] V [Gill-size=n^Stalk-shape=e^Bruises?=t] V [Gill-size=n^Cap-shape=x^Bruises?=f^Stalk-root=b^Stalk-color-below-ring=w] V [Ring-number=t^Population=v^Habitat=g] V [Habitat=m^Odor=n] V [Stalk-surface-above-ring=y^Cap-color=y]>,
#   <IREP object fit ruleset=[Stalk-surface-above-ring=k^Gill-spacing=c] V [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V [Gill-size=n^Population=s] V [Sport-print-color=h^Cap-surface=s] V [Gill-size=n^Sport-print-color=k^Bruises?=t] V [Gill-size=n^Sport-print-color=n^Stalk-shape=e^Bruises?=t] V [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w] V [Habitat=l^Cap-color=w] V [Stalk-surface-above-ring=y^Cap-color=y]>,
#   <IREP object fit ruleset=[Stalk-surface-above-ring=k^Gill-spacing=c] V [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V [Gill-size=n^Population=s] V [Sport-print-color=h^Cap-surface=s] V [Gill-size=n^Stalk-shape=e^Bruises?=t] V [Gill-size=n^Cap-shape=x^Stalk-root=b^Bruises?=f^Stalk-color-below-ring=w] V [Population=v^Ring-number=t^Cap-shape=b] V [Gill-size=n^Population=c] V [Ring-number=t^Population=v^Habitat=g] V [Habitat=m^Cap-shape=f]>,
#   <IREP object fit ruleset=[Stalk-surface-above-ring=k^Gill-spacing=c] V [Gill-size=n^Sport-print-color=w^Gill-spacing=c] V [Gill-size=n^Population=s] V [Sport-print-color=h^Cap-surface=s] V [Gill-size=n^Habitat=g] V [Gill-size=n^Sport-print-color=k^Stalk-root=b] V [Gill-size=n^Stalk-shape=e^Bruises?=t] V [Population=v^Stalk-shape=e^Stalk-root=b^Stalk-color-below-ring=w^Bruises?=f] V [Ring-number=t^Population=v^Habitat=m] V [Ring-number=t^Population=v^Habitat=g] V [Stalk-surface-above-ring=y^Cap-color=y]>],
#  't_means': (0.9997101449275363, 1.0, 25.8),
#  't_meds': (1.0, 1.0, 27.0)}

# %%
# Set up

# Recommend and very recommend

dataset = 'nursery.csv'
filename = datasets_path + dataset
class_feat = 'class'
pos_class = 'p'
n_classes = 2
k=2
verbosity=5
n_runs=1

# %%
# Set up

# Has test and train

dataset = 'SPECT.csv'
filename = datasets_path + dataset
class_feat = 'class'
pos_class = '1'
n_classes = 2
k=2
verbosity=5
n_runs=1

# %%
# Set up

# Has test and train

dataset = 'tic-tac-toe.csv'
filename = datasets_path + dataset
class_feat = 'Class'
pos_class = 'positive'
n_classes = 2
k=2
verbosity=5
n_runs=1

# %%
mushrooms = pd.read_csv(datasets_path+'mushroom.csv')
mushrooms.head()
# Out:
#   Poisonous/Edible Cap-shape Cap-surface Cap-color Bruises? Odor  \
# 0                p         x           s         n        t    p
# 1                e         x           s         y        t    a
# 2                e         b           s         w        t    l
# 3                p         x           y         w        t    p
# 4                e         x           s         g        f    n
#
#   Gill-attachment Gill-spacing Gill-size Gill-color   ...    \
# 0               f            c         n          k   ...
# 1               f            c         b          k   ...
# 2               f            c         b          n   ...
# 3               f            c         n          n   ...
# 4               f            w         b          k   ...
#
#   Stalk-surface-below-ring Stalk-color-above-ring Stalk-color-below-ring  \
# 0                        s                      w                      w
# 1                        s                      w                      w
# 2                        s                      w                      w
# 3                        s                      w                      w
# 4                        s                      w                      w
#
#   Veil-type Veil-color Ring-number Ring-type Sport-print-color Population  \
# 0         p          w           o         p                 k          s
# 1         p          w           o         p                 n          n
# 2         p          w           o         p                 n          n
# 3         p          w           o         p                 k          s
# 4         p          w           o         e                 n          a
#
#   Habitat
# 0       u
# 1       g
# 2       m
# 3       u
# 4       g
#
# [5 rows x 23 columns]

# %%
mushrooms = pd.read_csv(datasets_path+'mushroom.csv')
mushrooms['Gill-size']=mushrooms['Gill-size'].map(lambda x:1 if x=='b' else 0)
mushrooms['Poisonous/Edible']=mushrooms['Poisonous/Edible'].map(lambda x:1 if x=='p' else 0)
mushrooms = mushrooms[['Gill-size','Poisonous/Edible']].dropna()
mushrooms['Gill-size'].corr(mushrooms['Poisonous/Edible'])
# Out:
# -0.5400243574330186
